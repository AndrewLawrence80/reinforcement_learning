# %% [markdown]
# # Pendulum
# ## Description
#
# The inverted pendulum swingup problem is based on the classic problem in control theory.
# The system consists of a pendulum attached at one end to a fixed point, and the other end being free.
# The pendulum starts in a random position and the goal is to apply torque on the free end to swing it
# into an upright position, with its center of gravity right above the fixed point.
#
# The diagram below specifies the coordinate system used for the implementation of the pendulum's
# dynamic equations.
#
# ![Pendulum Coordinate System](https://gymnasium.farama.org/_images/pendulum.png)
#
# -  `x-y`: cartesian coordinates of the pendulum's end in meters.
# - `theta` : angle in radians.
# - `tau`: torque in `N m`. Defined as positive _counter-clockwise_.
#
# ### Action Space
#
# The action is a `ndarray` with shape `(1,)` representing the torque applied to free end of the pendulum.
#
# | Num | Action | Min  | Max |
# |-----|--------|------|-----|
# | 0   | Torque | -2.0 | 2.0 |
#
#
# ### Observation Space
#
# The observation is a `ndarray` with shape `(3,)` representing the x-y coordinates of the pendulum's free
# end and its angular velocity.
#
# | Num | Observation      | Min  | Max |
# |-----|------------------|------|-----|
# | 0   | x = cos(theta)   | -1.0 | 1.0 |
# | 1   | y = sin(theta)   | -1.0 | 1.0 |
# | 2   | Angular Velocity | -8.0 | 8.0 |
#
# ### Rewards
#
# The reward function is defined as:
#
# *r = -(theta<sup>2</sup> + 0.1 * theta_dt<sup>2</sup> + 0.001 * torque<sup>2</sup>)*
#
# where `$\theta$` is the pendulum's angle normalized between *[-pi, pi]* (with 0 being in the upright position).
# Based on the above equation, the minimum reward that can be obtained is
# *-(pi<sup>2</sup> + 0.1 * 8<sup>2</sup> + 0.001 * 2<sup>2</sup>) = -16.2736044*,
# while the maximum reward is zero (pendulum is upright with zero velocity and no torque applied).
#
# ### Starting State
#
# The starting state is a random angle in *[-pi, pi]* and a random angular velocity in *[-1,1]*.
#
# ### Episode Truncation
#
# The episode truncates at 200 time steps.
#
# ### Arguments
#
# - `g`: acceleration of gravity measured in *(m s<sup>-2</sup>)* used to calculate the pendulum dynamics.
#     The default value is g = 10.0 .
#
# ```python
# import gymnasium as gym
# gym.make('Pendulum-v1', g=9.81)
# ```
#
# On reset, the `options` parameter allows the user to change the bounds used to determine
# the new random state.
#
# ### Version History
#
# * v1: Simplify the math equations, no difference in behavior.
# * v0: Initial versions release (1.0.0)

# %%
import gymnasium as gym
from gymnasium.envs.classic_control.pendulum import PendulumEnv
for k,v in gym.envs.registry.items():
    print(str(k)+"\t"+str(v))
# Out:
# CartPole-v0	EnvSpec(id='CartPole-v0', entry_point='gymnasium.envs.classic_control.cartpole:CartPoleEnv', reward_threshold=195.0, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='CartPole', version=0, additional_wrappers=(), vector_entry_point='gymnasium.envs.classic_control.cartpole:CartPoleVectorEnv')
# CartPole-v1	EnvSpec(id='CartPole-v1', entry_point='gymnasium.envs.classic_control.cartpole:CartPoleEnv', reward_threshold=475.0, nondeterministic=False, max_episode_steps=500, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='CartPole', version=1, additional_wrappers=(), vector_entry_point='gymnasium.envs.classic_control.cartpole:CartPoleVectorEnv')
# MountainCar-v0	EnvSpec(id='MountainCar-v0', entry_point='gymnasium.envs.classic_control.mountain_car:MountainCarEnv', reward_threshold=-110.0, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='MountainCar', version=0, additional_wrappers=(), vector_entry_point=None)
# MountainCarContinuous-v0	EnvSpec(id='MountainCarContinuous-v0', entry_point='gymnasium.envs.classic_control.continuous_mountain_car:Continuous_MountainCarEnv', reward_threshold=90.0, nondeterministic=False, max_episode_steps=999, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='MountainCarContinuous', version=0, additional_wrappers=(), vector_entry_point=None)
# Pendulum-v1	EnvSpec(id='Pendulum-v1', entry_point='gymnasium.envs.classic_control.pendulum:PendulumEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Pendulum', version=1, additional_wrappers=(), vector_entry_point=None)
# Acrobot-v1	EnvSpec(id='Acrobot-v1', entry_point='gymnasium.envs.classic_control.acrobot:AcrobotEnv', reward_threshold=-100.0, nondeterministic=False, max_episode_steps=500, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Acrobot', version=1, additional_wrappers=(), vector_entry_point=None)
# CartPoleJax-v0	EnvSpec(id='CartPoleJax-v0', entry_point='gymnasium.envs.phys2d.cartpole:CartPoleJaxEnv', reward_threshold=195.0, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='CartPoleJax', version=0, additional_wrappers=(), vector_entry_point='gymnasium.envs.phys2d.cartpole:CartPoleJaxVectorEnv')
# CartPoleJax-v1	EnvSpec(id='CartPoleJax-v1', entry_point='gymnasium.envs.phys2d.cartpole:CartPoleJaxEnv', reward_threshold=475.0, nondeterministic=False, max_episode_steps=500, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='CartPoleJax', version=1, additional_wrappers=(), vector_entry_point='gymnasium.envs.phys2d.cartpole:CartPoleJaxVectorEnv')
# PendulumJax-v0	EnvSpec(id='PendulumJax-v0', entry_point='gymnasium.envs.phys2d.pendulum:PendulumJaxEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='PendulumJax', version=0, additional_wrappers=(), vector_entry_point='gymnasium.envs.phys2d.pendulum:PendulumJaxVectorEnv')
# LunarLander-v2	EnvSpec(id='LunarLander-v2', entry_point='gymnasium.envs.box2d.lunar_lander:LunarLander', reward_threshold=200, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='LunarLander', version=2, additional_wrappers=(), vector_entry_point=None)
# LunarLanderContinuous-v2	EnvSpec(id='LunarLanderContinuous-v2', entry_point='gymnasium.envs.box2d.lunar_lander:LunarLander', reward_threshold=200, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={'continuous': True}, namespace=None, name='LunarLanderContinuous', version=2, additional_wrappers=(), vector_entry_point=None)
# BipedalWalker-v3	EnvSpec(id='BipedalWalker-v3', entry_point='gymnasium.envs.box2d.bipedal_walker:BipedalWalker', reward_threshold=300, nondeterministic=False, max_episode_steps=1600, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='BipedalWalker', version=3, additional_wrappers=(), vector_entry_point=None)
# BipedalWalkerHardcore-v3	EnvSpec(id='BipedalWalkerHardcore-v3', entry_point='gymnasium.envs.box2d.bipedal_walker:BipedalWalker', reward_threshold=300, nondeterministic=False, max_episode_steps=2000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={'hardcore': True}, namespace=None, name='BipedalWalkerHardcore', version=3, additional_wrappers=(), vector_entry_point=None)
# CarRacing-v2	EnvSpec(id='CarRacing-v2', entry_point='gymnasium.envs.box2d.car_racing:CarRacing', reward_threshold=900, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='CarRacing', version=2, additional_wrappers=(), vector_entry_point=None)
# Blackjack-v1	EnvSpec(id='Blackjack-v1', entry_point='gymnasium.envs.toy_text.blackjack:BlackjackEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=None, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={'sab': True, 'natural': False}, namespace=None, name='Blackjack', version=1, additional_wrappers=(), vector_entry_point=None)
# FrozenLake-v1	EnvSpec(id='FrozenLake-v1', entry_point='gymnasium.envs.toy_text.frozen_lake:FrozenLakeEnv', reward_threshold=0.7, nondeterministic=False, max_episode_steps=100, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={'map_name': '4x4'}, namespace=None, name='FrozenLake', version=1, additional_wrappers=(), vector_entry_point=None)
# FrozenLake8x8-v1	EnvSpec(id='FrozenLake8x8-v1', entry_point='gymnasium.envs.toy_text.frozen_lake:FrozenLakeEnv', reward_threshold=0.85, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={'map_name': '8x8'}, namespace=None, name='FrozenLake8x8', version=1, additional_wrappers=(), vector_entry_point=None)
# CliffWalking-v0	EnvSpec(id='CliffWalking-v0', entry_point='gymnasium.envs.toy_text.cliffwalking:CliffWalkingEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=None, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='CliffWalking', version=0, additional_wrappers=(), vector_entry_point=None)
# Taxi-v3	EnvSpec(id='Taxi-v3', entry_point='gymnasium.envs.toy_text.taxi:TaxiEnv', reward_threshold=8, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Taxi', version=3, additional_wrappers=(), vector_entry_point=None)
# Jax-Blackjack-v0	EnvSpec(id='Jax-Blackjack-v0', entry_point='gymnasium.envs.tabular.blackjack:BlackJackJaxEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=None, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={'sutton_and_barto': True, 'natural': False}, namespace=None, name='Jax-Blackjack', version=0, additional_wrappers=(), vector_entry_point=None)
# Reacher-v2	EnvSpec(id='Reacher-v2', entry_point='gymnasium.envs.mujoco:ReacherEnv', reward_threshold=-3.75, nondeterministic=False, max_episode_steps=50, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Reacher', version=2, additional_wrappers=(), vector_entry_point=None)
# Reacher-v4	EnvSpec(id='Reacher-v4', entry_point='gymnasium.envs.mujoco.reacher_v4:ReacherEnv', reward_threshold=-3.75, nondeterministic=False, max_episode_steps=50, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Reacher', version=4, additional_wrappers=(), vector_entry_point=None)
# Pusher-v2	EnvSpec(id='Pusher-v2', entry_point='gymnasium.envs.mujoco:PusherEnv', reward_threshold=0.0, nondeterministic=False, max_episode_steps=100, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Pusher', version=2, additional_wrappers=(), vector_entry_point=None)
# Pusher-v4	EnvSpec(id='Pusher-v4', entry_point='gymnasium.envs.mujoco.pusher_v4:PusherEnv', reward_threshold=0.0, nondeterministic=False, max_episode_steps=100, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Pusher', version=4, additional_wrappers=(), vector_entry_point=None)
# InvertedPendulum-v2	EnvSpec(id='InvertedPendulum-v2', entry_point='gymnasium.envs.mujoco:InvertedPendulumEnv', reward_threshold=950.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='InvertedPendulum', version=2, additional_wrappers=(), vector_entry_point=None)
# InvertedPendulum-v4	EnvSpec(id='InvertedPendulum-v4', entry_point='gymnasium.envs.mujoco.inverted_pendulum_v4:InvertedPendulumEnv', reward_threshold=950.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='InvertedPendulum', version=4, additional_wrappers=(), vector_entry_point=None)
# InvertedDoublePendulum-v2	EnvSpec(id='InvertedDoublePendulum-v2', entry_point='gymnasium.envs.mujoco:InvertedDoublePendulumEnv', reward_threshold=9100.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='InvertedDoublePendulum', version=2, additional_wrappers=(), vector_entry_point=None)
# InvertedDoublePendulum-v4	EnvSpec(id='InvertedDoublePendulum-v4', entry_point='gymnasium.envs.mujoco.inverted_double_pendulum_v4:InvertedDoublePendulumEnv', reward_threshold=9100.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='InvertedDoublePendulum', version=4, additional_wrappers=(), vector_entry_point=None)
# HalfCheetah-v2	EnvSpec(id='HalfCheetah-v2', entry_point='gymnasium.envs.mujoco:HalfCheetahEnv', reward_threshold=4800.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='HalfCheetah', version=2, additional_wrappers=(), vector_entry_point=None)
# HalfCheetah-v3	EnvSpec(id='HalfCheetah-v3', entry_point='gymnasium.envs.mujoco.half_cheetah_v3:HalfCheetahEnv', reward_threshold=4800.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='HalfCheetah', version=3, additional_wrappers=(), vector_entry_point=None)
# HalfCheetah-v4	EnvSpec(id='HalfCheetah-v4', entry_point='gymnasium.envs.mujoco.half_cheetah_v4:HalfCheetahEnv', reward_threshold=4800.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='HalfCheetah', version=4, additional_wrappers=(), vector_entry_point=None)
# Hopper-v2	EnvSpec(id='Hopper-v2', entry_point='gymnasium.envs.mujoco:HopperEnv', reward_threshold=3800.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Hopper', version=2, additional_wrappers=(), vector_entry_point=None)
# Hopper-v3	EnvSpec(id='Hopper-v3', entry_point='gymnasium.envs.mujoco.hopper_v3:HopperEnv', reward_threshold=3800.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Hopper', version=3, additional_wrappers=(), vector_entry_point=None)
# Hopper-v4	EnvSpec(id='Hopper-v4', entry_point='gymnasium.envs.mujoco.hopper_v4:HopperEnv', reward_threshold=3800.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Hopper', version=4, additional_wrappers=(), vector_entry_point=None)
# Swimmer-v2	EnvSpec(id='Swimmer-v2', entry_point='gymnasium.envs.mujoco:SwimmerEnv', reward_threshold=360.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Swimmer', version=2, additional_wrappers=(), vector_entry_point=None)
# Swimmer-v3	EnvSpec(id='Swimmer-v3', entry_point='gymnasium.envs.mujoco.swimmer_v3:SwimmerEnv', reward_threshold=360.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Swimmer', version=3, additional_wrappers=(), vector_entry_point=None)
# Swimmer-v4	EnvSpec(id='Swimmer-v4', entry_point='gymnasium.envs.mujoco.swimmer_v4:SwimmerEnv', reward_threshold=360.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Swimmer', version=4, additional_wrappers=(), vector_entry_point=None)
# Walker2d-v2	EnvSpec(id='Walker2d-v2', entry_point='gymnasium.envs.mujoco:Walker2dEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Walker2d', version=2, additional_wrappers=(), vector_entry_point=None)
# Walker2d-v3	EnvSpec(id='Walker2d-v3', entry_point='gymnasium.envs.mujoco.walker2d_v3:Walker2dEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Walker2d', version=3, additional_wrappers=(), vector_entry_point=None)
# Walker2d-v4	EnvSpec(id='Walker2d-v4', entry_point='gymnasium.envs.mujoco.walker2d_v4:Walker2dEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Walker2d', version=4, additional_wrappers=(), vector_entry_point=None)
# Ant-v2	EnvSpec(id='Ant-v2', entry_point='gymnasium.envs.mujoco:AntEnv', reward_threshold=6000.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Ant', version=2, additional_wrappers=(), vector_entry_point=None)
# Ant-v3	EnvSpec(id='Ant-v3', entry_point='gymnasium.envs.mujoco.ant_v3:AntEnv', reward_threshold=6000.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Ant', version=3, additional_wrappers=(), vector_entry_point=None)
# Ant-v4	EnvSpec(id='Ant-v4', entry_point='gymnasium.envs.mujoco.ant_v4:AntEnv', reward_threshold=6000.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Ant', version=4, additional_wrappers=(), vector_entry_point=None)
# Humanoid-v2	EnvSpec(id='Humanoid-v2', entry_point='gymnasium.envs.mujoco:HumanoidEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Humanoid', version=2, additional_wrappers=(), vector_entry_point=None)
# Humanoid-v3	EnvSpec(id='Humanoid-v3', entry_point='gymnasium.envs.mujoco.humanoid_v3:HumanoidEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Humanoid', version=3, additional_wrappers=(), vector_entry_point=None)
# Humanoid-v4	EnvSpec(id='Humanoid-v4', entry_point='gymnasium.envs.mujoco.humanoid_v4:HumanoidEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Humanoid', version=4, additional_wrappers=(), vector_entry_point=None)
# HumanoidStandup-v2	EnvSpec(id='HumanoidStandup-v2', entry_point='gymnasium.envs.mujoco:HumanoidStandupEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='HumanoidStandup', version=2, additional_wrappers=(), vector_entry_point=None)
# HumanoidStandup-v4	EnvSpec(id='HumanoidStandup-v4', entry_point='gymnasium.envs.mujoco.humanoidstandup_v4:HumanoidStandupEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='HumanoidStandup', version=4, additional_wrappers=(), vector_entry_point=None)
# GymV21Environment-v0	EnvSpec(id='GymV21Environment-v0', entry_point=<function _raise_shimmy_error at 0x7efd283ae7a0>, reward_threshold=None, nondeterministic=False, max_episode_steps=None, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='GymV21Environment', version=0, additional_wrappers=(), vector_entry_point=None)
# GymV26Environment-v0	EnvSpec(id='GymV26Environment-v0', entry_point=<function _raise_shimmy_error at 0x7efd283ae7a0>, reward_threshold=None, nondeterministic=False, max_episode_steps=None, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='GymV26Environment', version=0, additional_wrappers=(), vector_entry_point=None)

# %%
env=gym.make("Pendulum-v1")
print("Observation space: ",env.observation_space)
print("Action space: ",env.action_space)
# Out:
# Observation space:  Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# Action space:  Box(-2.0, 2.0, (1,), float32)

# %%
import torch
import torch.nn as nn
class Actor(nn.Module):
    def __init__(self,num_observations,num_actions,action_bound) -> None:
        super().__init__()
        self.num_hidden=128
        self.linear_1=nn.Linear(num_observations,self.num_hidden)
        self.selu=nn.SELU()
        self.linear_2=nn.Linear(self.num_hidden,num_actions)
        self.tanh=nn.Tanh()
        self.action_bound=action_bound
    
    def forward(self,x:torch.Tensor)->torch.Tensor:
        x=self.linear_1(x)
        x=self.selu(x)
        x=self.linear_2(x)
        x=self.tanh(x)
        x=self.action_bound*x
        return x
    
class Critic(nn.Module):
    def __init__(self,num_observations,num_actions) -> None:
        super().__init__()
        self.num_hidden=128
        self.linear_1=nn.Linear(num_observations+num_actions,self.num_hidden)
        self.selu=nn.SELU()
        self.linear_2=nn.Linear(self.num_hidden,1)
    
    def forward(self,state:torch.Tensor,action:torch.Tensor)->torch.Tensor:
        x=torch.cat([state,action],dim=1)
        x=self.linear_1(x)
        x=self.selu(x)
        x=self.linear_2(x)
        return x

# %%
from collections import namedtuple,deque
import random
from typing import List
Transition=namedtuple("Transition",["state","action","next_state","next_action","reward"])
class Experience:
    def __init__(self,maxlen=1024) -> None:
        self.experience=deque([],maxlen)
    def append(self,transition:Transition)->None:
        self.experience.append(transition)
    def __len__(self)->int:
        return len(self.experience)
    def sample(self,batch_size:int)->List[Transition]:
        return random.sample(self.experience,batch_size)

# %%
def update_actor_critic(actor: Actor, actor_target: Actor,
                        critic: Critic, critic_target: Critic,
                        experience: Experience, batch_size: int,
                        optimizer_actor: torch.optim.Optimizer, optimizer_critic: torch.optim.Optimizer,
                        discount_factor: float,
                        tau: float,
                        device: str):
    batch = experience.sample(batch_size)
    batch_state, batch_action, batch_next_state, batch_next_action, batch_reward = zip(*batch)
    mask_batch_next_state_is_not_none = [next_state is not None for next_state in batch_next_state]
    batch_not_none_next_state = [next_state for next_state in batch_next_state if next_state is not None]

    batch_state = torch.tensor(batch_state, dtype=torch.float32, device=device)
    batch_action = torch.tensor(batch_action, dtype=torch.float32, device=device).reshape(-1, 1)
    batch_not_none_next_state = torch.tensor(batch_not_none_next_state, dtype=torch.float32, device=device)
    batch_reward = torch.tensor(batch_reward, dtype=torch.float32, device=device).reshape((-1, 1))
    mask_batch_next_state_is_not_none = torch.tensor(mask_batch_next_state_is_not_none, dtype=torch.bool, device=device)

    value_state = critic(batch_state, batch_action)
    value_next_state = torch.zeros(batch_reward.size(), dtype=torch.float32, device=device)
    # with torch.no_grad():
    value_next_state[mask_batch_next_state_is_not_none] = critic_target(batch_not_none_next_state, actor_target(batch_not_none_next_state))
    td_target = batch_reward+discount_factor*value_next_state

    loss_critic_fn = nn.MSELoss()
    loss_critic = loss_critic_fn(value_state, td_target)
    optimizer_critic.zero_grad()
    loss_critic.backward()
    optimizer_critic.step()

    loss_actor = -torch.mean(critic(batch_state, actor(batch_state)))
    optimizer_actor.zero_grad()
    loss_actor.backward()
    optimizer_actor.step()

    actor_state_dict = actor.state_dict()
    actor_target_state_dict = actor_target.state_dict()
    for key in actor_target_state_dict:
        actor_target_state_dict[key] = actor_target_state_dict[key]*(1-tau)+actor_state_dict[key]*tau
    actor_target.load_state_dict(actor_target_state_dict)
    
    critic_state_dict = critic.state_dict()
    critic_target_state_dict = critic_target.state_dict()
    for key in critic_target_state_dict:
        critic_target_state_dict[key] = critic_target_state_dict[key]*(1-tau)+critic_state_dict[key]*tau
    critic_target.load_state_dict(critic_target_state_dict)
    
    return loss_actor.item(),loss_critic.item()

# %%
from collections import defaultdict
import numpy as np


def actor_critic_learning(env: gym.Env, num_episodes: int = 1000,
                          experience_maxlen: int = 1024, batch_size: int = 128,
                          epsilon: float = 0.01,
                          learning_rate_actor: float = 1e-3, learning_rate_critic: float = 1e-4,
                          discount_factor: float = 0.9,
                          tau=0.05, device: str = "cpu",
                          print_step=100):
    actor = Actor(env.observation_space.shape[0], env.action_space.shape[0], env.action_space.high.item()).to(device)
    actor_target = Actor(env.observation_space.shape[0], env.action_space.shape[0], env.action_space.high.item()).to(device)
    actor_target.load_state_dict(actor.state_dict())

    critic = Critic(env.observation_space.shape[0], env.action_space.shape[0]).to(device)
    critic_target = Critic(env.observation_space.shape[0], env.action_space.shape[0]).to(device)
    critic_target.load_state_dict(critic.state_dict())

    optimizer_actor = torch.optim.SGD(actor.parameters(), lr=learning_rate_actor)
    optimizer_critic = torch.optim.SGD(critic.parameters(), lr=learning_rate_critic)

    experience = Experience(experience_maxlen)

    reward_per_episode = defaultdict(float)

    loss_actor = 0.0
    loss_critic = 0.0

    for episode_i in range(num_episodes):
        state = env.reset()[0]
        is_truncated = False
        while not is_truncated:
            state_tensor = torch.tensor(state, dtype=torch.float32, device=device)
            action = actor(state_tensor).item()+epsilon*np.random.randn()
            next_state, reward, is_terminated, is_truncated, info = env.step([action])
            if is_truncated:
                reward = 0.0
                next_state = None
            experience.append(Transition(state, action, next_state, None, reward))
            state = next_state

            reward_per_episode[episode_i] += reward

            if len(experience) > batch_size:
                loss_actor, loss_critic = update_actor_critic(actor, actor_target, critic, critic_target, experience, batch_size, optimizer_actor, optimizer_critic, discount_factor, tau, device)

        if episode_i % print_step == 0:
            print("episode %d, loss_actor %f, loss_critic %f, reawrd %f" % (episode_i, loss_actor, loss_critic, reward_per_episode[episode_i]))

# %%
actor_critic_learning(env, num_episodes=1500, experience_maxlen=1024, batch_size=128, epsilon=0.01, learning_rate_actor=3e-3, learning_rate_critic=3e-4, discount_factor=0.9, tau=0.05, device="cuda" if torch.cuda.is_available() else "cpu", print_step=1)
# Out:
# /tmp/ipykernel_16291/2950718575.py:13: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484808560/work/torch/csrc/utils/tensor_new.cpp:201.)
#   batch_state = torch.tensor(batch_state, dtype=torch.float32, device=device)
# episode 0, loss_actor 10.512185, loss_critic 30.276833, reawrd -1770.783230
# episode 1, loss_actor 27.716431, loss_critic 12.491794, reawrd -1518.686475
# episode 2, loss_actor 44.098740, loss_critic 21.519272, reawrd -1169.299229
# episode 3, loss_actor 56.730980, loss_critic 91.141937, reawrd -1488.669692
# episode 4, loss_actor 64.612373, loss_critic 2.155486, reawrd -1406.448515
# episode 5, loss_actor 67.242676, loss_critic 45.969559, reawrd -1493.003400
# episode 6, loss_actor 66.703239, loss_critic 44.321308, reawrd -1498.863705
# episode 7, loss_actor 69.414383, loss_critic 45.792313, reawrd -1402.397442
# episode 8, loss_actor 67.405685, loss_critic 81.629982, reawrd -1266.794407
# episode 9, loss_actor 66.223236, loss_critic 82.468948, reawrd -1377.986299
# episode 10, loss_actor 63.418789, loss_critic 1.987171, reawrd -1143.166934
# episode 11, loss_actor 63.779243, loss_critic 52.410198, reawrd -1488.604266
# episode 12, loss_actor 59.983757, loss_critic 30.469446, reawrd -1050.722646
# episode 13, loss_actor 57.172321, loss_critic 3.260321, reawrd -945.853930
# episode 14, loss_actor 50.789360, loss_critic 45.530132, reawrd -760.050724
# episode 15, loss_actor 43.600147, loss_critic 79.780060, reawrd -830.317593
# episode 16, loss_actor 40.507339, loss_critic 8.476865, reawrd -1345.235523
# episode 17, loss_actor 42.462376, loss_critic 47.318409, reawrd -1205.615276
# episode 18, loss_actor 44.455627, loss_critic 40.974205, reawrd -1177.254214
# episode 19, loss_actor 55.426094, loss_critic 3.712667, reawrd -1361.819212
# episode 20, loss_actor 58.924961, loss_critic 3.866527, reawrd -854.600266
# episode 21, loss_actor 60.530384, loss_critic 1.027700, reawrd -1496.103385
# episode 22, loss_actor 61.333740, loss_critic 0.823502, reawrd -1489.022273
# episode 23, loss_actor 64.955132, loss_critic 0.552697, reawrd -1384.527266
# episode 24, loss_actor 61.462582, loss_critic 77.654297, reawrd -1612.272400
# episode 25, loss_actor 65.816727, loss_critic 48.479084, reawrd -1487.892112
# episode 26, loss_actor 64.149246, loss_critic 129.356720, reawrd -796.263436
# episode 27, loss_actor 59.262756, loss_critic 73.538689, reawrd -1521.710681
# episode 28, loss_actor 62.695320, loss_critic 38.039692, reawrd -1642.903992
# episode 29, loss_actor 63.194099, loss_critic 6.623063, reawrd -1484.305519
# episode 30, loss_actor 59.574715, loss_critic 42.228626, reawrd -1677.468406
# episode 31, loss_actor 69.143608, loss_critic 6.391191, reawrd -1581.461080
# episode 32, loss_actor 73.547592, loss_critic 47.737942, reawrd -1489.524473
# episode 33, loss_actor 73.938492, loss_critic 96.639023, reawrd -1542.149200
# episode 34, loss_actor 72.659058, loss_critic 7.934090, reawrd -1578.228572
# episode 35, loss_actor 74.403793, loss_critic 86.069099, reawrd -1601.037280
# episode 36, loss_actor 64.249298, loss_critic 2.664949, reawrd -1332.150932
# episode 37, loss_actor 61.935719, loss_critic 1.832122, reawrd -1420.184790
# episode 38, loss_actor 62.112152, loss_critic 27.287426, reawrd -1424.550909
# episode 39, loss_actor 66.195946, loss_critic 1.240355, reawrd -1417.943684
# episode 40, loss_actor 68.642151, loss_critic 1.157527, reawrd -1478.076893
# episode 41, loss_actor 69.208405, loss_critic 0.871858, reawrd -1489.270204
# episode 42, loss_actor 70.633408, loss_critic 83.047073, reawrd -1500.510738
# episode 43, loss_actor 71.585052, loss_critic 41.381271, reawrd -1496.256482
# episode 44, loss_actor 72.477036, loss_critic 44.906704, reawrd -1439.951024
# episode 45, loss_actor 72.477379, loss_critic 0.647978, reawrd -1469.971626
# episode 46, loss_actor 71.134705, loss_critic 0.493451, reawrd -1462.039824
# episode 47, loss_actor 70.690269, loss_critic 43.860146, reawrd -1487.900475
# episode 48, loss_actor 69.518524, loss_critic 0.340266, reawrd -1472.207840
# episode 49, loss_actor 69.000458, loss_critic 86.227402, reawrd -1397.382751
# episode 50, loss_actor 69.552696, loss_critic 0.233150, reawrd -1484.817782
# episode 51, loss_actor 69.369965, loss_critic 0.337877, reawrd -1459.006686
# episode 52, loss_actor 68.054230, loss_critic 55.873337, reawrd -1207.417401
# episode 53, loss_actor 67.840172, loss_critic 46.284660, reawrd -1380.447396
# episode 54, loss_actor 67.274666, loss_critic 26.657509, reawrd -1357.647116
# episode 55, loss_actor 66.680725, loss_critic 45.435005, reawrd -1244.924686
# episode 56, loss_actor 65.610382, loss_critic 0.889653, reawrd -1354.798248
# episode 57, loss_actor 60.933037, loss_critic 33.320702, reawrd -969.405406
# episode 58, loss_actor 58.444996, loss_critic 17.195621, reawrd -876.386741
# episode 59, loss_actor 61.049423, loss_critic 51.342361, reawrd -1489.042078
# episode 60, loss_actor 57.904087, loss_critic 2.464899, reawrd -1620.599300
# episode 61, loss_actor 56.110329, loss_critic 40.755516, reawrd -1004.315878
# episode 62, loss_actor 61.040993, loss_critic 3.265688, reawrd -1630.471098
# episode 63, loss_actor 65.710274, loss_critic 58.395668, reawrd -1600.378436
# episode 64, loss_actor 69.826385, loss_critic 13.535000, reawrd -1331.726419
# episode 65, loss_actor 64.817101, loss_critic 36.695309, reawrd -1380.755114
# episode 66, loss_actor 65.439980, loss_critic 2.913825, reawrd -841.407424
# episode 67, loss_actor 67.698387, loss_critic 97.487122, reawrd -1629.134416
# episode 68, loss_actor 66.503052, loss_critic 127.039932, reawrd -1641.776631
# episode 69, loss_actor 59.270267, loss_critic 72.666885, reawrd -492.002000
# episode 70, loss_actor 60.214634, loss_critic 3.661385, reawrd -1380.821889
# episode 71, loss_actor 66.759087, loss_critic 3.113968, reawrd -1610.228608
# episode 72, loss_actor 59.777576, loss_critic 3.953427, reawrd -1503.687461
# episode 73, loss_actor 65.480865, loss_critic 2.228313, reawrd -1651.237231
# episode 74, loss_actor 69.906403, loss_critic 49.429573, reawrd -1650.263083
# episode 75, loss_actor 75.228020, loss_critic 2.422614, reawrd -1373.105803
# episode 76, loss_actor 70.723480, loss_critic 19.286034, reawrd -937.176002
# episode 77, loss_actor 67.846848, loss_critic 4.783994, reawrd -1223.795411
# episode 78, loss_actor 63.306248, loss_critic 54.188957, reawrd -1503.823630
# episode 79, loss_actor 63.681690, loss_critic 2.141687, reawrd -1375.472895
# episode 80, loss_actor 65.381104, loss_critic 48.924503, reawrd -1591.159074
# episode 81, loss_actor 66.264427, loss_critic 1.889631, reawrd -1338.217016
# episode 82, loss_actor 70.673309, loss_critic 24.599216, reawrd -1640.370505
# episode 83, loss_actor 72.784286, loss_critic 58.182373, reawrd -1485.775511
# episode 84, loss_actor 73.902962, loss_critic 1.396008, reawrd -1499.592661
# episode 85, loss_actor 69.408936, loss_critic 1.433606, reawrd -1345.492274
# episode 86, loss_actor 69.810776, loss_critic 1.039126, reawrd -1141.146614
# episode 87, loss_actor 69.374336, loss_critic 0.882042, reawrd -1585.378143
# episode 88, loss_actor 65.903969, loss_critic 2.503562, reawrd -934.570713
# episode 89, loss_actor 62.150494, loss_critic 33.867493, reawrd -1506.080954
# episode 90, loss_actor 66.336212, loss_critic 36.332264, reawrd -1653.300818
# episode 91, loss_actor 67.800674, loss_critic 2.193304, reawrd -1180.994939
# episode 92, loss_actor 64.564445, loss_critic 36.727058, reawrd -1266.521440
# episode 93, loss_actor 67.910217, loss_critic 2.142655, reawrd -1461.911024
# episode 94, loss_actor 69.614517, loss_critic 85.669250, reawrd -1665.717870
# episode 95, loss_actor 71.552048, loss_critic 2.099098, reawrd -1596.922388
# episode 96, loss_actor 70.750839, loss_critic 43.647030, reawrd -1493.654513
# episode 97, loss_actor 74.237411, loss_critic 65.456306, reawrd -1610.164206
# episode 98, loss_actor 77.422729, loss_critic 46.479057, reawrd -1490.594090
# episode 99, loss_actor 74.074753, loss_critic 1.420757, reawrd -1394.450607
# episode 100, loss_actor 71.522858, loss_critic 147.157898, reawrd -1494.170899
# episode 101, loss_actor 70.088837, loss_critic 1.051451, reawrd -1365.995320
# episode 102, loss_actor 71.004578, loss_critic 1.172589, reawrd -1630.569427
# episode 103, loss_actor 71.026657, loss_critic 67.075844, reawrd -1386.397762
# episode 104, loss_actor 73.859085, loss_critic 1.268892, reawrd -1656.511215
# episode 105, loss_actor 75.170509, loss_critic 46.704151, reawrd -1617.403009
# episode 106, loss_actor 76.536522, loss_critic 26.226166, reawrd -1490.870367
# episode 107, loss_actor 73.023079, loss_critic 52.840843, reawrd -1484.095918
# episode 108, loss_actor 74.769257, loss_critic 36.727009, reawrd -1557.069694
# episode 109, loss_actor 69.859665, loss_critic 1.689270, reawrd -1067.568415
# episode 110, loss_actor 64.210175, loss_critic 58.384769, reawrd -1191.100397
# episode 111, loss_actor 65.605476, loss_critic 28.747713, reawrd -1424.853958
# episode 112, loss_actor 62.176697, loss_critic 8.916069, reawrd -1164.874972
# episode 113, loss_actor 58.166229, loss_critic 11.328615, reawrd -978.592608
# episode 114, loss_actor 63.963615, loss_critic 57.348598, reawrd -1574.334036
# episode 115, loss_actor 62.847923, loss_critic 47.685257, reawrd -1506.785502
# episode 116, loss_actor 65.239944, loss_critic 12.381802, reawrd -1656.168546
# episode 117, loss_actor 66.570511, loss_critic 45.388985, reawrd -1446.242784
# episode 118, loss_actor 74.154251, loss_critic 43.078350, reawrd -1676.219171
# episode 119, loss_actor 75.651199, loss_critic 46.057953, reawrd -1645.241632
# episode 120, loss_actor 74.365364, loss_critic 1.463406, reawrd -1317.521114
# episode 121, loss_actor 73.810982, loss_critic 16.223181, reawrd -1643.166246
# episode 122, loss_actor 75.096115, loss_critic 54.661888, reawrd -1627.221517
# episode 123, loss_actor 73.138512, loss_critic 14.488648, reawrd -1187.495915
# episode 124, loss_actor 67.970932, loss_critic 52.360664, reawrd -1180.745514
# episode 125, loss_actor 68.419800, loss_critic 1.475212, reawrd -1487.852246
# episode 126, loss_actor 68.644836, loss_critic 1.215108, reawrd -1381.436805
# episode 127, loss_actor 66.313217, loss_critic 0.819743, reawrd -1492.426615
# episode 128, loss_actor 65.545975, loss_critic 0.768743, reawrd -1440.119032
# episode 129, loss_actor 71.132782, loss_critic 10.232071, reawrd -1649.364385
# episode 130, loss_actor 71.086594, loss_critic 60.031296, reawrd -1500.474549
# episode 131, loss_actor 69.970840, loss_critic 0.897846, reawrd -1252.957475
# episode 132, loss_actor 73.939636, loss_critic 80.247864, reawrd -1627.487687
# episode 133, loss_actor 74.391663, loss_critic 67.972542, reawrd -1627.069047
# episode 134, loss_actor 72.398369, loss_critic 1.670917, reawrd -1503.932639
# episode 135, loss_actor 60.852943, loss_critic 64.263725, reawrd -1220.388121
# episode 136, loss_actor 65.656219, loss_critic 38.549271, reawrd -1035.402236
# episode 137, loss_actor 60.395817, loss_critic 78.498810, reawrd -1045.907325
# episode 138, loss_actor 57.627682, loss_critic 18.510935, reawrd -1494.924785
# episode 139, loss_actor 59.015442, loss_critic 2.806473, reawrd -1462.430633
# episode 140, loss_actor 59.544815, loss_critic 51.321243, reawrd -1418.789698
# episode 141, loss_actor 63.984394, loss_critic 17.914593, reawrd -1525.687662
# episode 142, loss_actor 66.301186, loss_critic 0.836677, reawrd -988.828064
# episode 143, loss_actor 65.980667, loss_critic 48.157032, reawrd -1448.770432
# episode 144, loss_actor 63.012501, loss_critic 49.867046, reawrd -1329.774599
# episode 145, loss_actor 62.156559, loss_critic 1.740366, reawrd -1457.591284
# episode 146, loss_actor 63.022884, loss_critic 14.680385, reawrd -1552.544961
# episode 147, loss_actor 65.573471, loss_critic 1.409034, reawrd -1254.665912
# episode 148, loss_actor 62.092106, loss_critic 1.572078, reawrd -955.803523
# episode 149, loss_actor 63.816734, loss_critic 51.180389, reawrd -1500.582950
# episode 150, loss_actor 60.868893, loss_critic 25.103464, reawrd -1149.356787
# episode 151, loss_actor 61.501785, loss_critic 0.831702, reawrd -1368.299035
# episode 152, loss_actor 60.776352, loss_critic 1.060387, reawrd -1334.216357
# episode 153, loss_actor 65.089767, loss_critic 27.130987, reawrd -1484.149816
# episode 154, loss_actor 63.140308, loss_critic 29.863068, reawrd -1506.475465
# episode 155, loss_actor 68.351715, loss_critic 1.579162, reawrd -1397.703216
# episode 156, loss_actor 70.466644, loss_critic 1.324240, reawrd -1496.244375
# episode 157, loss_actor 69.487488, loss_critic 0.786869, reawrd -1447.643501
# episode 158, loss_actor 68.823570, loss_critic 44.716625, reawrd -1211.880122
# episode 159, loss_actor 66.212799, loss_critic 29.614714, reawrd -1312.772062
# episode 160, loss_actor 66.254921, loss_critic 66.858765, reawrd -1401.688358
# episode 161, loss_actor 67.214287, loss_critic 35.940945, reawrd -1500.952714
# episode 162, loss_actor 62.364029, loss_critic 0.645771, reawrd -1001.153960
# episode 163, loss_actor 62.287003, loss_critic 0.535325, reawrd -1097.092606
# episode 164, loss_actor 59.481686, loss_critic 36.717770, reawrd -1252.068076
# episode 165, loss_actor 59.790169, loss_critic 34.919514, reawrd -1391.498517
# episode 166, loss_actor 56.503628, loss_critic 1.408149, reawrd -1062.125793
# episode 167, loss_actor 58.186970, loss_critic 1.068662, reawrd -980.828023
# episode 168, loss_actor 52.651314, loss_critic 2.252848, reawrd -933.245130
# episode 169, loss_actor 52.827686, loss_critic 46.243481, reawrd -711.765274
# episode 170, loss_actor 44.290436, loss_critic 2.546076, reawrd -411.352379
# episode 171, loss_actor 37.839661, loss_critic 3.010477, reawrd -949.841100
# episode 172, loss_actor 45.293861, loss_critic 2.144505, reawrd -1494.592813
# episode 173, loss_actor 32.958946, loss_critic 3.395750, reawrd -297.579246
# episode 174, loss_actor 42.852329, loss_critic 4.743644, reawrd -1186.128342
# episode 175, loss_actor 45.062149, loss_critic 2.965641, reawrd -948.973025
# episode 176, loss_actor 47.277855, loss_critic 8.907206, reawrd -1223.883893
# episode 177, loss_actor 45.193207, loss_critic 21.160675, reawrd -1527.358828
# episode 178, loss_actor 54.123638, loss_critic 25.591606, reawrd -1485.269510
# episode 179, loss_actor 51.438820, loss_critic 76.616615, reawrd -947.133185
# episode 180, loss_actor 49.943352, loss_critic 2.506386, reawrd -1055.644122
# episode 181, loss_actor 56.471867, loss_critic 1.506778, reawrd -1496.127457
# episode 182, loss_actor 62.974815, loss_critic 27.690538, reawrd -1496.452174
# episode 183, loss_actor 57.653389, loss_critic 1.074576, reawrd -975.717006
# episode 184, loss_actor 55.793793, loss_critic 26.272749, reawrd -968.398638
# episode 185, loss_actor 60.124165, loss_critic 1.222365, reawrd -1165.139222
# episode 186, loss_actor 56.680695, loss_critic 1.438925, reawrd -1231.761989
# episode 187, loss_actor 55.885216, loss_critic 39.923546, reawrd -1507.347557
# episode 188, loss_actor 52.490463, loss_critic 32.516811, reawrd -1120.314074
# episode 189, loss_actor 54.248276, loss_critic 34.363415, reawrd -1499.308913
# episode 190, loss_actor 58.918106, loss_critic 21.731236, reawrd -1587.976750
# episode 191, loss_actor 66.873413, loss_critic 7.289134, reawrd -1635.978611
# episode 192, loss_actor 67.638603, loss_critic 70.382202, reawrd -1577.931608
# episode 193, loss_actor 72.609970, loss_critic 59.685677, reawrd -1570.638725
# episode 194, loss_actor 67.568314, loss_critic 197.548767, reawrd -1600.095627
# episode 195, loss_actor 78.536987, loss_critic 2.845588, reawrd -1653.325548
# episode 196, loss_actor 79.401352, loss_critic 3.439699, reawrd -1620.425661
# episode 197, loss_actor 79.326439, loss_critic 2.520416, reawrd -1584.351197
# episode 198, loss_actor 80.554260, loss_critic 10.512227, reawrd -1641.149082
# episode 199, loss_actor 79.659256, loss_critic 2.341361, reawrd -1596.239850
# episode 200, loss_actor 79.336479, loss_critic 1.561317, reawrd -1663.007533
# episode 201, loss_actor 77.226013, loss_critic 2.617901, reawrd -1490.033544
# episode 202, loss_actor 77.459106, loss_critic 52.157486, reawrd -1616.470929
# episode 203, loss_actor 78.268738, loss_critic 6.341524, reawrd -1596.949872
# episode 204, loss_actor 76.741531, loss_critic 113.379723, reawrd -1429.059798
# episode 205, loss_actor 77.399185, loss_critic 0.959738, reawrd -1587.934460
# episode 206, loss_actor 75.689896, loss_critic 1.846041, reawrd -1485.985337
# episode 207, loss_actor 72.432251, loss_critic 2.657011, reawrd -1494.652745
# episode 208, loss_actor 72.556053, loss_critic 42.330875, reawrd -1605.374804
# episode 209, loss_actor 74.378006, loss_critic 2.173912, reawrd -1484.670400
# episode 210, loss_actor 71.914436, loss_critic 108.026901, reawrd -1473.683854
# episode 211, loss_actor 73.458435, loss_critic 2.093290, reawrd -1639.831494
# episode 212, loss_actor 75.449493, loss_critic 106.549438, reawrd -1622.939227
# episode 213, loss_actor 66.074295, loss_critic 23.491249, reawrd -1442.464808
# episode 214, loss_actor 43.072910, loss_critic 4.808741, reawrd -1300.739059
# episode 215, loss_actor 54.366333, loss_critic 72.487274, reawrd -1479.798312
# episode 216, loss_actor 62.537254, loss_critic 1.836378, reawrd -1502.745682
# episode 217, loss_actor 69.351791, loss_critic 1.639266, reawrd -1441.642501
# episode 218, loss_actor 69.994476, loss_critic 41.554710, reawrd -1461.027531
# episode 219, loss_actor 71.132950, loss_critic 1.197472, reawrd -1453.433296
# episode 220, loss_actor 70.419022, loss_critic 46.039425, reawrd -1415.492714
# episode 221, loss_actor 68.940399, loss_critic 46.768917, reawrd -1383.360599
# episode 222, loss_actor 67.952301, loss_critic 0.598666, reawrd -1262.077096
# episode 223, loss_actor 64.410530, loss_critic 0.720013, reawrd -1088.168530
# episode 224, loss_actor 65.854561, loss_critic 28.092073, reawrd -1491.653238
# episode 225, loss_actor 66.364594, loss_critic 0.441748, reawrd -1383.471284
# episode 226, loss_actor 63.472149, loss_critic 46.224743, reawrd -1364.368309
# episode 227, loss_actor 64.691788, loss_critic 43.339252, reawrd -1362.105561
# episode 228, loss_actor 68.658096, loss_critic 26.856874, reawrd -1491.175452
# episode 229, loss_actor 66.401352, loss_critic 93.650726, reawrd -1306.301968
# episode 230, loss_actor 64.559219, loss_critic 38.022762, reawrd -1175.621135
# episode 231, loss_actor 61.792652, loss_critic 1.326986, reawrd -1025.360820
# episode 232, loss_actor 63.150467, loss_critic 0.751001, reawrd -1289.518009
# episode 233, loss_actor 58.131618, loss_critic 0.966108, reawrd -1184.465165
# episode 234, loss_actor 57.294376, loss_critic 0.703127, reawrd -1134.760026
# episode 235, loss_actor 58.738602, loss_critic 0.779122, reawrd -1152.647584
# episode 236, loss_actor 53.004219, loss_critic 39.225777, reawrd -1006.655954
# episode 237, loss_actor 54.768089, loss_critic 64.111839, reawrd -1294.448226
# episode 238, loss_actor 53.141090, loss_critic 1.221547, reawrd -1121.677001
# episode 239, loss_actor 54.999939, loss_critic 40.596004, reawrd -1353.063242
# episode 240, loss_actor 54.683815, loss_critic 32.791084, reawrd -1223.158821
# episode 241, loss_actor 58.021622, loss_critic 39.064182, reawrd -1363.900137
# episode 242, loss_actor 60.457634, loss_critic 0.980057, reawrd -1392.405013
# episode 243, loss_actor 60.802063, loss_critic 0.888277, reawrd -781.950850
# episode 244, loss_actor 56.938385, loss_critic 4.157047, reawrd -1060.599496
# episode 245, loss_actor 52.919174, loss_critic 2.476458, reawrd -949.129044
# episode 246, loss_actor 56.886726, loss_critic 77.561203, reawrd -1486.115085
# episode 247, loss_actor 50.521770, loss_critic 73.014069, reawrd -1373.275736
# episode 248, loss_actor 54.238914, loss_critic 40.177170, reawrd -1026.304054
# episode 249, loss_actor 57.258141, loss_critic 1.470186, reawrd -1500.447280
# episode 250, loss_actor 60.818848, loss_critic 1.523811, reawrd -1173.208938
# episode 251, loss_actor 58.864967, loss_critic 40.634472, reawrd -1135.949149
# episode 252, loss_actor 57.495190, loss_critic 22.123390, reawrd -1193.876579
# episode 253, loss_actor 58.071430, loss_critic 1.125240, reawrd -1094.883941
# episode 254, loss_actor 53.900063, loss_critic 45.360397, reawrd -1067.316304
# episode 255, loss_actor 52.247349, loss_critic 37.713436, reawrd -918.957929
# episode 256, loss_actor 53.461334, loss_critic 1.157080, reawrd -1347.956441
# episode 257, loss_actor 56.670174, loss_critic 1.148197, reawrd -1403.899956
# episode 258, loss_actor 52.188969, loss_critic 34.221909, reawrd -826.538489
# episode 259, loss_actor 56.994686, loss_critic 39.241333, reawrd -1490.341371
# episode 260, loss_actor 55.708015, loss_critic 18.293716, reawrd -1082.440338
# episode 261, loss_actor 54.715946, loss_critic 38.228256, reawrd -1227.806318
# episode 262, loss_actor 51.015274, loss_critic 3.100753, reawrd -1215.135781
# episode 263, loss_actor 59.762993, loss_critic 6.387155, reawrd -1417.716550
# episode 264, loss_actor 58.768372, loss_critic 35.067551, reawrd -1541.792331
# episode 265, loss_actor 63.888306, loss_critic 42.472752, reawrd -1475.439453
# episode 266, loss_actor 70.088692, loss_critic 4.757670, reawrd -1501.635884
# episode 267, loss_actor 69.656540, loss_critic 44.076370, reawrd -1496.640994
# episode 268, loss_actor 71.079475, loss_critic 103.023041, reawrd -1492.901608
# episode 269, loss_actor 70.903015, loss_critic 37.486614, reawrd -1484.645774
# episode 270, loss_actor 70.420799, loss_critic 37.478802, reawrd -1397.470908
# episode 271, loss_actor 70.374603, loss_critic 37.840164, reawrd -1431.894755
# episode 272, loss_actor 67.395630, loss_critic 1.058030, reawrd -1318.928714
# episode 273, loss_actor 67.302002, loss_critic 2.183012, reawrd -1442.869836
# episode 274, loss_actor 66.838669, loss_critic 91.209534, reawrd -1581.543516
# episode 275, loss_actor 66.147667, loss_critic 82.552399, reawrd -1326.676653
# episode 276, loss_actor 65.709320, loss_critic 2.570897, reawrd -1471.143597
# episode 277, loss_actor 67.698196, loss_critic 31.679724, reawrd -1465.091785
# episode 278, loss_actor 70.270622, loss_critic 2.055481, reawrd -1594.559271
# episode 279, loss_actor 68.872787, loss_critic 65.190376, reawrd -1502.315118
# episode 280, loss_actor 67.889694, loss_critic 4.052632, reawrd -1479.785650
# episode 281, loss_actor 63.804668, loss_critic 0.582110, reawrd -1499.135645
# episode 282, loss_actor 67.844421, loss_critic 0.472257, reawrd -1499.954239
# episode 283, loss_actor 72.094894, loss_critic 33.161503, reawrd -1507.197820
# episode 284, loss_actor 71.647545, loss_critic 0.171326, reawrd -1520.694331
# episode 285, loss_actor 71.196083, loss_critic 0.212138, reawrd -1494.795813
# episode 286, loss_actor 71.023590, loss_critic 118.578720, reawrd -1362.856063
# episode 287, loss_actor 69.659691, loss_critic 0.919183, reawrd -1486.186755
# episode 288, loss_actor 70.040977, loss_critic 0.587042, reawrd -1462.267236
# episode 289, loss_actor 67.827652, loss_critic 45.890076, reawrd -1458.659794
# episode 290, loss_actor 68.987259, loss_critic 72.266426, reawrd -1488.799863
# episode 291, loss_actor 70.635559, loss_critic 36.561916, reawrd -1489.033252
# episode 292, loss_actor 69.792023, loss_critic 0.189882, reawrd -1506.743342
# episode 293, loss_actor 70.733704, loss_critic 0.509974, reawrd -1463.304319
# episode 294, loss_actor 69.601410, loss_critic 98.154655, reawrd -1469.705924
# episode 295, loss_actor 71.198586, loss_critic 0.607385, reawrd -1303.752523
# episode 296, loss_actor 58.076752, loss_critic 5.443007, reawrd -4.856321
# episode 297, loss_actor 53.685787, loss_critic 26.450352, reawrd -1314.799644
# episode 298, loss_actor 48.537651, loss_critic 2.389764, reawrd -1153.153606
# episode 299, loss_actor 43.785233, loss_critic 2.517288, reawrd -1397.679147
# episode 300, loss_actor 46.061325, loss_critic 4.579247, reawrd -1414.790044
# episode 301, loss_actor 59.141689, loss_critic 4.521009, reawrd -1487.473584
# episode 302, loss_actor 59.943802, loss_critic 72.198135, reawrd -1448.768790
# episode 303, loss_actor 63.581905, loss_critic 18.297827, reawrd -1484.925976
# episode 304, loss_actor 66.421249, loss_critic 3.985463, reawrd -1487.369218
# episode 305, loss_actor 67.721603, loss_critic 2.742334, reawrd -1311.057931
# episode 306, loss_actor 59.431808, loss_critic 132.750305, reawrd -1403.386097
# episode 307, loss_actor 60.082397, loss_critic 3.104142, reawrd -1506.358381
# episode 308, loss_actor 57.901154, loss_critic 41.457657, reawrd -1532.249674
# episode 309, loss_actor 59.577065, loss_critic 22.143673, reawrd -1473.311745
# episode 310, loss_actor 66.751602, loss_critic 43.252728, reawrd -1455.589936
# episode 311, loss_actor 70.100029, loss_critic 1.248069, reawrd -1466.847361
# episode 312, loss_actor 60.697956, loss_critic 30.599087, reawrd -285.142826
# episode 313, loss_actor 57.027634, loss_critic 45.350624, reawrd -1491.456653
# episode 314, loss_actor 59.677635, loss_critic 67.593124, reawrd -1324.760077
# episode 315, loss_actor 58.375290, loss_critic 1.103803, reawrd -1484.165303
# episode 316, loss_actor 53.855904, loss_critic 31.071585, reawrd -1079.312339
# episode 317, loss_actor 60.967850, loss_critic 2.090909, reawrd -1066.689451
# episode 318, loss_actor 57.693726, loss_critic 41.278549, reawrd -1353.289977
# episode 319, loss_actor 55.579346, loss_critic 2.349266, reawrd -1474.744276
# episode 320, loss_actor 56.705376, loss_critic 36.330788, reawrd -1485.949326
# episode 321, loss_actor 59.739655, loss_critic 41.398529, reawrd -1248.325436
# episode 322, loss_actor 62.603275, loss_critic 42.311218, reawrd -1608.617788
# episode 323, loss_actor 67.986160, loss_critic 4.890492, reawrd -1572.509315
# episode 324, loss_actor 67.589279, loss_critic 1.847238, reawrd -1270.958928
# episode 325, loss_actor 67.555756, loss_critic 50.875675, reawrd -1574.789600
# episode 326, loss_actor 69.014648, loss_critic 39.518597, reawrd -1583.577513
# episode 327, loss_actor 69.302048, loss_critic 110.539124, reawrd -1444.770774
# episode 328, loss_actor 68.536804, loss_critic 37.016846, reawrd -1355.064477
# episode 329, loss_actor 74.978767, loss_critic 3.817395, reawrd -1244.914416
# episode 330, loss_actor 67.883987, loss_critic 16.844915, reawrd -1342.791881
# episode 331, loss_actor 64.942734, loss_critic 52.259357, reawrd -1431.047831
# episode 332, loss_actor 66.168503, loss_critic 30.065233, reawrd -1422.479488
# episode 333, loss_actor 68.448853, loss_critic 30.361717, reawrd -1611.416134
# episode 334, loss_actor 69.313416, loss_critic 95.414894, reawrd -1206.629199
# episode 335, loss_actor 72.406967, loss_critic 1.069787, reawrd -1587.842898
# episode 336, loss_actor 71.486488, loss_critic 12.195770, reawrd -1580.756333
# episode 337, loss_actor 70.301414, loss_critic 123.515762, reawrd -1448.244541
# episode 338, loss_actor 67.877426, loss_critic 44.179588, reawrd -1431.418790
# episode 339, loss_actor 73.032394, loss_critic 62.437603, reawrd -1265.183697
# episode 340, loss_actor 71.159058, loss_critic 3.993191, reawrd -1274.601362
# episode 341, loss_actor 67.264633, loss_critic 61.732548, reawrd -1582.466736
# episode 342, loss_actor 67.426697, loss_critic 136.022644, reawrd -1589.350668
# episode 343, loss_actor 71.160034, loss_critic 45.323429, reawrd -1594.772665
# episode 344, loss_actor 70.477905, loss_critic 40.296825, reawrd -1488.605842
# episode 345, loss_actor 74.795662, loss_critic 43.844860, reawrd -1483.838355
# episode 346, loss_actor 75.481125, loss_critic 0.638750, reawrd -1616.921076
# episode 347, loss_actor 75.700447, loss_critic 42.316975, reawrd -1514.576288
# episode 348, loss_actor 71.855492, loss_critic 0.605237, reawrd -1364.338948
# episode 349, loss_actor 73.673645, loss_critic 0.650172, reawrd -1592.618985
# episode 350, loss_actor 72.114738, loss_critic 70.065369, reawrd -1448.406568
# episode 351, loss_actor 71.666191, loss_critic 56.007801, reawrd -1348.098803
# episode 352, loss_actor 68.850594, loss_critic 0.610648, reawrd -1452.436171
# episode 353, loss_actor 69.882904, loss_critic 53.093132, reawrd -1631.400638
# episode 354, loss_actor 73.877441, loss_critic 54.528347, reawrd -1612.193546
# episode 355, loss_actor 74.015274, loss_critic 67.018143, reawrd -1608.599761
# episode 356, loss_actor 72.373596, loss_critic 66.289940, reawrd -1413.816760
# episode 357, loss_actor 73.817780, loss_critic 84.600777, reawrd -1352.808647
# episode 358, loss_actor 73.442017, loss_critic 1.871145, reawrd -1468.434566
# episode 359, loss_actor 68.349419, loss_critic 5.085372, reawrd -1482.637597
# episode 360, loss_actor 62.506557, loss_critic 1.024644, reawrd -927.338734
# episode 361, loss_actor 60.568291, loss_critic 2.096064, reawrd -1290.747096
# episode 362, loss_actor 62.909470, loss_critic 68.323906, reawrd -1491.219994
# episode 363, loss_actor 60.404140, loss_critic 62.276760, reawrd -1289.096701
# episode 364, loss_actor 61.456352, loss_critic 1.381451, reawrd -1275.072660
# episode 365, loss_actor 58.557178, loss_critic 4.393649, reawrd -806.446248
# episode 366, loss_actor 61.818443, loss_critic 1.321986, reawrd -1494.756547
# episode 367, loss_actor 57.265991, loss_critic 1.197112, reawrd -1019.452322
# episode 368, loss_actor 57.965134, loss_critic 83.180412, reawrd -1209.929448
# episode 369, loss_actor 54.391464, loss_critic 1.371669, reawrd -1395.757688
# episode 370, loss_actor 58.846615, loss_critic 24.044525, reawrd -1431.634554
# episode 371, loss_actor 60.279472, loss_critic 2.376274, reawrd -1206.030201
# episode 372, loss_actor 59.834808, loss_critic 3.403510, reawrd -1195.239326
# episode 373, loss_actor 61.710979, loss_critic 18.300827, reawrd -1433.168588
# episode 374, loss_actor 63.571533, loss_critic 34.376671, reawrd -1562.461030
# episode 375, loss_actor 66.432220, loss_critic 7.497110, reawrd -1541.785618
# episode 376, loss_actor 67.427155, loss_critic 11.831121, reawrd -1403.507372
# episode 377, loss_actor 70.631813, loss_critic 11.761890, reawrd -1528.640307
# episode 378, loss_actor 69.358841, loss_critic 3.340755, reawrd -1521.292688
# episode 379, loss_actor 71.173698, loss_critic 58.151371, reawrd -1425.070395
# episode 380, loss_actor 72.361603, loss_critic 1.335327, reawrd -1537.563975
# episode 381, loss_actor 69.556412, loss_critic 83.466591, reawrd -1469.427767
# episode 382, loss_actor 72.104111, loss_critic 56.522381, reawrd -1430.657581
# episode 383, loss_actor 71.295547, loss_critic 10.364723, reawrd -1391.368992
# episode 384, loss_actor 68.186684, loss_critic 2.094221, reawrd -1284.329068
# episode 385, loss_actor 69.738060, loss_critic 75.593361, reawrd -1420.845356
# episode 386, loss_actor 67.338623, loss_critic 144.045410, reawrd -1427.805392
# episode 387, loss_actor 64.070389, loss_critic 57.505459, reawrd -1362.653614
# episode 388, loss_actor 66.157333, loss_critic 33.146477, reawrd -1490.899060
# episode 389, loss_actor 69.703262, loss_critic 28.607397, reawrd -1466.745659
# episode 390, loss_actor 69.963402, loss_critic 2.841638, reawrd -1485.454595
# episode 391, loss_actor 70.439766, loss_critic 2.427101, reawrd -1436.102030
# episode 392, loss_actor 71.074638, loss_critic 2.279333, reawrd -1375.913738
# episode 393, loss_actor 68.649086, loss_critic 2.004479, reawrd -1378.358455
# episode 394, loss_actor 69.038620, loss_critic 32.571358, reawrd -1416.841271
# episode 395, loss_actor 68.099426, loss_critic 2.001523, reawrd -1492.173500
# episode 396, loss_actor 70.254807, loss_critic 33.204571, reawrd -1591.706197
# episode 397, loss_actor 62.412666, loss_critic 190.383728, reawrd -1558.241638
# episode 398, loss_actor 76.025436, loss_critic 7.240348, reawrd -1476.242588
# episode 399, loss_actor 70.118698, loss_critic 69.147949, reawrd -1506.878835
# episode 400, loss_actor 72.515396, loss_critic 9.590162, reawrd -1642.215529
# episode 401, loss_actor 69.607117, loss_critic 52.287514, reawrd -1600.944273
# episode 402, loss_actor 69.464584, loss_critic 1.445283, reawrd -1129.564900
# episode 403, loss_actor 63.464119, loss_critic 33.132187, reawrd -1214.485269
# episode 404, loss_actor 57.572556, loss_critic 35.168545, reawrd -671.090223
# episode 405, loss_actor 57.491539, loss_critic 3.293196, reawrd -924.370303
# episode 406, loss_actor 51.039906, loss_critic 3.735323, reawrd -1240.295975
# episode 407, loss_actor 55.687473, loss_critic 3.545764, reawrd -1450.160351
# episode 408, loss_actor 52.406231, loss_critic 17.226028, reawrd -1226.137597
# episode 409, loss_actor 53.055805, loss_critic 32.114601, reawrd -976.883354
# episode 410, loss_actor 59.179985, loss_critic 36.299488, reawrd -1531.951395
# episode 411, loss_actor 59.096153, loss_critic 29.771605, reawrd -1288.503196
# episode 412, loss_actor 55.246716, loss_critic 54.916492, reawrd -1508.806236
# episode 413, loss_actor 59.547707, loss_critic 28.755283, reawrd -1334.665131
# episode 414, loss_actor 67.375641, loss_critic 35.900303, reawrd -1446.878557
# episode 415, loss_actor 63.798927, loss_critic 1.375077, reawrd -1313.984928
# episode 416, loss_actor 60.831436, loss_critic 59.514828, reawrd -1257.259328
# episode 417, loss_actor 62.224148, loss_critic 35.246792, reawrd -1276.414810
# episode 418, loss_actor 48.416275, loss_critic 1.441685, reawrd -2.436529
# episode 419, loss_actor 49.700363, loss_critic 1.774754, reawrd -1491.965771
# episode 420, loss_actor 48.840462, loss_critic 2.427913, reawrd -1406.121347
# episode 421, loss_actor 52.794464, loss_critic 2.016153, reawrd -1496.367472
# episode 422, loss_actor 54.005348, loss_critic 3.409192, reawrd -1545.746155
# episode 423, loss_actor 64.464935, loss_critic 35.622307, reawrd -1592.738452
# episode 424, loss_actor 66.111755, loss_critic 95.403000, reawrd -1519.433394
# episode 425, loss_actor 71.013390, loss_critic 2.054679, reawrd -1589.062739
# episode 426, loss_actor 68.119797, loss_critic 97.043472, reawrd -1021.268433
# episode 427, loss_actor 62.091080, loss_critic 1.339192, reawrd -790.629563
# episode 428, loss_actor 58.244598, loss_critic 55.766361, reawrd -1253.326107
# episode 429, loss_actor 57.369148, loss_critic 38.124859, reawrd -1440.861329
# episode 430, loss_actor 55.344330, loss_critic 2.085853, reawrd -1381.283724
# episode 431, loss_actor 61.476135, loss_critic 1.222697, reawrd -1587.975081
# episode 432, loss_actor 64.994186, loss_critic 14.138955, reawrd -1202.628708
# episode 433, loss_actor 65.927795, loss_critic 48.125481, reawrd -1226.016747
# episode 434, loss_actor 61.691795, loss_critic 20.207706, reawrd -1080.609423
# episode 435, loss_actor 61.332947, loss_critic 39.188438, reawrd -1084.917981
# episode 436, loss_actor 58.796570, loss_critic 114.806404, reawrd -1593.112972
# episode 437, loss_actor 67.201218, loss_critic 38.997223, reawrd -1635.353035
# episode 438, loss_actor 64.292847, loss_critic 6.596921, reawrd -1596.432256
# episode 439, loss_actor 70.022964, loss_critic 1.940451, reawrd -1494.581709
# episode 440, loss_actor 78.001213, loss_critic 73.010559, reawrd -1572.378574
# episode 441, loss_actor 64.989296, loss_critic 70.534531, reawrd -1232.702749
# episode 442, loss_actor 68.847382, loss_critic 1.961388, reawrd -1635.358108
# episode 443, loss_actor 69.234467, loss_critic 1.752929, reawrd -1557.108557
# episode 444, loss_actor 70.355362, loss_critic 70.720329, reawrd -1641.376775
# episode 445, loss_actor 67.698761, loss_critic 75.498428, reawrd -1493.088457
# episode 446, loss_actor 74.417152, loss_critic 2.624018, reawrd -1482.136239
# episode 447, loss_actor 72.841110, loss_critic 96.858070, reawrd -1520.760717
# episode 448, loss_actor 71.208862, loss_critic 60.830673, reawrd -1463.830621
# episode 449, loss_actor 72.928391, loss_critic 1.404891, reawrd -1571.237050
# episode 450, loss_actor 73.866219, loss_critic 68.893661, reawrd -1616.841728
# episode 451, loss_actor 76.661751, loss_critic 4.873408, reawrd -1507.457193
# episode 452, loss_actor 74.502792, loss_critic 127.757828, reawrd -1431.973482
# episode 453, loss_actor 74.335564, loss_critic 5.949294, reawrd -1339.961743
# episode 454, loss_actor 67.824944, loss_critic 45.557774, reawrd -1140.177471
# episode 455, loss_actor 62.763947, loss_critic 1.005250, reawrd -1054.555167
# episode 456, loss_actor 57.355289, loss_critic 44.188263, reawrd -1049.280620
# episode 457, loss_actor 60.112865, loss_critic 105.196671, reawrd -1639.083488
# episode 458, loss_actor 62.364124, loss_critic 28.957462, reawrd -1635.672361
# episode 459, loss_actor 65.157707, loss_critic 1.596424, reawrd -1638.571261
# episode 460, loss_actor 64.692307, loss_critic 25.955063, reawrd -1027.929220
# episode 461, loss_actor 70.951828, loss_critic 61.536728, reawrd -1606.550024
# episode 462, loss_actor 71.582695, loss_critic 125.390732, reawrd -1573.703689
# episode 463, loss_actor 71.233246, loss_critic 64.550476, reawrd -1603.229704
# episode 464, loss_actor 72.934814, loss_critic 68.438881, reawrd -1647.857843
# episode 465, loss_actor 76.401962, loss_critic 10.569047, reawrd -1477.059800
# episode 466, loss_actor 72.503654, loss_critic 76.415718, reawrd -1541.592459
# episode 467, loss_actor 75.703529, loss_critic 1.196407, reawrd -1645.900633
# episode 468, loss_actor 79.109848, loss_critic 6.563743, reawrd -1622.236019
# episode 469, loss_actor 79.434464, loss_critic 10.475826, reawrd -1557.372129
# episode 470, loss_actor 75.533218, loss_critic 172.194855, reawrd -1565.707147
# episode 471, loss_actor 75.124138, loss_critic 124.367722, reawrd -1610.503849
# episode 472, loss_actor 77.274200, loss_critic 72.123833, reawrd -1584.647351
# episode 473, loss_actor 75.263290, loss_critic 1.099304, reawrd -1404.810811
# episode 474, loss_actor 74.942177, loss_critic 52.918510, reawrd -1573.400187
# episode 475, loss_actor 72.635315, loss_critic 58.382839, reawrd -1418.608499
# episode 476, loss_actor 71.104942, loss_critic 5.644064, reawrd -1223.493686
# episode 477, loss_actor 66.821907, loss_critic 3.530451, reawrd -1236.220656
# episode 478, loss_actor 67.511818, loss_critic 1.766646, reawrd -1419.459591
# episode 479, loss_actor 63.017784, loss_critic 83.307953, reawrd -1273.629004
# episode 480, loss_actor 63.315853, loss_critic 47.005310, reawrd -1394.520333
# episode 481, loss_actor 60.475044, loss_critic 83.614517, reawrd -1129.212965
# episode 482, loss_actor 56.006409, loss_critic 50.953041, reawrd -1396.419921
# episode 483, loss_actor 61.056252, loss_critic 47.662498, reawrd -1578.509279
# episode 484, loss_actor 59.557327, loss_critic 5.166875, reawrd -1216.472360
# episode 485, loss_actor 61.434021, loss_critic 1.849571, reawrd -1140.272048
# episode 486, loss_actor 56.533543, loss_critic 56.163048, reawrd -1101.328472
# episode 487, loss_actor 55.880993, loss_critic 2.407083, reawrd -917.463921
# episode 488, loss_actor 51.702656, loss_critic 2.107265, reawrd -779.685572
# episode 489, loss_actor 42.716217, loss_critic 7.321021, reawrd -782.941325
# episode 490, loss_actor 43.201527, loss_critic 5.897454, reawrd -782.091402
# episode 491, loss_actor 39.944702, loss_critic 2.996325, reawrd -1048.631291
# episode 492, loss_actor 37.083218, loss_critic 5.314322, reawrd -1183.484182
# episode 493, loss_actor 40.866161, loss_critic 7.261789, reawrd -1161.906882
# episode 494, loss_actor 46.763557, loss_critic 14.287375, reawrd -1115.025431
# episode 495, loss_actor 45.643013, loss_critic 30.298069, reawrd -1148.092066
# episode 496, loss_actor 49.877121, loss_critic 1.388200, reawrd -1050.155749
# episode 497, loss_actor 49.819355, loss_critic 11.308898, reawrd -1038.405401
# episode 498, loss_actor 50.636253, loss_critic 7.084112, reawrd -910.595672
# episode 499, loss_actor 46.184910, loss_critic 26.151960, reawrd -896.689017
# episode 500, loss_actor 42.090458, loss_critic 0.889839, reawrd -779.482994
# episode 501, loss_actor 44.190701, loss_critic 0.957889, reawrd -1078.292279
# episode 502, loss_actor 44.630180, loss_critic 1.073218, reawrd -1075.230266
# episode 503, loss_actor 44.986694, loss_critic 17.493214, reawrd -1079.644771
# episode 504, loss_actor 47.193283, loss_critic 50.091721, reawrd -1062.075670
# episode 505, loss_actor 52.254448, loss_critic 1.688021, reawrd -847.714159
# episode 506, loss_actor 45.390003, loss_critic 24.819187, reawrd -841.163257
# episode 507, loss_actor 50.543148, loss_critic 1.393393, reawrd -1491.412656
# episode 508, loss_actor 47.676464, loss_critic 22.568773, reawrd -649.739098
# episode 509, loss_actor 46.642895, loss_critic 1.103263, reawrd -1043.276271
# episode 510, loss_actor 47.922249, loss_critic 0.948585, reawrd -914.219196
# episode 511, loss_actor 46.573692, loss_critic 1.071256, reawrd -942.388337
# episode 512, loss_actor 42.301010, loss_critic 1.128614, reawrd -999.990543
# episode 513, loss_actor 44.639626, loss_critic 18.846972, reawrd -1113.648120
# episode 514, loss_actor 45.846031, loss_critic 0.793759, reawrd -997.155545
# episode 515, loss_actor 48.119484, loss_critic 33.041271, reawrd -906.799775
# episode 516, loss_actor 46.503143, loss_critic 16.965662, reawrd -1002.839671
# episode 517, loss_actor 45.374550, loss_critic 1.006751, reawrd -913.711485
# episode 518, loss_actor 43.711456, loss_critic 23.904091, reawrd -992.961919
# episode 519, loss_actor 46.365437, loss_critic 28.078390, reawrd -970.946968
# episode 520, loss_actor 43.653969, loss_critic 0.757743, reawrd -994.487892
# episode 521, loss_actor 43.328102, loss_critic 7.512471, reawrd -986.672520
# episode 522, loss_actor 42.061241, loss_critic 17.230375, reawrd -989.070564
# episode 523, loss_actor 44.135963, loss_critic 9.514241, reawrd -1001.300861
# episode 524, loss_actor 46.150421, loss_critic 0.594884, reawrd -902.379870
# episode 525, loss_actor 44.364876, loss_critic 36.345192, reawrd -782.707999
# episode 526, loss_actor 39.536591, loss_critic 0.805895, reawrd -890.563967
# episode 527, loss_actor 38.555084, loss_critic 1.840283, reawrd -1141.400932
# episode 528, loss_actor 39.644505, loss_critic 2.678661, reawrd -1406.721632
# episode 529, loss_actor 45.431774, loss_critic 36.224522, reawrd -1315.366571
# episode 530, loss_actor 55.708687, loss_critic 1.489504, reawrd -1731.573174
# episode 531, loss_actor 62.615517, loss_critic 48.809196, reawrd -1626.646983
# episode 532, loss_actor 68.085213, loss_critic 1.298746, reawrd -1384.584041
# episode 533, loss_actor 66.529343, loss_critic 1.061111, reawrd -1220.849856
# episode 534, loss_actor 65.324341, loss_critic 18.227495, reawrd -1560.050148
# episode 535, loss_actor 64.926926, loss_critic 66.202621, reawrd -1088.196988
# episode 536, loss_actor 63.656612, loss_critic 22.013769, reawrd -1672.178650
# episode 537, loss_actor 68.918564, loss_critic 77.572800, reawrd -1587.482013
# episode 538, loss_actor 67.158180, loss_critic 54.044861, reawrd -1332.351780
# episode 539, loss_actor 63.254616, loss_critic 1.960172, reawrd -984.466663
# episode 540, loss_actor 63.607346, loss_critic 3.190301, reawrd -1463.336819
# episode 541, loss_actor 61.264046, loss_critic 1.375173, reawrd -1125.127706
# episode 542, loss_actor 61.445953, loss_critic 1.094778, reawrd -1442.540373
# episode 543, loss_actor 62.207550, loss_critic 1.079876, reawrd -1499.195104
# episode 544, loss_actor 63.410080, loss_critic 41.936623, reawrd -1196.232850
# episode 545, loss_actor 65.050522, loss_critic 79.861046, reawrd -1590.093520
# episode 546, loss_actor 69.487228, loss_critic 43.892998, reawrd -1574.157795
# episode 547, loss_actor 69.219147, loss_critic 0.919552, reawrd -1495.762630
# episode 548, loss_actor 69.137314, loss_critic 66.264542, reawrd -1513.393755
# episode 549, loss_actor 71.575691, loss_critic 0.713318, reawrd -1370.183006
# episode 550, loss_actor 69.370148, loss_critic 3.173444, reawrd -1228.174982
# episode 551, loss_actor 65.181000, loss_critic 0.564683, reawrd -1185.243527
# episode 552, loss_actor 61.378708, loss_critic 0.685883, reawrd -1094.017001
# episode 553, loss_actor 62.300667, loss_critic 52.220524, reawrd -1537.921468
# episode 554, loss_actor 57.113544, loss_critic 6.939478, reawrd -768.977464
# episode 555, loss_actor 58.714912, loss_critic 1.002030, reawrd -1393.490449
# episode 556, loss_actor 56.281605, loss_critic 0.892387, reawrd -867.790433
# episode 557, loss_actor 60.008106, loss_critic 1.317433, reawrd -1483.324485
# episode 558, loss_actor 59.526085, loss_critic 1.013896, reawrd -1600.545169
# episode 559, loss_actor 60.975670, loss_critic 43.839771, reawrd -975.614521
# episode 560, loss_actor 55.806755, loss_critic 44.063965, reawrd -1152.754451
# episode 561, loss_actor 58.632889, loss_critic 18.424772, reawrd -1241.452286
# episode 562, loss_actor 54.872707, loss_critic 44.385624, reawrd -1464.871699
# episode 563, loss_actor 51.625744, loss_critic 44.174549, reawrd -1274.545771
# episode 564, loss_actor 53.523273, loss_critic 9.191092, reawrd -1223.347190
# episode 565, loss_actor 51.094650, loss_critic 1.918610, reawrd -1265.136167
# episode 566, loss_actor 50.718216, loss_critic 1.640447, reawrd -1101.548939
# episode 567, loss_actor 54.550682, loss_critic 18.230009, reawrd -1384.599704
# episode 568, loss_actor 56.135128, loss_critic 1.448156, reawrd -1079.430176
# episode 569, loss_actor 52.619225, loss_critic 16.369852, reawrd -1064.217306
# episode 570, loss_actor 54.177128, loss_critic 79.794952, reawrd -1103.400199
# episode 571, loss_actor 49.052071, loss_critic 2.115741, reawrd -818.763728
# episode 572, loss_actor 44.210411, loss_critic 1.577901, reawrd -656.547651
# episode 573, loss_actor 41.079376, loss_critic 12.125068, reawrd -789.517517
# episode 574, loss_actor 39.952911, loss_critic 2.907291, reawrd -1219.656091
# episode 575, loss_actor 41.525406, loss_critic 2.860427, reawrd -1419.152142
# episode 576, loss_actor 48.583843, loss_critic 3.477466, reawrd -1411.518428
# episode 577, loss_actor 53.494633, loss_critic 4.576340, reawrd -1441.520980
# episode 578, loss_actor 60.818424, loss_critic 40.724403, reawrd -1391.557267
# episode 579, loss_actor 61.606560, loss_critic 18.157784, reawrd -1254.871406
# episode 580, loss_actor 59.478561, loss_critic 3.216404, reawrd -648.397490
# episode 581, loss_actor 53.872559, loss_critic 3.674300, reawrd -945.510388
# episode 582, loss_actor 52.361336, loss_critic 10.519881, reawrd -1378.559087
# episode 583, loss_actor 52.490067, loss_critic 4.858720, reawrd -1577.509045
# episode 584, loss_actor 52.239815, loss_critic 3.614955, reawrd -1502.404223
# episode 585, loss_actor 59.087509, loss_critic 35.056259, reawrd -1358.650343
# episode 586, loss_actor 65.876617, loss_critic 3.548950, reawrd -1255.832799
# episode 587, loss_actor 63.242706, loss_critic 24.515089, reawrd -1203.081330
# episode 588, loss_actor 56.879662, loss_critic 86.375885, reawrd -931.004016
# episode 589, loss_actor 53.410366, loss_critic 2.709399, reawrd -1065.744894
# episode 590, loss_actor 49.068691, loss_critic 17.128777, reawrd -768.352380
# episode 591, loss_actor 44.100456, loss_critic 1.865563, reawrd -889.956961
# episode 592, loss_actor 37.312843, loss_critic 1.413847, reawrd -923.974055
# episode 593, loss_actor 37.907928, loss_critic 27.699451, reawrd -983.618202
# episode 594, loss_actor 42.617371, loss_critic 3.377942, reawrd -1231.702479
# episode 595, loss_actor 47.545071, loss_critic 30.057997, reawrd -1209.101438
# episode 596, loss_actor 48.971550, loss_critic 2.019213, reawrd -1055.959338
# episode 597, loss_actor 53.110031, loss_critic 1.692254, reawrd -1382.794900
# episode 598, loss_actor 55.203854, loss_critic 48.229656, reawrd -1372.069289
# episode 599, loss_actor 54.566704, loss_critic 22.321352, reawrd -799.927695
# episode 600, loss_actor 48.471375, loss_critic 19.837130, reawrd -728.515518
# episode 601, loss_actor 44.749603, loss_critic 15.724457, reawrd -884.299602
# episode 602, loss_actor 40.487659, loss_critic 9.997248, reawrd -768.787167
# episode 603, loss_actor 40.393150, loss_critic 0.732306, reawrd -771.149420
# episode 604, loss_actor 38.279495, loss_critic 8.634473, reawrd -917.828640
# episode 605, loss_actor 38.507195, loss_critic 1.402378, reawrd -1037.792491
# episode 606, loss_actor 39.120056, loss_critic 5.920624, reawrd -760.942147
# episode 607, loss_actor 43.879513, loss_critic 1.366970, reawrd -1604.088370
# episode 608, loss_actor 48.296257, loss_critic 1.436325, reawrd -992.581159
# episode 609, loss_actor 46.563057, loss_critic 19.285908, reawrd -985.192307
# episode 610, loss_actor 43.182732, loss_critic 1.218498, reawrd -765.976728
# episode 611, loss_actor 51.822693, loss_critic 0.723840, reawrd -1489.260005
# episode 612, loss_actor 43.674324, loss_critic 0.476469, reawrd -554.753044
# episode 613, loss_actor 48.523712, loss_critic 45.066669, reawrd -1391.445923
# episode 614, loss_actor 44.075829, loss_critic 23.433807, reawrd -795.378870
# ...
# episode 1292, loss_actor 44.486687, loss_critic 0.647732, reawrd -1219.298725
# episode 1293, loss_actor 37.980110, loss_critic 0.456151, reawrd -508.424742
# episode 1294, loss_actor 34.918655, loss_critic 0.400348, reawrd -501.655374
# episode 1295, loss_actor 31.627232, loss_critic 0.449231, reawrd -499.479709
# episode 1296, loss_actor 27.543596, loss_critic 0.307509, reawrd -385.511260
# episode 1297, loss_actor 19.249914, loss_critic 2.997959, reawrd -376.953332
# episode 1298, loss_actor 16.787344, loss_critic 0.249095, reawrd -354.364512
# episode 1299, loss_actor 11.924365, loss_critic 0.199030, reawrd -8.805883
# episode 1300, loss_actor 15.508754, loss_critic 0.161582, reawrd -622.755417
# episode 1301, loss_actor 13.512642, loss_critic 0.565222, reawrd -136.133044
# episode 1302, loss_actor 11.865128, loss_critic 0.102334, reawrd -255.968633
# episode 1303, loss_actor 13.014973, loss_critic 0.200662, reawrd -249.769915
# episode 1304, loss_actor 12.990742, loss_critic 0.164149, reawrd -254.480317
# episode 1305, loss_actor 12.248329, loss_critic 0.168464, reawrd -728.357793
# episode 1306, loss_actor 21.554991, loss_critic 0.225723, reawrd -855.671525
# episode 1307, loss_actor 13.292271, loss_critic 0.157351, reawrd -138.278744
# episode 1308, loss_actor 15.407846, loss_critic 0.188945, reawrd -132.420056
# episode 1309, loss_actor 15.075504, loss_critic 0.149862, reawrd -5.913043
# episode 1310, loss_actor 11.511110, loss_critic 0.139344, reawrd -252.020655
# episode 1311, loss_actor 2.274899, loss_critic 0.040248, reawrd -4.012880
# episode 1312, loss_actor 7.516461, loss_critic 0.091406, reawrd -372.449356
# episode 1313, loss_actor 6.360709, loss_critic 0.059828, reawrd -246.215377
# episode 1314, loss_actor 8.867299, loss_critic 0.078163, reawrd -378.882614
# episode 1315, loss_actor 26.623371, loss_critic 0.092739, reawrd -1751.853933
# episode 1316, loss_actor 36.167061, loss_critic 0.195083, reawrd -1520.520770
# episode 1317, loss_actor 35.751099, loss_critic 0.290347, reawrd -135.045915
# episode 1318, loss_actor 47.959042, loss_critic 0.377815, reawrd -1737.379867
# episode 1319, loss_actor 54.628883, loss_critic 28.946848, reawrd -383.069624
# episode 1320, loss_actor 54.472191, loss_critic 55.384537, reawrd -1713.981686
# episode 1321, loss_actor 41.971024, loss_critic 55.005348, reawrd -134.907682
# episode 1322, loss_actor 36.860069, loss_critic 0.230599, reawrd -125.537501
# episode 1323, loss_actor 36.498993, loss_critic 0.444467, reawrd -1291.337597
# episode 1324, loss_actor 41.130177, loss_critic 0.462369, reawrd -1194.723187
# episode 1325, loss_actor 25.917032, loss_critic 52.282883, reawrd -3.493737
# episode 1326, loss_actor 33.316387, loss_critic 30.511127, reawrd -1202.866552
# episode 1327, loss_actor 44.193146, loss_critic 16.149086, reawrd -1282.376254
# episode 1328, loss_actor 35.083382, loss_critic 0.708627, reawrd -11.049546
# episode 1329, loss_actor 37.117256, loss_critic 14.299695, reawrd -981.016286
# episode 1330, loss_actor 47.489758, loss_critic 13.441600, reawrd -1772.283117
# episode 1331, loss_actor 47.094360, loss_critic 0.683551, reawrd -757.994202
# episode 1332, loss_actor 51.891640, loss_critic 0.450754, reawrd -1772.783997
# episode 1333, loss_actor 63.653225, loss_critic 0.290633, reawrd -1789.048618
# episode 1334, loss_actor 55.762417, loss_critic 0.280559, reawrd -125.833902
# episode 1335, loss_actor 47.761948, loss_critic 56.302830, reawrd -251.751082
# episode 1336, loss_actor 46.903465, loss_critic 0.293403, reawrd -1008.883123
# episode 1337, loss_actor 31.660252, loss_critic 0.223409, reawrd -495.597680
# episode 1338, loss_actor 33.738705, loss_critic 0.462127, reawrd -1276.667576
# episode 1339, loss_actor 33.417236, loss_critic 0.363807, reawrd -850.546945
# episode 1340, loss_actor 39.404633, loss_critic 0.397506, reawrd -970.109440
# episode 1341, loss_actor 37.384113, loss_critic 0.413611, reawrd -9.319506
# episode 1342, loss_actor 31.967247, loss_critic 0.276190, reawrd -496.599286
# episode 1343, loss_actor 21.898026, loss_critic 0.234069, reawrd -6.888218
# episode 1344, loss_actor 18.980175, loss_critic 0.330686, reawrd -552.697645
# episode 1345, loss_actor 13.763659, loss_critic 0.345395, reawrd -523.396529
# episode 1346, loss_actor 17.908794, loss_critic 0.587518, reawrd -766.789832
# episode 1347, loss_actor 26.779562, loss_critic 7.567207, reawrd -1176.149406
# episode 1348, loss_actor 37.583206, loss_critic 5.906229, reawrd -1262.074839
# episode 1349, loss_actor 39.200474, loss_critic 50.745560, reawrd -1191.139420
# episode 1350, loss_actor 45.197548, loss_critic 6.066024, reawrd -724.532317
# episode 1351, loss_actor 47.080742, loss_critic 7.888692, reawrd -742.333239
# episode 1352, loss_actor 35.689873, loss_critic 1.664929, reawrd -133.501316
# episode 1353, loss_actor 30.645908, loss_critic 1.677437, reawrd -959.878056
# episode 1354, loss_actor 34.258972, loss_critic 26.416430, reawrd -1019.413456
# episode 1355, loss_actor 35.086487, loss_critic 27.247246, reawrd -1122.220617
# episode 1356, loss_actor 35.008408, loss_critic 1.172871, reawrd -1205.101288
# episode 1357, loss_actor 46.322990, loss_critic 29.082470, reawrd -978.144470
# episode 1358, loss_actor 37.048347, loss_critic 3.638887, reawrd -133.346107
# episode 1359, loss_actor 39.224136, loss_critic 1.829478, reawrd -382.054398
# episode 1360, loss_actor 32.177921, loss_critic 34.092346, reawrd -834.984178
# episode 1361, loss_actor 21.343693, loss_critic 1.186265, reawrd -254.484787
# episode 1362, loss_actor 29.837017, loss_critic 0.605981, reawrd -1759.595414
# episode 1363, loss_actor 33.226337, loss_critic 63.659794, reawrd -382.598321
# episode 1364, loss_actor 28.899357, loss_critic 0.199868, reawrd -133.880062
# episode 1365, loss_actor 25.236988, loss_critic 0.241581, reawrd -493.298319
# episode 1366, loss_actor 23.622311, loss_critic 0.226837, reawrd -126.664073
# episode 1367, loss_actor 17.711243, loss_critic 51.051056, reawrd -611.211127
# episode 1368, loss_actor 11.857583, loss_critic 0.101449, reawrd -278.152411
# episode 1369, loss_actor 18.420921, loss_critic 0.229050, reawrd -646.308475
# episode 1370, loss_actor 29.268576, loss_critic 0.232533, reawrd -1800.663737
# episode 1371, loss_actor 33.165833, loss_critic 0.827399, reawrd -646.083890
# episode 1372, loss_actor 37.060432, loss_critic 0.319430, reawrd -726.233138
# episode 1373, loss_actor 40.233055, loss_critic 0.691608, reawrd -917.691446
# episode 1374, loss_actor 45.972710, loss_critic 0.478141, reawrd -738.196898
# episode 1375, loss_actor 36.951729, loss_critic 16.867495, reawrd -1013.834762
# episode 1376, loss_actor 39.589817, loss_critic 1.890288, reawrd -996.098871
# episode 1377, loss_actor 41.137264, loss_critic 10.498540, reawrd -1093.632344
# episode 1378, loss_actor 41.273674, loss_critic 2.747439, reawrd -553.879428
# episode 1379, loss_actor 36.865318, loss_critic 25.678669, reawrd -374.762497
# episode 1380, loss_actor 28.029102, loss_critic 8.475583, reawrd -385.180837
# episode 1381, loss_actor 21.360565, loss_critic 0.377621, reawrd -133.803243
# episode 1382, loss_actor 16.941986, loss_critic 0.849673, reawrd -501.474042
# episode 1383, loss_actor 13.814235, loss_critic 0.487054, reawrd -248.502308
# episode 1384, loss_actor 15.113523, loss_critic 0.273792, reawrd -122.027412
# episode 1385, loss_actor 13.588037, loss_critic 0.156022, reawrd -648.824255
# episode 1386, loss_actor 21.823336, loss_critic 0.460358, reawrd -1172.290047
# episode 1387, loss_actor 23.270113, loss_critic 0.618295, reawrd -624.709583
# episode 1388, loss_actor 26.582090, loss_critic 0.542254, reawrd -642.399817
# episode 1389, loss_actor 31.504702, loss_critic 0.475893, reawrd -521.550958
# episode 1390, loss_actor 22.900867, loss_critic 0.221796, reawrd -3.959202
# episode 1391, loss_actor 18.181534, loss_critic 0.747504, reawrd -249.966706
# episode 1392, loss_actor 11.039551, loss_critic 0.116638, reawrd -126.147941
# episode 1393, loss_actor 11.149529, loss_critic 0.184090, reawrd -588.948632
# episode 1394, loss_actor 7.128402, loss_critic 0.119508, reawrd -131.277782
# episode 1395, loss_actor 10.182957, loss_critic 0.107701, reawrd -259.848617
# episode 1396, loss_actor 12.556269, loss_critic 0.161527, reawrd -636.538843
# episode 1397, loss_actor 14.642564, loss_critic 0.212977, reawrd -253.429957
# episode 1398, loss_actor 16.672152, loss_critic 0.248407, reawrd -259.024969
# episode 1399, loss_actor 13.629972, loss_critic 0.194200, reawrd -128.759481
# episode 1400, loss_actor 10.970479, loss_critic 0.141577, reawrd -253.928388
# episode 1401, loss_actor 8.054431, loss_critic 0.132200, reawrd -378.480659
# episode 1402, loss_actor 5.989639, loss_critic 0.114509, reawrd -248.245114
# episode 1403, loss_actor 8.621109, loss_critic 0.086230, reawrd -122.978954
# episode 1404, loss_actor 12.018119, loss_critic 0.113272, reawrd -122.572663
# episode 1405, loss_actor 7.579027, loss_critic 0.065464, reawrd -120.505395
# episode 1406, loss_actor 4.960745, loss_critic 0.025272, reawrd -126.548013
# episode 1407, loss_actor 1.546193, loss_critic 0.011407, reawrd -2.242002
# episode 1408, loss_actor 3.572548, loss_critic 0.046223, reawrd -377.349677
# episode 1409, loss_actor 10.116924, loss_critic 0.084153, reawrd -501.540673
# episode 1410, loss_actor 9.463370, loss_critic 0.131453, reawrd -245.319183
# episode 1411, loss_actor 8.466072, loss_critic 0.050182, reawrd -370.256176
# episode 1412, loss_actor 15.989483, loss_critic 0.161803, reawrd -499.263179
# episode 1413, loss_actor 13.520720, loss_critic 0.153244, reawrd -374.521442
# episode 1414, loss_actor 12.537555, loss_critic 0.118187, reawrd -368.037049
# episode 1415, loss_actor 10.775507, loss_critic 0.081446, reawrd -257.569571
# episode 1416, loss_actor 15.361858, loss_critic 0.113362, reawrd -253.367671
# episode 1417, loss_actor 10.619868, loss_critic 0.087526, reawrd -127.346757
# episode 1418, loss_actor 9.351969, loss_critic 0.088802, reawrd -126.945623
# episode 1419, loss_actor 5.255617, loss_critic 0.059601, reawrd -127.461814
# episode 1420, loss_actor 4.918398, loss_critic 0.032959, reawrd -128.517959
# episode 1421, loss_actor 7.911520, loss_critic 0.049751, reawrd -376.108987
# episode 1422, loss_actor 8.327229, loss_critic 0.056045, reawrd -126.133257
# episode 1423, loss_actor 9.393810, loss_critic 0.071066, reawrd -241.477129
# episode 1424, loss_actor 9.856233, loss_critic 0.084227, reawrd -509.143722
# episode 1425, loss_actor 13.297887, loss_critic 0.090426, reawrd -352.868382
# episode 1426, loss_actor 9.705224, loss_critic 0.118272, reawrd -127.709091
# episode 1427, loss_actor 8.331935, loss_critic 0.039311, reawrd -126.740426
# episode 1428, loss_actor 11.401794, loss_critic 0.052902, reawrd -242.841871
# episode 1429, loss_actor 5.083333, loss_critic 0.072170, reawrd -127.568791
# episode 1430, loss_actor 5.963126, loss_critic 0.067243, reawrd -242.551449
# episode 1431, loss_actor 7.051548, loss_critic 0.043254, reawrd -131.506902
# episode 1432, loss_actor 12.523943, loss_critic 0.106773, reawrd -836.809886
# episode 1433, loss_actor 11.830816, loss_critic 0.131998, reawrd -252.602276
# episode 1434, loss_actor 11.598963, loss_critic 0.116068, reawrd -124.279280
# episode 1435, loss_actor 9.130005, loss_critic 0.125138, reawrd -0.349175
# episode 1436, loss_actor 10.836229, loss_critic 0.141502, reawrd -0.987870
# episode 1437, loss_actor 6.306250, loss_critic 0.042143, reawrd -490.545787
# episode 1438, loss_actor 9.324178, loss_critic 0.095043, reawrd -352.562465
# episode 1439, loss_actor 10.925947, loss_critic 0.060125, reawrd -468.172049
# episode 1440, loss_actor 16.684561, loss_critic 0.109554, reawrd -518.324111
# episode 1441, loss_actor 13.095409, loss_critic 0.149114, reawrd -247.602675
# episode 1442, loss_actor 10.095737, loss_critic 0.062242, reawrd -0.625116
# episode 1443, loss_actor 9.769926, loss_critic 0.096111, reawrd -130.384589
# episode 1444, loss_actor 4.869017, loss_critic 0.039657, reawrd -1.231297
# episode 1445, loss_actor 3.593775, loss_critic 0.018103, reawrd -236.436066
# episode 1446, loss_actor 2.581458, loss_critic 0.027620, reawrd -131.526376
# episode 1447, loss_actor 4.392280, loss_critic 0.017741, reawrd -124.233807
# episode 1448, loss_actor 4.177892, loss_critic 0.010226, reawrd -2.964009
# episode 1449, loss_actor 7.315468, loss_critic 0.063457, reawrd -374.122384
# episode 1450, loss_actor 5.370639, loss_critic 0.035974, reawrd -3.662995
# episode 1451, loss_actor 3.785307, loss_critic 0.029852, reawrd -248.529533
# episode 1452, loss_actor 2.845917, loss_critic 0.022559, reawrd -131.119847
# episode 1453, loss_actor 9.174276, loss_critic 0.094860, reawrd -242.219330
# episode 1454, loss_actor 6.003743, loss_critic 0.062604, reawrd -122.001122
# episode 1455, loss_actor 4.402351, loss_critic 0.032623, reawrd -122.806824
# episode 1456, loss_actor 4.965040, loss_critic 0.060737, reawrd -245.456256
# episode 1457, loss_actor 5.788041, loss_critic 0.100576, reawrd -450.891780
# episode 1458, loss_actor 9.097394, loss_critic 0.114939, reawrd -129.697042
# episode 1459, loss_actor 7.082045, loss_critic 0.051287, reawrd -253.964275
# episode 1460, loss_actor 6.952381, loss_critic 0.073117, reawrd -243.800497
# episode 1461, loss_actor 8.285420, loss_critic 0.062395, reawrd -373.209692
# episode 1462, loss_actor 11.862795, loss_critic 0.085847, reawrd -131.568452
# episode 1463, loss_actor 10.018345, loss_critic 0.078112, reawrd -125.309950
# episode 1464, loss_actor 9.386818, loss_critic 0.070213, reawrd -121.767730
# episode 1465, loss_actor 7.283250, loss_critic 0.042828, reawrd -243.904066
# episode 1466, loss_actor 5.310556, loss_critic 0.054379, reawrd -368.353168
# episode 1467, loss_actor 9.124959, loss_critic 0.073208, reawrd -354.419659
# episode 1468, loss_actor 8.015455, loss_critic 0.093119, reawrd -127.254074
# episode 1469, loss_actor 8.127293, loss_critic 0.078925, reawrd -0.712010
# episode 1470, loss_actor 6.788784, loss_critic 0.110651, reawrd -126.001683
# episode 1471, loss_actor 6.165278, loss_critic 0.042476, reawrd -249.696129
# episode 1472, loss_actor 8.404732, loss_critic 0.044069, reawrd -250.321378
# episode 1473, loss_actor 7.007804, loss_critic 0.052235, reawrd -244.856749
# episode 1474, loss_actor 13.869741, loss_critic 0.084983, reawrd -413.669890
# episode 1475, loss_actor 9.438116, loss_critic 0.070322, reawrd -129.227362
# episode 1476, loss_actor 10.538301, loss_critic 0.080274, reawrd -128.335187
# episode 1477, loss_actor 8.794036, loss_critic 0.078864, reawrd -131.206923
# episode 1478, loss_actor 10.263203, loss_critic 0.083882, reawrd -240.791250
# episode 1479, loss_actor 5.415839, loss_critic 0.030469, reawrd -131.000449
# episode 1480, loss_actor 6.245021, loss_critic 0.040848, reawrd -369.815837
# episode 1481, loss_actor 8.953645, loss_critic 0.056978, reawrd -126.744157
# episode 1482, loss_actor 6.676629, loss_critic 0.041892, reawrd -0.132571
# episode 1483, loss_actor 7.146956, loss_critic 0.064030, reawrd -121.618606
# episode 1484, loss_actor 5.138489, loss_critic 0.047924, reawrd -125.543749
# episode 1485, loss_actor 3.263751, loss_critic 0.011330, reawrd -126.499646
# episode 1486, loss_actor 4.220980, loss_critic 0.045527, reawrd -242.170404
# episode 1487, loss_actor 5.113860, loss_critic 0.044617, reawrd -131.369797
# episode 1488, loss_actor 6.922232, loss_critic 0.055870, reawrd -256.735139
# episode 1489, loss_actor 4.134373, loss_critic 0.032859, reawrd -1.019582
# episode 1490, loss_actor 9.807122, loss_critic 0.067358, reawrd -360.155673
# episode 1491, loss_actor 5.819401, loss_critic 0.036601, reawrd -126.481092
# episode 1492, loss_actor 7.631182, loss_critic 0.054850, reawrd -245.698197
# episode 1493, loss_actor 7.906218, loss_critic 0.094749, reawrd -361.897816
# episode 1494, loss_actor 9.006355, loss_critic 0.116260, reawrd -258.593126
# episode 1495, loss_actor 6.384840, loss_critic 0.188162, reawrd -6.060309
# episode 1496, loss_actor 5.235768, loss_critic 0.050004, reawrd -131.420073
# episode 1497, loss_actor 7.994850, loss_critic 0.077235, reawrd -361.499780
# episode 1498, loss_actor 8.050888, loss_critic 0.092368, reawrd -137.029795
# episode 1499, loss_actor 6.512442, loss_critic 0.068099, reawrd -131.800288
