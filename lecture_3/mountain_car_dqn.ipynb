# %% [markdown]
# # Mountain Car Q Value Approximation
#
# ![mountain_car_0](../images/lecture_3/mountain_car_0.png)
#
# ![mountain_car_1](../images/lecture_3/mountain_car_1.png)
#
# ![mountain_car_2](../images/lecture_3/mountain_car_2.png)

# %% [markdown]
# ## Gym Description
#
# ### Description
#
# The Mountain Car MDP is a deterministic MDP that consists of a car placed stochastically
# at the bottom of a sinusoidal valley, with the only possible actions being the accelerations
# that can be applied to the car in either direction. The goal of the MDP is to strategically
# accelerate the car to reach the goal state on top of the right hill. There are two versions
# of the mountain car domain in gymnasium: one with discrete actions and one with continuous.
# This version is the one with discrete actions.
#
# This MDP first appeared in [Andrew Moore's PhD Thesis (1990)](https://www.cl.cam.ac.uk/techreports/UCAM-CL-TR-209.pdf)
#
# ```
# @TECHREPORT{Moore90efficientmemory-based,
#     author = {Andrew William Moore},
#     title = {Efficient Memory-based Learning for Robot Control},
#     institution = {University of Cambridge},
#     year = {1990}
# }
# ```
#
# ### Observation Space
#
# The observation is a `ndarray` with shape `(2,)` where the elements correspond to the following:
#
# | Num | Observation                          | Min   | Max  | Unit         |
# | --- | ------------------------------------ | ----- | ---- | ------------ |
# | 0   | position of the car along the x-axis | -1.2  | 0.6  | position (m) |
# | 1   | velocity of the car                  | -0.07 | 0.07 | velocity (v) |
#
# ### Action Space
#
# There are 3 discrete deterministic actions:
#
# - 0: Accelerate to the left
# - 1: Don't accelerate
# - 2: Accelerate to the right
#
# ### Transition Dynamics:
#
# Given an action, the mountain car follows the following transition dynamics:
#
# _velocity<sub>t+1</sub> = velocity<sub>t</sub> + (action - 1) _ force - cos(3 _ position<sub>t</sub>) _ gravity\*
#
# _position<sub>t+1</sub> = position<sub>t</sub> + velocity<sub>t+1</sub>_
#
# where force = 0.001 and gravity = 0.0025. The collisions at either end are inelastic with the velocity set to 0
# upon collision with the wall. The position is clipped to the range `[-1.2, 0.6]` and
# velocity is clipped to the range `[-0.07, 0.07]`.
#
# ### Reward:
#
# The goal is to reach the flag placed on top of the right hill as quickly as possible, as such the agent is
# penalised with a reward of -1 for each timestep.
#
# ### Starting State
#
# The position of the car is assigned a uniform random value in _[-0.6 , -0.4]_.
# The starting velocity of the car is always assigned to 0.
#
# ### Episode End
#
# The episode ends if either of the following happens:
#
# 1. Termination: The position of the car is greater than or equal to 0.5 (the goal position on top of the right hill)
# 2. Truncation: The length of the episode is 200.
#
# ### Arguments
#
# ```python
# import gymnasium as gym
# gym.make('MountainCar-v0')
# ```
#
# On reset, the `options` parameter allows the user to change the bounds used to determine
# the new random state.
#
# ### Version History
#
# - v0: Initial versions release (1.0.0)

# %% [markdown]
# ## Import Env

# %%
import gymnasium as gym
for k,v in gym.envs.registry.items():
    print(k,"\t",v)
# Out:
# CartPole-v0 	 EnvSpec(id='CartPole-v0', entry_point='gymnasium.envs.classic_control.cartpole:CartPoleEnv', reward_threshold=195.0, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='CartPole', version=0, additional_wrappers=(), vector_entry_point='gymnasium.envs.classic_control.cartpole:CartPoleVectorEnv')
# CartPole-v1 	 EnvSpec(id='CartPole-v1', entry_point='gymnasium.envs.classic_control.cartpole:CartPoleEnv', reward_threshold=475.0, nondeterministic=False, max_episode_steps=500, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='CartPole', version=1, additional_wrappers=(), vector_entry_point='gymnasium.envs.classic_control.cartpole:CartPoleVectorEnv')
# MountainCar-v0 	 EnvSpec(id='MountainCar-v0', entry_point='gymnasium.envs.classic_control.mountain_car:MountainCarEnv', reward_threshold=-110.0, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='MountainCar', version=0, additional_wrappers=(), vector_entry_point=None)
# MountainCarContinuous-v0 	 EnvSpec(id='MountainCarContinuous-v0', entry_point='gymnasium.envs.classic_control.continuous_mountain_car:Continuous_MountainCarEnv', reward_threshold=90.0, nondeterministic=False, max_episode_steps=999, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='MountainCarContinuous', version=0, additional_wrappers=(), vector_entry_point=None)
# Pendulum-v1 	 EnvSpec(id='Pendulum-v1', entry_point='gymnasium.envs.classic_control.pendulum:PendulumEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Pendulum', version=1, additional_wrappers=(), vector_entry_point=None)
# Acrobot-v1 	 EnvSpec(id='Acrobot-v1', entry_point='gymnasium.envs.classic_control.acrobot:AcrobotEnv', reward_threshold=-100.0, nondeterministic=False, max_episode_steps=500, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Acrobot', version=1, additional_wrappers=(), vector_entry_point=None)
# CartPoleJax-v0 	 EnvSpec(id='CartPoleJax-v0', entry_point='gymnasium.envs.phys2d.cartpole:CartPoleJaxEnv', reward_threshold=195.0, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='CartPoleJax', version=0, additional_wrappers=(), vector_entry_point='gymnasium.envs.phys2d.cartpole:CartPoleJaxVectorEnv')
# CartPoleJax-v1 	 EnvSpec(id='CartPoleJax-v1', entry_point='gymnasium.envs.phys2d.cartpole:CartPoleJaxEnv', reward_threshold=475.0, nondeterministic=False, max_episode_steps=500, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='CartPoleJax', version=1, additional_wrappers=(), vector_entry_point='gymnasium.envs.phys2d.cartpole:CartPoleJaxVectorEnv')
# PendulumJax-v0 	 EnvSpec(id='PendulumJax-v0', entry_point='gymnasium.envs.phys2d.pendulum:PendulumJaxEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='PendulumJax', version=0, additional_wrappers=(), vector_entry_point='gymnasium.envs.phys2d.pendulum:PendulumJaxVectorEnv')
# LunarLander-v2 	 EnvSpec(id='LunarLander-v2', entry_point='gymnasium.envs.box2d.lunar_lander:LunarLander', reward_threshold=200, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='LunarLander', version=2, additional_wrappers=(), vector_entry_point=None)
# LunarLanderContinuous-v2 	 EnvSpec(id='LunarLanderContinuous-v2', entry_point='gymnasium.envs.box2d.lunar_lander:LunarLander', reward_threshold=200, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={'continuous': True}, namespace=None, name='LunarLanderContinuous', version=2, additional_wrappers=(), vector_entry_point=None)
# BipedalWalker-v3 	 EnvSpec(id='BipedalWalker-v3', entry_point='gymnasium.envs.box2d.bipedal_walker:BipedalWalker', reward_threshold=300, nondeterministic=False, max_episode_steps=1600, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='BipedalWalker', version=3, additional_wrappers=(), vector_entry_point=None)
# BipedalWalkerHardcore-v3 	 EnvSpec(id='BipedalWalkerHardcore-v3', entry_point='gymnasium.envs.box2d.bipedal_walker:BipedalWalker', reward_threshold=300, nondeterministic=False, max_episode_steps=2000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={'hardcore': True}, namespace=None, name='BipedalWalkerHardcore', version=3, additional_wrappers=(), vector_entry_point=None)
# CarRacing-v2 	 EnvSpec(id='CarRacing-v2', entry_point='gymnasium.envs.box2d.car_racing:CarRacing', reward_threshold=900, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='CarRacing', version=2, additional_wrappers=(), vector_entry_point=None)
# Blackjack-v1 	 EnvSpec(id='Blackjack-v1', entry_point='gymnasium.envs.toy_text.blackjack:BlackjackEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=None, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={'sab': True, 'natural': False}, namespace=None, name='Blackjack', version=1, additional_wrappers=(), vector_entry_point=None)
# FrozenLake-v1 	 EnvSpec(id='FrozenLake-v1', entry_point='gymnasium.envs.toy_text.frozen_lake:FrozenLakeEnv', reward_threshold=0.7, nondeterministic=False, max_episode_steps=100, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={'map_name': '4x4'}, namespace=None, name='FrozenLake', version=1, additional_wrappers=(), vector_entry_point=None)
# FrozenLake8x8-v1 	 EnvSpec(id='FrozenLake8x8-v1', entry_point='gymnasium.envs.toy_text.frozen_lake:FrozenLakeEnv', reward_threshold=0.85, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={'map_name': '8x8'}, namespace=None, name='FrozenLake8x8', version=1, additional_wrappers=(), vector_entry_point=None)
# CliffWalking-v0 	 EnvSpec(id='CliffWalking-v0', entry_point='gymnasium.envs.toy_text.cliffwalking:CliffWalkingEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=None, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='CliffWalking', version=0, additional_wrappers=(), vector_entry_point=None)
# Taxi-v3 	 EnvSpec(id='Taxi-v3', entry_point='gymnasium.envs.toy_text.taxi:TaxiEnv', reward_threshold=8, nondeterministic=False, max_episode_steps=200, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Taxi', version=3, additional_wrappers=(), vector_entry_point=None)
# Jax-Blackjack-v0 	 EnvSpec(id='Jax-Blackjack-v0', entry_point='gymnasium.envs.tabular.blackjack:BlackJackJaxEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=None, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={'sutton_and_barto': True, 'natural': False}, namespace=None, name='Jax-Blackjack', version=0, additional_wrappers=(), vector_entry_point=None)
# Reacher-v2 	 EnvSpec(id='Reacher-v2', entry_point='gymnasium.envs.mujoco:ReacherEnv', reward_threshold=-3.75, nondeterministic=False, max_episode_steps=50, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Reacher', version=2, additional_wrappers=(), vector_entry_point=None)
# Reacher-v4 	 EnvSpec(id='Reacher-v4', entry_point='gymnasium.envs.mujoco.reacher_v4:ReacherEnv', reward_threshold=-3.75, nondeterministic=False, max_episode_steps=50, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Reacher', version=4, additional_wrappers=(), vector_entry_point=None)
# Pusher-v2 	 EnvSpec(id='Pusher-v2', entry_point='gymnasium.envs.mujoco:PusherEnv', reward_threshold=0.0, nondeterministic=False, max_episode_steps=100, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Pusher', version=2, additional_wrappers=(), vector_entry_point=None)
# Pusher-v4 	 EnvSpec(id='Pusher-v4', entry_point='gymnasium.envs.mujoco.pusher_v4:PusherEnv', reward_threshold=0.0, nondeterministic=False, max_episode_steps=100, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Pusher', version=4, additional_wrappers=(), vector_entry_point=None)
# InvertedPendulum-v2 	 EnvSpec(id='InvertedPendulum-v2', entry_point='gymnasium.envs.mujoco:InvertedPendulumEnv', reward_threshold=950.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='InvertedPendulum', version=2, additional_wrappers=(), vector_entry_point=None)
# InvertedPendulum-v4 	 EnvSpec(id='InvertedPendulum-v4', entry_point='gymnasium.envs.mujoco.inverted_pendulum_v4:InvertedPendulumEnv', reward_threshold=950.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='InvertedPendulum', version=4, additional_wrappers=(), vector_entry_point=None)
# InvertedDoublePendulum-v2 	 EnvSpec(id='InvertedDoublePendulum-v2', entry_point='gymnasium.envs.mujoco:InvertedDoublePendulumEnv', reward_threshold=9100.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='InvertedDoublePendulum', version=2, additional_wrappers=(), vector_entry_point=None)
# InvertedDoublePendulum-v4 	 EnvSpec(id='InvertedDoublePendulum-v4', entry_point='gymnasium.envs.mujoco.inverted_double_pendulum_v4:InvertedDoublePendulumEnv', reward_threshold=9100.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='InvertedDoublePendulum', version=4, additional_wrappers=(), vector_entry_point=None)
# HalfCheetah-v2 	 EnvSpec(id='HalfCheetah-v2', entry_point='gymnasium.envs.mujoco:HalfCheetahEnv', reward_threshold=4800.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='HalfCheetah', version=2, additional_wrappers=(), vector_entry_point=None)
# HalfCheetah-v3 	 EnvSpec(id='HalfCheetah-v3', entry_point='gymnasium.envs.mujoco.half_cheetah_v3:HalfCheetahEnv', reward_threshold=4800.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='HalfCheetah', version=3, additional_wrappers=(), vector_entry_point=None)
# HalfCheetah-v4 	 EnvSpec(id='HalfCheetah-v4', entry_point='gymnasium.envs.mujoco.half_cheetah_v4:HalfCheetahEnv', reward_threshold=4800.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='HalfCheetah', version=4, additional_wrappers=(), vector_entry_point=None)
# Hopper-v2 	 EnvSpec(id='Hopper-v2', entry_point='gymnasium.envs.mujoco:HopperEnv', reward_threshold=3800.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Hopper', version=2, additional_wrappers=(), vector_entry_point=None)
# Hopper-v3 	 EnvSpec(id='Hopper-v3', entry_point='gymnasium.envs.mujoco.hopper_v3:HopperEnv', reward_threshold=3800.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Hopper', version=3, additional_wrappers=(), vector_entry_point=None)
# Hopper-v4 	 EnvSpec(id='Hopper-v4', entry_point='gymnasium.envs.mujoco.hopper_v4:HopperEnv', reward_threshold=3800.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Hopper', version=4, additional_wrappers=(), vector_entry_point=None)
# Swimmer-v2 	 EnvSpec(id='Swimmer-v2', entry_point='gymnasium.envs.mujoco:SwimmerEnv', reward_threshold=360.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Swimmer', version=2, additional_wrappers=(), vector_entry_point=None)
# Swimmer-v3 	 EnvSpec(id='Swimmer-v3', entry_point='gymnasium.envs.mujoco.swimmer_v3:SwimmerEnv', reward_threshold=360.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Swimmer', version=3, additional_wrappers=(), vector_entry_point=None)
# Swimmer-v4 	 EnvSpec(id='Swimmer-v4', entry_point='gymnasium.envs.mujoco.swimmer_v4:SwimmerEnv', reward_threshold=360.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Swimmer', version=4, additional_wrappers=(), vector_entry_point=None)
# Walker2d-v2 	 EnvSpec(id='Walker2d-v2', entry_point='gymnasium.envs.mujoco:Walker2dEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Walker2d', version=2, additional_wrappers=(), vector_entry_point=None)
# Walker2d-v3 	 EnvSpec(id='Walker2d-v3', entry_point='gymnasium.envs.mujoco.walker2d_v3:Walker2dEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Walker2d', version=3, additional_wrappers=(), vector_entry_point=None)
# Walker2d-v4 	 EnvSpec(id='Walker2d-v4', entry_point='gymnasium.envs.mujoco.walker2d_v4:Walker2dEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Walker2d', version=4, additional_wrappers=(), vector_entry_point=None)
# Ant-v2 	 EnvSpec(id='Ant-v2', entry_point='gymnasium.envs.mujoco:AntEnv', reward_threshold=6000.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Ant', version=2, additional_wrappers=(), vector_entry_point=None)
# Ant-v3 	 EnvSpec(id='Ant-v3', entry_point='gymnasium.envs.mujoco.ant_v3:AntEnv', reward_threshold=6000.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Ant', version=3, additional_wrappers=(), vector_entry_point=None)
# Ant-v4 	 EnvSpec(id='Ant-v4', entry_point='gymnasium.envs.mujoco.ant_v4:AntEnv', reward_threshold=6000.0, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Ant', version=4, additional_wrappers=(), vector_entry_point=None)
# Humanoid-v2 	 EnvSpec(id='Humanoid-v2', entry_point='gymnasium.envs.mujoco:HumanoidEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Humanoid', version=2, additional_wrappers=(), vector_entry_point=None)
# Humanoid-v3 	 EnvSpec(id='Humanoid-v3', entry_point='gymnasium.envs.mujoco.humanoid_v3:HumanoidEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Humanoid', version=3, additional_wrappers=(), vector_entry_point=None)
# Humanoid-v4 	 EnvSpec(id='Humanoid-v4', entry_point='gymnasium.envs.mujoco.humanoid_v4:HumanoidEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='Humanoid', version=4, additional_wrappers=(), vector_entry_point=None)
# HumanoidStandup-v2 	 EnvSpec(id='HumanoidStandup-v2', entry_point='gymnasium.envs.mujoco:HumanoidStandupEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='HumanoidStandup', version=2, additional_wrappers=(), vector_entry_point=None)
# HumanoidStandup-v4 	 EnvSpec(id='HumanoidStandup-v4', entry_point='gymnasium.envs.mujoco.humanoidstandup_v4:HumanoidStandupEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=1000, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='HumanoidStandup', version=4, additional_wrappers=(), vector_entry_point=None)
# GymV21Environment-v0 	 EnvSpec(id='GymV21Environment-v0', entry_point=<function _raise_shimmy_error at 0x7f2ae8043ac0>, reward_threshold=None, nondeterministic=False, max_episode_steps=None, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='GymV21Environment', version=0, additional_wrappers=(), vector_entry_point=None)
# GymV26Environment-v0 	 EnvSpec(id='GymV26Environment-v0', entry_point=<function _raise_shimmy_error at 0x7f2ae8043ac0>, reward_threshold=None, nondeterministic=False, max_episode_steps=None, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={}, namespace=None, name='GymV26Environment', version=0, additional_wrappers=(), vector_entry_point=None)

# %%
from gymnasium.envs.classic_control.mountain_car import MountainCarEnv
env=gym.make("MountainCar-v0")
print("Observation space: ",env.observation_space)
print("Action space: ",env.action_space)
# Out:
# Observation space:  Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action space:  Discrete(3)

# %% [markdown]
# ## Normalizer

# %%
import numpy as np


def normalizer(env: gym.Env, state: np.ndarray):
    LOW = env.observation_space.low
    HIGH = env.observation_space.high
    normalized_state = np.zeros(state.shape)
    normalized_state = (state-LOW)/(HIGH - LOW)
    return normalized_state


normalizer(env, env.reset()[0])
# Out:
# array([0.3983981, 0.5      ], dtype=float32)

# %% [markdown]
# ## Q Approximator

# %%
import torch
import torch.nn as nn


class Q_Approximator(nn.Module):
    def __init__(self, num_observations: int, num_actions: int) -> None:
        super().__init__()
        self.layer_1 = nn.Linear(num_observations, 128)
        self.layer_2 = nn.Linear(128, num_actions)
        self.selu = nn.SELU()

    def forward(self, state: torch.Tensor) -> torch.Tensor:
        q_actions = self.layer_1(state)
        q_actions = self.selu(q_actions)
        q_actions = self.layer_2(q_actions)
        return q_actions

# %% [markdown]
# ## Experience

# %%
from collections import namedtuple, deque
from typing import List
import random
Transition = namedtuple(
    "transition", ["state", "action", "next_state", "next_action", "reward"])


class Experience:
    def __init__(self, maxlen: int) -> None:
        self.experience = deque([], maxlen)

    def append(self, transition: Transition):
        self.experience.append(transition)

    def sample(self, batch_size) -> List:
        return random.sample(self.experience, batch_size)

    def get_length(self) -> int:
        return len(self.experience)

# %% [markdown]
# ## Epsilon Decay

# %%
import numpy as np


def get_epsilon(epsilon_start: float, epsilon_end: float, num_episodes: float, step_i: int):
    """return epsilon=epsilon_end+(epsilon_start-epsilon_end)*decay_rate**step_decay"""
    epsilon = epsilon_end+(epsilon_start-epsilon_end) * \
        np.exp(-1.0*step_i/(1.0*num_episodes))
    return epsilon


def plot_epsilon(epsilon_start: float, epsilon_end: float, num_episode: float):
    import matplotlib.pyplot as plt
    xs = np.arange(num_episode)
    epsilons = np.array(
        [get_epsilon(epsilon_start, epsilon_end, num_episode, step) for step in xs])
    plt.plot(xs, epsilons)


plot_epsilon(0.9, 0.05, int(1e3))

# %% [markdown]
# ## Epsilon-greedy

# %%
def epsilon_greedy(policy_net: Q_Approximator, num_actions: int, state: torch.Tensor, epsilon: float) -> int:
    probability = 1.0*np.ones(num_actions)*epsilon/num_actions
    q_actions = policy_net(state).detach().cpu().numpy()
    idx_action_with_max_q = np.argmax(q_actions)
    probability[idx_action_with_max_q] = 1-np.sum(probability[1:])
    return np.random.choice(np.arange(num_actions), p=probability)


epsilon_greedy(Q_Approximator(env.observation_space.shape[0], env.action_space.n), env.action_space.n, torch.tensor(
    env.reset()[0], dtype=torch.float32), 0.1)
# Out:
# 2

# %% [markdown]
# ## Learning Rate Decay

# %%
def get_learning_rate(learning_rate_start:float,learning_rate_end:float,num_episodes:float,step_i:int):
    """return epsilon=epsilon_end+(epsilon_start-epsilon_end)*decay_rate**step_decay"""
    learning_rate=learning_rate_end+(learning_rate_start-learning_rate_end)*np.exp(-1.0*step_i/num_episodes)
    return learning_rate

def plot_learning_rate(epsilon_start: float, epsilon_end: float, num_episode: float):
    import matplotlib.pyplot as plt
    xs = np.arange(num_episode)
    lrs = np.array(
        [get_learning_rate(epsilon_start, epsilon_end, num_episode, step) for step in xs])
    plt.plot(xs, lrs)


plot_learning_rate(1e-2, 1e-4, int(1e3))

# %%
def q_learning_update_policy_net(policy_net:Q_Approximator,target_net:Q_Approximator,
                                experience:Experience,batch_size:int,
                                learning_rate:float,gamma:float,
                                loss_fn:nn.Module,optimizer:torch.optim.Optimizer,
                                device:str):
    
    # set up learning rate
    for g in optimizer.param_groups:
        g['lr']=learning_rate
    
    batch=experience.sample(batch_size)
    [batch_state,batch_action,batch_next_state,batch_next_action,batch_reward]=zip(*batch)
    batch_state=torch.tensor(batch_state,dtype= torch.float32,device= device)
    batch_action=torch.tensor(batch_action,dtype= torch.int64,device= device).unsqueeze(-1)
    mask_batch_next_state_is_not_none=torch.tensor([next_state is not None for next_state in batch_next_state],dtype= torch.bool,device=device)
    batch_not_none_next_state=torch.tensor([next_state for next_state in batch_next_state if next_state is not None],dtype= torch.float32,device= device)
    batch_reward=torch.tensor(batch_reward,dtype= torch.float32,device= device).unsqueeze(-1)
    
    q_state_action=policy_net(batch_state).gather(1,batch_action)
    q_next_state_action=torch.zeros(q_state_action.size(),device=device)
    with torch.no_grad():
        q_next_state_action[mask_batch_next_state_is_not_none]=target_net(batch_not_none_next_state).max(1)[0].unsqueeze(-1)
    q_target=batch_reward+gamma*q_next_state_action
    
    optimizer.zero_grad()
    loss=loss_fn(q_state_action,q_target)
    loss.backward()
    optimizer.step()
    
    return loss.item()

# %% [markdown]
# ## Q Learning

# %%
from collections import defaultdict


def q_learning(env: gym.Env, num_episodes: int = int(1e3),
               experience_maxlen: int = 2**10, batch_size: int = 64,
               gamma: float = 0.9,
               learning_rate_start: float = 1e-3, learning_rate_end: float = 1e-4,
               epsilon_start: float = 0.9, epsilon_end: float = 0.05,
               tau=0.005,
               device: str = "cpu",
               print_step: int = 100):
    policy_net = Q_Approximator(
        env.observation_space.shape[0], env.action_space.n).to(device)
    target_net = Q_Approximator(
        env.observation_space.shape[0], env.action_space.n).to(device)

    loss_fn = nn.SmoothL1Loss()
    optimizer = torch.optim.SGD(policy_net.parameters(), learning_rate_start)

    experience = Experience(experience_maxlen)

    num_attempts_per_episode = defaultdict(int)
    reward_per_episode = defaultdict(float)

    loss = 0.0

    for episode_i in range(num_episodes):
        state = env.reset()[0]
        is_terminated = False
        epsilon = get_epsilon(epsilon_start, epsilon_end,
                              num_episodes, episode_i)
        learning_rate = get_learning_rate(
            learning_rate_start, learning_rate_end, num_episodes, episode_i)
        while not is_terminated:
            normalized_state = normalizer(env, state)
            action = epsilon_greedy(policy_net, env.action_space.n, torch.tensor(
                normalized_state, dtype=torch.float32, device=device), epsilon)
            next_state, reward, is_terminated, is_truncated, info = env.step(
                action)
            normalized_next_state = normalizer(env, next_state)
            if is_terminated:
                next_state = None
            experience.append(Transition(
                normalized_state, action, normalized_next_state, None, reward))
            
            state=next_state
            
            if experience.get_length() >= batch_size:
                loss = q_learning_update_policy_net(
                    policy_net, target_net, experience, batch_size, learning_rate, gamma, loss_fn, optimizer, device)

                target_net_state_dict = target_net.state_dict()
                policy_net_state_dict = policy_net.state_dict()
                for key in policy_net_state_dict:
                    target_net_state_dict[key] = policy_net_state_dict[key] * \
                        tau + target_net_state_dict[key]*(1-tau)
                target_net.load_state_dict(target_net_state_dict)

            num_attempts_per_episode[episode_i] += 1
            reward_per_episode[episode_i] += reward

        if episode_i % print_step == 0:
            print("episode %d, loss %f, num_attempts %d" %
                  (episode_i, loss, num_attempts_per_episode[episode_i]))

    return policy_net, num_attempts_per_episode, reward_per_episode

# %%
import time
t_start=time.time()
q_learning_policy_net,q_learning_num_attempts_per_episode,q_learning_reward_per_episode=q_learning(env,num_episodes=int(1e3),experience_maxlen=2**10,batch_size=128,gamma=0.9,learning_rate_start=1e-7,learning_rate_end=1e-8,epsilon_start=0.9,epsilon_end=0.05,tau=0.005,device="cuda" if torch.cuda.is_available() else "cpu",print_step=1)
t_end=time.time()
print("training cost: ", t_end-t_start)
# Out:
# /tmp/ipykernel_25725/2943973590.py:13: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484808560/work/torch/csrc/utils/tensor_new.cpp:201.)
#   batch_state=torch.tensor(batch_state,dtype= torch.float32,device= device)
# episode 0, loss 0.311343, num_attempts 5892
# episode 1, loss 0.280436, num_attempts 1572
# episode 2, loss 0.315003, num_attempts 12729
# episode 3, loss 0.307361, num_attempts 20435
# episode 4, loss 0.270593, num_attempts 4314
# episode 5, loss 0.291885, num_attempts 8119
# episode 6, loss 0.299465, num_attempts 11418
# episode 7, loss 0.333980, num_attempts 11642
# episode 8, loss 0.309965, num_attempts 24977
# episode 9, loss 0.306880, num_attempts 3018
# episode 10, loss 0.285600, num_attempts 7153
# episode 11, loss 0.287499, num_attempts 6624
# episode 12, loss 0.287394, num_attempts 17291
# episode 13, loss 0.295706, num_attempts 20781
# episode 14, loss 0.308931, num_attempts 12047
# episode 15, loss 0.287326, num_attempts 3828
# episode 16, loss 0.301597, num_attempts 17824
# episode 17, loss 0.328731, num_attempts 12488
# episode 18, loss 0.307988, num_attempts 6092
# episode 19, loss 0.370098, num_attempts 13597
# episode 20, loss 0.328066, num_attempts 13410
# episode 21, loss 0.320109, num_attempts 7544
# episode 22, loss 0.330308, num_attempts 4899
# episode 23, loss 0.319896, num_attempts 12582
# episode 24, loss 0.351007, num_attempts 5130
# episode 25, loss 0.318573, num_attempts 2134
# episode 26, loss 0.324632, num_attempts 10619
# episode 27, loss 0.309782, num_attempts 2905
# episode 28, loss 0.327005, num_attempts 3749
# episode 29, loss 0.325651, num_attempts 3964
# episode 30, loss 0.319500, num_attempts 1120
# episode 31, loss 0.335610, num_attempts 5542
# episode 32, loss 0.327954, num_attempts 7920
# episode 33, loss 0.347427, num_attempts 6734
# episode 34, loss 0.331768, num_attempts 8092
# episode 35, loss 0.332183, num_attempts 1817
# episode 36, loss 0.304814, num_attempts 2659
# episode 37, loss 0.340644, num_attempts 2439
# episode 38, loss 0.328450, num_attempts 2535
# episode 39, loss 0.353797, num_attempts 2521
# episode 40, loss 0.351964, num_attempts 3266
# episode 41, loss 0.340470, num_attempts 2974
# episode 42, loss 0.327960, num_attempts 4695
# episode 43, loss 0.319408, num_attempts 2682
# episode 44, loss 0.334634, num_attempts 924
# episode 45, loss 0.339787, num_attempts 1284
# episode 46, loss 0.338838, num_attempts 1764
# episode 47, loss 0.339515, num_attempts 5680
# episode 48, loss 0.361591, num_attempts 1830
# episode 49, loss 0.341560, num_attempts 2667
# episode 50, loss 0.351740, num_attempts 1569
# episode 51, loss 0.344986, num_attempts 4724
# episode 52, loss 0.349555, num_attempts 4583
# episode 53, loss 0.326704, num_attempts 1323
# episode 54, loss 0.319506, num_attempts 4647
# episode 55, loss 0.338345, num_attempts 1026
# episode 56, loss 0.357979, num_attempts 1285
# episode 57, loss 0.335648, num_attempts 1541
# episode 58, loss 0.339059, num_attempts 3319
# episode 59, loss 0.362183, num_attempts 3676
# episode 60, loss 0.325127, num_attempts 1547
# episode 61, loss 0.338105, num_attempts 902
# episode 62, loss 0.305228, num_attempts 3424
# episode 63, loss 0.377073, num_attempts 2778
# episode 64, loss 0.343563, num_attempts 2267
# episode 65, loss 0.354752, num_attempts 1503
# episode 66, loss 0.323034, num_attempts 2466
# episode 67, loss 0.339210, num_attempts 1175
# episode 68, loss 0.327010, num_attempts 2879
# episode 69, loss 0.345954, num_attempts 2022
# episode 70, loss 0.333223, num_attempts 570
# episode 71, loss 0.367528, num_attempts 910
# episode 72, loss 0.329725, num_attempts 968
# episode 73, loss 0.338049, num_attempts 957
# episode 74, loss 0.355963, num_attempts 1282
# episode 75, loss 0.358082, num_attempts 2398
# episode 76, loss 0.339114, num_attempts 1159
# episode 77, loss 0.343332, num_attempts 2417
# episode 78, loss 0.341299, num_attempts 2571
# episode 79, loss 0.345020, num_attempts 1388
# episode 80, loss 0.339216, num_attempts 1663
# episode 81, loss 0.353456, num_attempts 1530
# episode 82, loss 0.337606, num_attempts 1427
# episode 83, loss 0.334080, num_attempts 1203
# episode 84, loss 0.337714, num_attempts 1366
# episode 85, loss 0.355242, num_attempts 1441
# episode 86, loss 0.370418, num_attempts 1370
# episode 87, loss 0.354115, num_attempts 1409
# episode 88, loss 0.338523, num_attempts 2949
# episode 89, loss 0.334714, num_attempts 1467
# episode 90, loss 0.358138, num_attempts 790
# episode 91, loss 0.356068, num_attempts 1313
# episode 92, loss 0.337582, num_attempts 1258
# episode 93, loss 0.348184, num_attempts 2298
# episode 94, loss 0.338664, num_attempts 1300
# episode 95, loss 0.368757, num_attempts 1831
# episode 96, loss 0.348405, num_attempts 783
# episode 97, loss 0.345847, num_attempts 1064
# episode 98, loss 0.346708, num_attempts 776
# episode 99, loss 0.344222, num_attempts 1652
# episode 100, loss 0.357341, num_attempts 925
# episode 101, loss 0.357633, num_attempts 637
# episode 102, loss 0.332796, num_attempts 1960
# episode 103, loss 0.338097, num_attempts 1692
# episode 104, loss 0.358506, num_attempts 615
# episode 105, loss 0.333845, num_attempts 1464
# episode 106, loss 0.357481, num_attempts 3208
# episode 107, loss 0.341215, num_attempts 841
# episode 108, loss 0.362834, num_attempts 759
# episode 109, loss 0.359664, num_attempts 1080
# episode 110, loss 0.352457, num_attempts 800
# episode 111, loss 0.349704, num_attempts 2191
# episode 112, loss 0.363997, num_attempts 1721
# episode 113, loss 0.312218, num_attempts 667
# episode 114, loss 0.352250, num_attempts 930
# episode 115, loss 0.362848, num_attempts 970
# episode 116, loss 0.381342, num_attempts 1742
# episode 117, loss 0.336169, num_attempts 749
# episode 118, loss 0.356877, num_attempts 1187
# episode 119, loss 0.353476, num_attempts 539
# episode 120, loss 0.346260, num_attempts 909
# episode 121, loss 0.373581, num_attempts 1404
# episode 122, loss 0.333939, num_attempts 866
# episode 123, loss 0.365378, num_attempts 1741
# episode 124, loss 0.335327, num_attempts 1043
# episode 125, loss 0.366494, num_attempts 414
# episode 126, loss 0.335126, num_attempts 823
# episode 127, loss 0.339444, num_attempts 1683
# episode 128, loss 0.351994, num_attempts 1035
# episode 129, loss 0.321668, num_attempts 609
# episode 130, loss 0.357957, num_attempts 1151
# episode 131, loss 0.364417, num_attempts 704
# episode 132, loss 0.340734, num_attempts 1816
# episode 133, loss 0.366956, num_attempts 1101
# episode 134, loss 0.351887, num_attempts 1005
# episode 135, loss 0.366747, num_attempts 368
# episode 136, loss 0.340007, num_attempts 1771
# episode 137, loss 0.378956, num_attempts 1616
# episode 138, loss 0.361049, num_attempts 619
# episode 139, loss 0.360973, num_attempts 702
# episode 140, loss 0.337498, num_attempts 824
# episode 141, loss 0.371155, num_attempts 855
# episode 142, loss 0.392388, num_attempts 956
# episode 143, loss 0.366293, num_attempts 659
# episode 144, loss 0.370594, num_attempts 804
# episode 145, loss 0.351367, num_attempts 693
# episode 146, loss 0.364466, num_attempts 1128
# episode 147, loss 0.338216, num_attempts 884
# episode 148, loss 0.358708, num_attempts 705
# episode 149, loss 0.361597, num_attempts 2168
# episode 150, loss 0.359792, num_attempts 591
# episode 151, loss 0.323879, num_attempts 990
# episode 152, loss 0.338073, num_attempts 692
# episode 153, loss 0.336029, num_attempts 1017
# episode 154, loss 0.352258, num_attempts 1305
# episode 155, loss 0.347079, num_attempts 1756
# episode 156, loss 0.358248, num_attempts 1745
# episode 157, loss 0.348587, num_attempts 1223
# episode 158, loss 0.345552, num_attempts 791
# episode 159, loss 0.371588, num_attempts 845
# episode 160, loss 0.360005, num_attempts 639
# episode 161, loss 0.372790, num_attempts 903
# episode 162, loss 0.344928, num_attempts 927
# episode 163, loss 0.357748, num_attempts 538
# episode 164, loss 0.357102, num_attempts 929
# episode 165, loss 0.347003, num_attempts 563
# episode 166, loss 0.366843, num_attempts 712
# episode 167, loss 0.350268, num_attempts 645
# episode 168, loss 0.356176, num_attempts 569
# episode 169, loss 0.353546, num_attempts 934
# episode 170, loss 0.356282, num_attempts 535
# episode 171, loss 0.369086, num_attempts 787
# episode 172, loss 0.361474, num_attempts 717
# episode 173, loss 0.354182, num_attempts 1246
# episode 174, loss 0.342813, num_attempts 522
# episode 175, loss 0.372818, num_attempts 980
# episode 176, loss 0.373112, num_attempts 381
# episode 177, loss 0.354177, num_attempts 968
# episode 178, loss 0.329775, num_attempts 335
# episode 179, loss 0.356472, num_attempts 844
# episode 180, loss 0.368027, num_attempts 695
# episode 181, loss 0.378188, num_attempts 443
# episode 182, loss 0.354466, num_attempts 1442
# episode 183, loss 0.346848, num_attempts 782
# episode 184, loss 0.368901, num_attempts 495
# episode 185, loss 0.376214, num_attempts 452
# episode 186, loss 0.354833, num_attempts 612
# episode 187, loss 0.372292, num_attempts 426
# episode 188, loss 0.353331, num_attempts 1108
# episode 189, loss 0.374100, num_attempts 1363
# episode 190, loss 0.374003, num_attempts 664
# episode 191, loss 0.365677, num_attempts 767
# episode 192, loss 0.357592, num_attempts 317
# episode 193, loss 0.370756, num_attempts 544
# episode 194, loss 0.359290, num_attempts 985
# episode 195, loss 0.364142, num_attempts 446
# episode 196, loss 0.342268, num_attempts 708
# episode 197, loss 0.367635, num_attempts 357
# episode 198, loss 0.355962, num_attempts 349
# episode 199, loss 0.355922, num_attempts 738
# episode 200, loss 0.354369, num_attempts 553
# episode 201, loss 0.379328, num_attempts 311
# episode 202, loss 0.367562, num_attempts 737
# episode 203, loss 0.367064, num_attempts 458
# episode 204, loss 0.366139, num_attempts 689
# episode 205, loss 0.357773, num_attempts 371
# episode 206, loss 0.354891, num_attempts 655
# episode 207, loss 0.377919, num_attempts 721
# episode 208, loss 0.349946, num_attempts 1075
# episode 209, loss 0.356206, num_attempts 741
# episode 210, loss 0.357270, num_attempts 1464
# episode 211, loss 0.358584, num_attempts 639
# episode 212, loss 0.376028, num_attempts 1271
# episode 213, loss 0.360140, num_attempts 1000
# episode 214, loss 0.338813, num_attempts 1009
# episode 215, loss 0.355581, num_attempts 574
# episode 216, loss 0.361628, num_attempts 428
# episode 217, loss 0.365071, num_attempts 401
# episode 218, loss 0.380914, num_attempts 816
# episode 219, loss 0.362442, num_attempts 763
# episode 220, loss 0.368043, num_attempts 757
# episode 221, loss 0.353620, num_attempts 638
# episode 222, loss 0.365835, num_attempts 436
# episode 223, loss 0.363513, num_attempts 926
# episode 224, loss 0.365911, num_attempts 356
# episode 225, loss 0.352195, num_attempts 496
# episode 226, loss 0.370585, num_attempts 779
# episode 227, loss 0.364879, num_attempts 742
# episode 228, loss 0.361509, num_attempts 617
# episode 229, loss 0.355312, num_attempts 738
# episode 230, loss 0.362467, num_attempts 389
# episode 231, loss 0.353041, num_attempts 247
# episode 232, loss 0.353809, num_attempts 589
# episode 233, loss 0.370692, num_attempts 603
# episode 234, loss 0.367796, num_attempts 258
# episode 235, loss 0.360385, num_attempts 483
# episode 236, loss 0.380955, num_attempts 445
# episode 237, loss 0.353437, num_attempts 615
# episode 238, loss 0.368135, num_attempts 648
# episode 239, loss 0.357131, num_attempts 511
# episode 240, loss 0.364826, num_attempts 414
# episode 241, loss 0.361055, num_attempts 638
# episode 242, loss 0.354857, num_attempts 425
# episode 243, loss 0.361571, num_attempts 423
# episode 244, loss 0.382113, num_attempts 364
# episode 245, loss 0.370450, num_attempts 892
# episode 246, loss 0.369518, num_attempts 687
# episode 247, loss 0.371423, num_attempts 1128
# episode 248, loss 0.352809, num_attempts 1167
# episode 249, loss 0.359474, num_attempts 669
# episode 250, loss 0.370880, num_attempts 481
# episode 251, loss 0.370726, num_attempts 370
# episode 252, loss 0.357936, num_attempts 386
# episode 253, loss 0.371017, num_attempts 756
# episode 254, loss 0.352442, num_attempts 632
# episode 255, loss 0.359642, num_attempts 606
# episode 256, loss 0.350868, num_attempts 1025
# episode 257, loss 0.376988, num_attempts 493
# episode 258, loss 0.372559, num_attempts 564
# episode 259, loss 0.379172, num_attempts 355
# episode 260, loss 0.355247, num_attempts 569
# episode 261, loss 0.366729, num_attempts 278
# episode 262, loss 0.360843, num_attempts 675
# episode 263, loss 0.369634, num_attempts 475
# episode 264, loss 0.371984, num_attempts 295
# episode 265, loss 0.367176, num_attempts 501
# episode 266, loss 0.350686, num_attempts 401
# episode 267, loss 0.357462, num_attempts 509
# episode 268, loss 0.359676, num_attempts 1164
# episode 269, loss 0.356880, num_attempts 296
# episode 270, loss 0.371874, num_attempts 402
# episode 271, loss 0.372549, num_attempts 461
# episode 272, loss 0.368965, num_attempts 471
# episode 273, loss 0.371366, num_attempts 283
# episode 274, loss 0.350864, num_attempts 463
# episode 275, loss 0.364150, num_attempts 307
# episode 276, loss 0.378367, num_attempts 364
# episode 277, loss 0.379099, num_attempts 825
# episode 278, loss 0.377994, num_attempts 360
# episode 279, loss 0.369856, num_attempts 392
# episode 280, loss 0.369426, num_attempts 409
# episode 281, loss 0.365337, num_attempts 327
# episode 282, loss 0.370444, num_attempts 426
# episode 283, loss 0.360709, num_attempts 417
# episode 284, loss 0.367678, num_attempts 581
# episode 285, loss 0.374161, num_attempts 321
# episode 286, loss 0.362856, num_attempts 298
# episode 287, loss 0.349487, num_attempts 275
# episode 288, loss 0.381667, num_attempts 511
# episode 289, loss 0.379260, num_attempts 313
# episode 290, loss 0.371517, num_attempts 379
# episode 291, loss 0.369211, num_attempts 311
# episode 292, loss 0.373398, num_attempts 335
# episode 293, loss 0.374489, num_attempts 324
# episode 294, loss 0.370498, num_attempts 423
# episode 295, loss 0.374746, num_attempts 523
# episode 296, loss 0.364231, num_attempts 288
# episode 297, loss 0.372168, num_attempts 403
# episode 298, loss 0.353196, num_attempts 630
# episode 299, loss 0.352536, num_attempts 364
# episode 300, loss 0.369557, num_attempts 756
# episode 301, loss 0.368920, num_attempts 408
# episode 302, loss 0.361592, num_attempts 458
# episode 303, loss 0.372947, num_attempts 450
# episode 304, loss 0.358006, num_attempts 340
# episode 305, loss 0.365527, num_attempts 334
# episode 306, loss 0.366944, num_attempts 296
# episode 307, loss 0.387201, num_attempts 344
# episode 308, loss 0.372138, num_attempts 674
# episode 309, loss 0.371055, num_attempts 459
# episode 310, loss 0.366626, num_attempts 340
# episode 311, loss 0.383897, num_attempts 631
# episode 312, loss 0.384800, num_attempts 447
# episode 313, loss 0.383184, num_attempts 251
# episode 314, loss 0.379091, num_attempts 196
# episode 315, loss 0.390841, num_attempts 373
# episode 316, loss 0.374158, num_attempts 711
# episode 317, loss 0.373511, num_attempts 294
# episode 318, loss 0.355771, num_attempts 350
# episode 319, loss 0.395403, num_attempts 283
# episode 320, loss 0.390713, num_attempts 247
# episode 321, loss 0.384290, num_attempts 306
# episode 322, loss 0.382713, num_attempts 299
# episode 323, loss 0.378303, num_attempts 305
# episode 324, loss 0.363925, num_attempts 472
# episode 325, loss 0.379815, num_attempts 363
# episode 326, loss 0.381539, num_attempts 434
# episode 327, loss 0.372669, num_attempts 401
# episode 328, loss 0.367899, num_attempts 399
# episode 329, loss 0.386422, num_attempts 354
# episode 330, loss 0.389916, num_attempts 384
# episode 331, loss 0.366372, num_attempts 495
# episode 332, loss 0.354441, num_attempts 279
# episode 333, loss 0.378144, num_attempts 343
# episode 334, loss 0.369621, num_attempts 207
# episode 335, loss 0.357033, num_attempts 370
# episode 336, loss 0.376748, num_attempts 392
# episode 337, loss 0.367613, num_attempts 1206
# episode 338, loss 0.371481, num_attempts 278
# episode 339, loss 0.383987, num_attempts 338
# episode 340, loss 0.394120, num_attempts 412
# episode 341, loss 0.382529, num_attempts 293
# episode 342, loss 0.378291, num_attempts 321
# episode 343, loss 0.371554, num_attempts 333
# episode 344, loss 0.387681, num_attempts 311
# episode 345, loss 0.367919, num_attempts 333
# episode 346, loss 0.368906, num_attempts 424
# episode 347, loss 0.380421, num_attempts 284
# episode 348, loss 0.370501, num_attempts 250
# episode 349, loss 0.370475, num_attempts 373
# episode 350, loss 0.373757, num_attempts 341
# episode 351, loss 0.387820, num_attempts 366
# episode 352, loss 0.370458, num_attempts 274
# episode 353, loss 0.380229, num_attempts 567
# episode 354, loss 0.370469, num_attempts 247
# episode 355, loss 0.378889, num_attempts 374
# episode 356, loss 0.350787, num_attempts 346
# episode 357, loss 0.375252, num_attempts 285
# episode 358, loss 0.383657, num_attempts 394
# episode 359, loss 0.365633, num_attempts 697
# episode 360, loss 0.382508, num_attempts 276
# episode 361, loss 0.363410, num_attempts 285
# episode 362, loss 0.365384, num_attempts 316
# episode 363, loss 0.378318, num_attempts 267
# episode 364, loss 0.370167, num_attempts 273
# episode 365, loss 0.374022, num_attempts 490
# episode 366, loss 0.376040, num_attempts 283
# episode 367, loss 0.370874, num_attempts 286
# episode 368, loss 0.362250, num_attempts 291
# episode 369, loss 0.371954, num_attempts 469
# episode 370, loss 0.386646, num_attempts 331
# episode 371, loss 0.372463, num_attempts 436
# episode 372, loss 0.372997, num_attempts 296
# episode 373, loss 0.395230, num_attempts 436
# episode 374, loss 0.366360, num_attempts 302
# episode 375, loss 0.385369, num_attempts 357
# episode 376, loss 0.368059, num_attempts 260
# episode 377, loss 0.363238, num_attempts 280
# episode 378, loss 0.395121, num_attempts 411
# episode 379, loss 0.367460, num_attempts 289
# episode 380, loss 0.374662, num_attempts 373
# episode 381, loss 0.373410, num_attempts 373
# episode 382, loss 0.389414, num_attempts 198
# episode 383, loss 0.388578, num_attempts 494
# episode 384, loss 0.391380, num_attempts 301
# episode 385, loss 0.380065, num_attempts 291
# episode 386, loss 0.392411, num_attempts 602
# episode 387, loss 0.373790, num_attempts 375
# episode 388, loss 0.377292, num_attempts 252
# episode 389, loss 0.377093, num_attempts 255
# episode 390, loss 0.373463, num_attempts 357
# episode 391, loss 0.377242, num_attempts 202
# episode 392, loss 0.394993, num_attempts 461
# episode 393, loss 0.383665, num_attempts 266
# episode 394, loss 0.380089, num_attempts 268
# episode 395, loss 0.376376, num_attempts 292
# episode 396, loss 0.370938, num_attempts 341
# episode 397, loss 0.386458, num_attempts 285
# episode 398, loss 0.377064, num_attempts 304
# episode 399, loss 0.387808, num_attempts 236
# episode 400, loss 0.387697, num_attempts 258
# episode 401, loss 0.384294, num_attempts 455
# episode 402, loss 0.372888, num_attempts 288
# episode 403, loss 0.382679, num_attempts 287
# episode 404, loss 0.372606, num_attempts 327
# episode 405, loss 0.375308, num_attempts 386
# episode 406, loss 0.382553, num_attempts 238
# episode 407, loss 0.352870, num_attempts 292
# episode 408, loss 0.372020, num_attempts 290
# episode 409, loss 0.385503, num_attempts 332
# episode 410, loss 0.392671, num_attempts 205
# episode 411, loss 0.382778, num_attempts 328
# episode 412, loss 0.378736, num_attempts 384
# episode 413, loss 0.386693, num_attempts 333
# episode 414, loss 0.391944, num_attempts 232
# episode 415, loss 0.361432, num_attempts 367
# episode 416, loss 0.375667, num_attempts 298
# episode 417, loss 0.396356, num_attempts 275
# episode 418, loss 0.383838, num_attempts 313
# episode 419, loss 0.379898, num_attempts 572
# episode 420, loss 0.379517, num_attempts 401
# episode 421, loss 0.372202, num_attempts 300
# episode 422, loss 0.398097, num_attempts 395
# episode 423, loss 0.389764, num_attempts 526
# episode 424, loss 0.366708, num_attempts 466
# episode 425, loss 0.368683, num_attempts 333
# episode 426, loss 0.382367, num_attempts 312
# episode 427, loss 0.373187, num_attempts 372
# episode 428, loss 0.380567, num_attempts 315
# episode 429, loss 0.378361, num_attempts 283
# episode 430, loss 0.389957, num_attempts 173
# episode 431, loss 0.374969, num_attempts 198
# episode 432, loss 0.380759, num_attempts 292
# episode 433, loss 0.390443, num_attempts 287
# episode 434, loss 0.397481, num_attempts 359
# episode 435, loss 0.382667, num_attempts 201
# episode 436, loss 0.378006, num_attempts 405
# episode 437, loss 0.373307, num_attempts 348
# episode 438, loss 0.365725, num_attempts 293
# episode 439, loss 0.384286, num_attempts 374
# episode 440, loss 0.372691, num_attempts 172
# episode 441, loss 0.393011, num_attempts 368
# episode 442, loss 0.379067, num_attempts 245
# episode 443, loss 0.366499, num_attempts 431
# episode 444, loss 0.372061, num_attempts 339
# episode 445, loss 0.360127, num_attempts 238
# episode 446, loss 0.396276, num_attempts 238
# episode 447, loss 0.378727, num_attempts 488
# episode 448, loss 0.379297, num_attempts 339
# episode 449, loss 0.385225, num_attempts 301
# episode 450, loss 0.381186, num_attempts 235
# episode 451, loss 0.382059, num_attempts 241
# episode 452, loss 0.396470, num_attempts 397
# episode 453, loss 0.374617, num_attempts 414
# episode 454, loss 0.382646, num_attempts 275
# episode 455, loss 0.386211, num_attempts 206
# episode 456, loss 0.375221, num_attempts 426
# episode 457, loss 0.386844, num_attempts 293
# episode 458, loss 0.376560, num_attempts 251
# episode 459, loss 0.404573, num_attempts 164
# episode 460, loss 0.377181, num_attempts 306
# episode 461, loss 0.386578, num_attempts 205
# episode 462, loss 0.378137, num_attempts 513
# episode 463, loss 0.363426, num_attempts 252
# episode 464, loss 0.373422, num_attempts 205
# episode 465, loss 0.384539, num_attempts 208
# episode 466, loss 0.404922, num_attempts 328
# episode 467, loss 0.394460, num_attempts 277
# episode 468, loss 0.384769, num_attempts 292
# episode 469, loss 0.383693, num_attempts 285
# episode 470, loss 0.389430, num_attempts 207
# episode 471, loss 0.374754, num_attempts 387
# episode 472, loss 0.373805, num_attempts 239
# episode 473, loss 0.382578, num_attempts 279
# episode 474, loss 0.383491, num_attempts 351
# episode 475, loss 0.381527, num_attempts 541
# episode 476, loss 0.392992, num_attempts 380
# episode 477, loss 0.373847, num_attempts 344
# episode 478, loss 0.393158, num_attempts 286
# episode 479, loss 0.385085, num_attempts 374
# episode 480, loss 0.399915, num_attempts 281
# episode 481, loss 0.374244, num_attempts 344
# episode 482, loss 0.376028, num_attempts 163
# episode 483, loss 0.380955, num_attempts 346
# episode 484, loss 0.374454, num_attempts 300
# episode 485, loss 0.370049, num_attempts 242
# episode 486, loss 0.383351, num_attempts 203
# episode 487, loss 0.386834, num_attempts 361
# episode 488, loss 0.386323, num_attempts 286
# episode 489, loss 0.389664, num_attempts 475
# episode 490, loss 0.386262, num_attempts 166
# episode 491, loss 0.393797, num_attempts 299
# episode 492, loss 0.394623, num_attempts 203
# episode 493, loss 0.386651, num_attempts 236
# episode 494, loss 0.388140, num_attempts 378
# episode 495, loss 0.389832, num_attempts 405
# episode 496, loss 0.393244, num_attempts 359
# episode 497, loss 0.393796, num_attempts 240
# episode 498, loss 0.378803, num_attempts 264
# episode 499, loss 0.381131, num_attempts 283
# episode 500, loss 0.371688, num_attempts 248
# episode 501, loss 0.380431, num_attempts 340
# episode 502, loss 0.376370, num_attempts 281
# episode 503, loss 0.389508, num_attempts 277
# episode 504, loss 0.380134, num_attempts 248
# episode 505, loss 0.377831, num_attempts 378
# episode 506, loss 0.384256, num_attempts 253
# episode 507, loss 0.379055, num_attempts 197
# episode 508, loss 0.390430, num_attempts 293
# episode 509, loss 0.391272, num_attempts 236
# episode 510, loss 0.372594, num_attempts 349
# episode 511, loss 0.387435, num_attempts 259
# episode 512, loss 0.374127, num_attempts 289
# episode 513, loss 0.375359, num_attempts 331
# episode 514, loss 0.363311, num_attempts 294
# episode 515, loss 0.385769, num_attempts 310
# episode 516, loss 0.385395, num_attempts 204
# episode 517, loss 0.386386, num_attempts 271
# episode 518, loss 0.387449, num_attempts 252
# episode 519, loss 0.386371, num_attempts 207
# episode 520, loss 0.374385, num_attempts 168
# episode 521, loss 0.396697, num_attempts 317
# episode 522, loss 0.392979, num_attempts 207
# episode 523, loss 0.375336, num_attempts 239
# episode 524, loss 0.382641, num_attempts 249
# episode 525, loss 0.383749, num_attempts 197
# episode 526, loss 0.368212, num_attempts 231
# episode 527, loss 0.386411, num_attempts 227
# episode 528, loss 0.391990, num_attempts 397
# episode 529, loss 0.377467, num_attempts 220
# episode 530, loss 0.382894, num_attempts 245
# episode 531, loss 0.375238, num_attempts 294
# episode 532, loss 0.380805, num_attempts 201
# episode 533, loss 0.378434, num_attempts 173
# episode 534, loss 0.384725, num_attempts 162
# episode 535, loss 0.387299, num_attempts 275
# episode 536, loss 0.383809, num_attempts 325
# episode 537, loss 0.386524, num_attempts 348
# episode 538, loss 0.396902, num_attempts 318
# episode 539, loss 0.372106, num_attempts 207
# episode 540, loss 0.383751, num_attempts 169
# episode 541, loss 0.391455, num_attempts 301
# episode 542, loss 0.389002, num_attempts 201
# episode 543, loss 0.391004, num_attempts 324
# episode 544, loss 0.389820, num_attempts 200
# episode 545, loss 0.387665, num_attempts 297
# episode 546, loss 0.386204, num_attempts 192
# episode 547, loss 0.392809, num_attempts 170
# episode 548, loss 0.394514, num_attempts 248
# episode 549, loss 0.387349, num_attempts 394
# episode 550, loss 0.391424, num_attempts 168
# episode 551, loss 0.393607, num_attempts 238
# episode 552, loss 0.384572, num_attempts 286
# episode 553, loss 0.389529, num_attempts 244
# episode 554, loss 0.392784, num_attempts 274
# episode 555, loss 0.402267, num_attempts 246
# episode 556, loss 0.385727, num_attempts 315
# episode 557, loss 0.384808, num_attempts 260
# episode 558, loss 0.373076, num_attempts 199
# episode 559, loss 0.387143, num_attempts 199
# episode 560, loss 0.403452, num_attempts 207
# episode 561, loss 0.393490, num_attempts 253
# episode 562, loss 0.399378, num_attempts 194
# episode 563, loss 0.379643, num_attempts 326
# episode 564, loss 0.396630, num_attempts 171
# episode 565, loss 0.399232, num_attempts 165
# episode 566, loss 0.381023, num_attempts 354
# episode 567, loss 0.368977, num_attempts 450
# episode 568, loss 0.370602, num_attempts 287
# episode 569, loss 0.400015, num_attempts 202
# episode 570, loss 0.374724, num_attempts 199
# episode 571, loss 0.408385, num_attempts 296
# episode 572, loss 0.378396, num_attempts 181
# episode 573, loss 0.392052, num_attempts 270
# episode 574, loss 0.395433, num_attempts 290
# episode 575, loss 0.387180, num_attempts 189
# episode 576, loss 0.390646, num_attempts 268
# episode 577, loss 0.390429, num_attempts 247
# episode 578, loss 0.386115, num_attempts 232
# episode 579, loss 0.373616, num_attempts 209
# episode 580, loss 0.376768, num_attempts 200
# episode 581, loss 0.379369, num_attempts 164
# episode 582, loss 0.386015, num_attempts 200
# episode 583, loss 0.390776, num_attempts 271
# episode 584, loss 0.392131, num_attempts 264
# episode 585, loss 0.388850, num_attempts 206
# episode 586, loss 0.383907, num_attempts 254
# episode 587, loss 0.380669, num_attempts 361
# episode 588, loss 0.382702, num_attempts 202
# episode 589, loss 0.382988, num_attempts 202
# episode 590, loss 0.389784, num_attempts 288
# episode 591, loss 0.393007, num_attempts 247
# episode 592, loss 0.382110, num_attempts 196
# episode 593, loss 0.372633, num_attempts 432
# episode 594, loss 0.378451, num_attempts 208
# episode 595, loss 0.389043, num_attempts 200
# episode 596, loss 0.393036, num_attempts 170
# episode 597, loss 0.390753, num_attempts 245
# episode 598, loss 0.396334, num_attempts 303
# episode 599, loss 0.390276, num_attempts 217
# episode 600, loss 0.389491, num_attempts 197
# episode 601, loss 0.387549, num_attempts 262
# episode 602, loss 0.386046, num_attempts 164
# episode 603, loss 0.375789, num_attempts 195
# episode 604, loss 0.388680, num_attempts 208
# episode 605, loss 0.385780, num_attempts 160
# episode 606, loss 0.379104, num_attempts 195
# episode 607, loss 0.397661, num_attempts 249
# episode 608, loss 0.389081, num_attempts 244
# episode 609, loss 0.382521, num_attempts 255
# episode 610, loss 0.392734, num_attempts 169
# episode 611, loss 0.375054, num_attempts 162
# episode 612, loss 0.388453, num_attempts 197
# episode 613, loss 0.393429, num_attempts 196
# episode 614, loss 0.394544, num_attempts 271
# episode 615, loss 0.380602, num_attempts 254
# episode 616, loss 0.391409, num_attempts 189
# episode 617, loss 0.390534, num_attempts 238
# episode 618, loss 0.394353, num_attempts 196
# episode 619, loss 0.389119, num_attempts 247
# episode 620, loss 0.392512, num_attempts 177
# episode 621, loss 0.384542, num_attempts 310
# episode 622, loss 0.385773, num_attempts 256
# episode 623, loss 0.384161, num_attempts 255
# episode 624, loss 0.396481, num_attempts 182
# episode 625, loss 0.386154, num_attempts 253
# episode 626, loss 0.390136, num_attempts 498
# episode 627, loss 0.387994, num_attempts 206
# episode 628, loss 0.378944, num_attempts 165
# episode 629, loss 0.383337, num_attempts 189
# episode 630, loss 0.377682, num_attempts 192
# episode 631, loss 0.402645, num_attempts 196
# episode 632, loss 0.386004, num_attempts 254
# episode 633, loss 0.384006, num_attempts 208
# episode 634, loss 0.386558, num_attempts 199
# episode 635, loss 0.377249, num_attempts 188
# episode 636, loss 0.401657, num_attempts 240
# episode 637, loss 0.386439, num_attempts 255
# episode 638, loss 0.384631, num_attempts 251
# episode 639, loss 0.385899, num_attempts 224
# episode 640, loss 0.381870, num_attempts 258
# episode 641, loss 0.380508, num_attempts 340
# episode 642, loss 0.395584, num_attempts 246
# episode 643, loss 0.389160, num_attempts 244
# episode 644, loss 0.391868, num_attempts 217
# episode 645, loss 0.393780, num_attempts 162
# episode 646, loss 0.384909, num_attempts 289
# episode 647, loss 0.379686, num_attempts 297
# episode 648, loss 0.394506, num_attempts 216
# episode 649, loss 0.390603, num_attempts 304
# episode 650, loss 0.382200, num_attempts 259
# episode 651, loss 0.395048, num_attempts 198
# episode 652, loss 0.398362, num_attempts 166
# episode 653, loss 0.402507, num_attempts 273
# episode 654, loss 0.392611, num_attempts 204
# episode 655, loss 0.398610, num_attempts 199
# episode 656, loss 0.395470, num_attempts 243
# episode 657, loss 0.391272, num_attempts 244
# episode 658, loss 0.384444, num_attempts 168
# episode 659, loss 0.404113, num_attempts 236
# episode 660, loss 0.396280, num_attempts 278
# episode 661, loss 0.393087, num_attempts 237
# episode 662, loss 0.403916, num_attempts 196
# episode 663, loss 0.393985, num_attempts 228
# episode 664, loss 0.395301, num_attempts 257
# episode 665, loss 0.390598, num_attempts 213
# episode 666, loss 0.385735, num_attempts 262
# episode 667, loss 0.399968, num_attempts 205
# episode 668, loss 0.393509, num_attempts 194
# episode 669, loss 0.391410, num_attempts 250
# episode 670, loss 0.392237, num_attempts 322
# episode 671, loss 0.395961, num_attempts 150
# episode 672, loss 0.400474, num_attempts 194
# episode 673, loss 0.389637, num_attempts 232
# episode 674, loss 0.400739, num_attempts 247
# episode 675, loss 0.380099, num_attempts 190
# episode 676, loss 0.392383, num_attempts 252
# episode 677, loss 0.400187, num_attempts 235
# episode 678, loss 0.394972, num_attempts 251
# episode 679, loss 0.391861, num_attempts 164
# episode 680, loss 0.380956, num_attempts 159
# episode 681, loss 0.396590, num_attempts 205
# episode 682, loss 0.374577, num_attempts 264
# episode 683, loss 0.386570, num_attempts 202
# episode 684, loss 0.386654, num_attempts 168
# episode 685, loss 0.402591, num_attempts 241
# episode 686, loss 0.388133, num_attempts 246
# episode 687, loss 0.377536, num_attempts 159
# episode 688, loss 0.401665, num_attempts 208
# episode 689, loss 0.394224, num_attempts 199
# episode 690, loss 0.390580, num_attempts 237
# episode 691, loss 0.402399, num_attempts 195
# episode 692, loss 0.395197, num_attempts 237
# episode 693, loss 0.394987, num_attempts 302
# episode 694, loss 0.394926, num_attempts 442
# episode 695, loss 0.388023, num_attempts 169
# episode 696, loss 0.407342, num_attempts 247
# episode 697, loss 0.397105, num_attempts 245
# episode 698, loss 0.392257, num_attempts 159
# episode 699, loss 0.396544, num_attempts 241
# episode 700, loss 0.386928, num_attempts 226
# episode 701, loss 0.408001, num_attempts 202
# episode 702, loss 0.396394, num_attempts 192
# episode 703, loss 0.397782, num_attempts 159
# episode 704, loss 0.391429, num_attempts 230
# episode 705, loss 0.382887, num_attempts 286
# episode 706, loss 0.387635, num_attempts 217
# episode 707, loss 0.379583, num_attempts 280
# episode 708, loss 0.387041, num_attempts 306
# episode 709, loss 0.381657, num_attempts 342
# episode 710, loss 0.398068, num_attempts 237
# episode 711, loss 0.401085, num_attempts 195
# episode 712, loss 0.388161, num_attempts 237
# episode 713, loss 0.391132, num_attempts 239
# episode 714, loss 0.398311, num_attempts 263
# episode 715, loss 0.398512, num_attempts 239
# episode 716, loss 0.398231, num_attempts 185
# episode 717, loss 0.373161, num_attempts 201
# episode 718, loss 0.399225, num_attempts 169
# episode 719, loss 0.394960, num_attempts 250
# episode 720, loss 0.395752, num_attempts 226
# episode 721, loss 0.391221, num_attempts 291
# episode 722, loss 0.393200, num_attempts 190
# episode 723, loss 0.381009, num_attempts 183
# episode 724, loss 0.392057, num_attempts 240
# episode 725, loss 0.394784, num_attempts 336
# episode 726, loss 0.383690, num_attempts 244
# episode 727, loss 0.392328, num_attempts 242
# episode 728, loss 0.397866, num_attempts 200
# episode 729, loss 0.377438, num_attempts 167
# episode 730, loss 0.397440, num_attempts 158
# episode 731, loss 0.387056, num_attempts 290
# episode 732, loss 0.403304, num_attempts 200
# episode 733, loss 0.386991, num_attempts 216
# episode 734, loss 0.402141, num_attempts 171
# episode 735, loss 0.394679, num_attempts 162
# episode 736, loss 0.394250, num_attempts 223
# episode 737, loss 0.389102, num_attempts 198
# episode 738, loss 0.391335, num_attempts 259
# episode 739, loss 0.391975, num_attempts 201
# episode 740, loss 0.394499, num_attempts 243
# episode 741, loss 0.390414, num_attempts 190
# episode 742, loss 0.387041, num_attempts 250
# episode 743, loss 0.391937, num_attempts 157
# episode 744, loss 0.385162, num_attempts 192
# episode 745, loss 0.382477, num_attempts 339
# episode 746, loss 0.393436, num_attempts 190
# episode 747, loss 0.399055, num_attempts 156
# episode 748, loss 0.392235, num_attempts 313
# episode 749, loss 0.399611, num_attempts 155
# episode 750, loss 0.401680, num_attempts 261
# episode 751, loss 0.396540, num_attempts 242
# episode 752, loss 0.381665, num_attempts 157
# episode 753, loss 0.389880, num_attempts 279
# episode 754, loss 0.394991, num_attempts 159
# episode 755, loss 0.388644, num_attempts 238
# episode 756, loss 0.389448, num_attempts 233
# episode 757, loss 0.398032, num_attempts 222
# episode 758, loss 0.394128, num_attempts 242
# episode 759, loss 0.377357, num_attempts 161
# episode 760, loss 0.400552, num_attempts 162
# episode 761, loss 0.395110, num_attempts 235
# episode 762, loss 0.387789, num_attempts 161
# episode 763, loss 0.390996, num_attempts 189
# episode 764, loss 0.390461, num_attempts 160
# episode 765, loss 0.387035, num_attempts 166
# episode 766, loss 0.392151, num_attempts 271
# episode 767, loss 0.395072, num_attempts 255
# episode 768, loss 0.396165, num_attempts 206
# episode 769, loss 0.393101, num_attempts 300
# episode 770, loss 0.387840, num_attempts 200
# episode 771, loss 0.405481, num_attempts 154
# episode 772, loss 0.392522, num_attempts 161
# episode 773, loss 0.389489, num_attempts 254
# episode 774, loss 0.392133, num_attempts 344
# episode 775, loss 0.394779, num_attempts 239
# episode 776, loss 0.386898, num_attempts 242
# episode 777, loss 0.392266, num_attempts 246
# episode 778, loss 0.390575, num_attempts 302
# episode 779, loss 0.398406, num_attempts 247
# episode 780, loss 0.386363, num_attempts 214
# episode 781, loss 0.406655, num_attempts 191
# episode 782, loss 0.405476, num_attempts 250
# episode 783, loss 0.396557, num_attempts 242
# episode 784, loss 0.397099, num_attempts 258
# episode 785, loss 0.395281, num_attempts 341
# episode 786, loss 0.401012, num_attempts 173
# episode 787, loss 0.388308, num_attempts 241
# episode 788, loss 0.392890, num_attempts 168
# episode 789, loss 0.394897, num_attempts 197
# episode 790, loss 0.394381, num_attempts 161
# episode 791, loss 0.390789, num_attempts 197
# episode 792, loss 0.391899, num_attempts 195
# episode 793, loss 0.399538, num_attempts 194
# episode 794, loss 0.399143, num_attempts 198
# episode 795, loss 0.393553, num_attempts 175
# episode 796, loss 0.406700, num_attempts 192
# episode 797, loss 0.394374, num_attempts 265
# episode 798, loss 0.394573, num_attempts 238
# episode 799, loss 0.378861, num_attempts 201
# episode 800, loss 0.395934, num_attempts 263
# episode 801, loss 0.398923, num_attempts 158
# episode 802, loss 0.388258, num_attempts 197
# episode 803, loss 0.398984, num_attempts 158
# episode 804, loss 0.396551, num_attempts 200
# episode 805, loss 0.395571, num_attempts 232
# episode 806, loss 0.407104, num_attempts 152
# episode 807, loss 0.398658, num_attempts 240
# episode 808, loss 0.394642, num_attempts 159
# episode 809, loss 0.397972, num_attempts 157
# episode 810, loss 0.405447, num_attempts 222
# episode 811, loss 0.399706, num_attempts 239
# episode 812, loss 0.403237, num_attempts 152
# episode 813, loss 0.409196, num_attempts 187
# episode 814, loss 0.408061, num_attempts 263
# episode 815, loss 0.397046, num_attempts 157
# episode 816, loss 0.400551, num_attempts 162
# episode 817, loss 0.397754, num_attempts 235
# episode 818, loss 0.397658, num_attempts 154
# episode 819, loss 0.396811, num_attempts 157
# episode 820, loss 0.399889, num_attempts 195
# episode 821, loss 0.389650, num_attempts 261
# episode 822, loss 0.403326, num_attempts 212
# episode 823, loss 0.396663, num_attempts 159
# episode 824, loss 0.402234, num_attempts 242
# episode 825, loss 0.383994, num_attempts 244
# episode 826, loss 0.384166, num_attempts 260
# episode 827, loss 0.392623, num_attempts 230
# episode 828, loss 0.385666, num_attempts 347
# episode 829, loss 0.396881, num_attempts 191
# episode 830, loss 0.397036, num_attempts 157
# episode 831, loss 0.400500, num_attempts 163
# episode 832, loss 0.402486, num_attempts 162
# episode 833, loss 0.401665, num_attempts 159
# episode 834, loss 0.400971, num_attempts 154
# episode 835, loss 0.400959, num_attempts 162
# episode 836, loss 0.395369, num_attempts 230
# episode 837, loss 0.399192, num_attempts 185
# episode 838, loss 0.402521, num_attempts 251
# episode 839, loss 0.391008, num_attempts 162
# episode 840, loss 0.391405, num_attempts 159
# episode 841, loss 0.395189, num_attempts 249
# episode 842, loss 0.397775, num_attempts 198
# episode 843, loss 0.412876, num_attempts 226
# episode 844, loss 0.404872, num_attempts 177
# episode 845, loss 0.406614, num_attempts 158
# episode 846, loss 0.409706, num_attempts 239
# episode 847, loss 0.391907, num_attempts 162
# episode 848, loss 0.403765, num_attempts 207
# episode 849, loss 0.399624, num_attempts 152
# episode 850, loss 0.397532, num_attempts 256
# episode 851, loss 0.403379, num_attempts 240
# episode 852, loss 0.385804, num_attempts 228
# episode 853, loss 0.388046, num_attempts 244
# episode 854, loss 0.397869, num_attempts 167
# episode 855, loss 0.395772, num_attempts 188
# episode 856, loss 0.403235, num_attempts 201
# episode 857, loss 0.408268, num_attempts 196
# episode 858, loss 0.411752, num_attempts 210
# episode 859, loss 0.406503, num_attempts 158
# episode 860, loss 0.397590, num_attempts 155
# episode 861, loss 0.400012, num_attempts 219
# episode 862, loss 0.397449, num_attempts 167
# episode 863, loss 0.407532, num_attempts 167
# episode 864, loss 0.396947, num_attempts 253
# episode 865, loss 0.399243, num_attempts 157
# episode 866, loss 0.410555, num_attempts 151
# episode 867, loss 0.409919, num_attempts 197
# episode 868, loss 0.392778, num_attempts 453
# episode 869, loss 0.406218, num_attempts 199
# episode 870, loss 0.403291, num_attempts 157
# episode 871, loss 0.383458, num_attempts 147
# episode 872, loss 0.393257, num_attempts 239
# episode 873, loss 0.393664, num_attempts 248
# episode 874, loss 0.393675, num_attempts 195
# episode 875, loss 0.401884, num_attempts 157
# episode 876, loss 0.397681, num_attempts 274
# episode 877, loss 0.390223, num_attempts 175
# episode 878, loss 0.394764, num_attempts 263
# episode 879, loss 0.394245, num_attempts 160
# episode 880, loss 0.401715, num_attempts 243
# episode 881, loss 0.401226, num_attempts 155
# episode 882, loss 0.390689, num_attempts 173
# episode 883, loss 0.405463, num_attempts 252
# episode 884, loss 0.388167, num_attempts 198
# episode 885, loss 0.401904, num_attempts 239
# episode 886, loss 0.408069, num_attempts 151
# episode 887, loss 0.392408, num_attempts 276
# episode 888, loss 0.394196, num_attempts 165
# episode 889, loss 0.397874, num_attempts 195
# episode 890, loss 0.387613, num_attempts 170
# episode 891, loss 0.391735, num_attempts 159
# episode 892, loss 0.396278, num_attempts 326
# episode 893, loss 0.394890, num_attempts 200
# episode 894, loss 0.396991, num_attempts 161
# episode 895, loss 0.391856, num_attempts 160
# episode 896, loss 0.388368, num_attempts 241
# episode 897, loss 0.395710, num_attempts 226
# episode 898, loss 0.397234, num_attempts 151
# episode 899, loss 0.395548, num_attempts 168
# episode 900, loss 0.410199, num_attempts 158
# episode 901, loss 0.404008, num_attempts 259
# episode 902, loss 0.403072, num_attempts 155
# episode 903, loss 0.394278, num_attempts 193
# episode 904, loss 0.395465, num_attempts 151
# episode 905, loss 0.406603, num_attempts 159
# episode 906, loss 0.408345, num_attempts 156
# episode 907, loss 0.401234, num_attempts 165
# episode 908, loss 0.405603, num_attempts 157
# episode 909, loss 0.405397, num_attempts 160
# episode 910, loss 0.403419, num_attempts 159
# episode 911, loss 0.400472, num_attempts 155
# episode 912, loss 0.389873, num_attempts 244
# episode 913, loss 0.393220, num_attempts 232
# episode 914, loss 0.397192, num_attempts 156
# episode 915, loss 0.388250, num_attempts 151
# episode 916, loss 0.400652, num_attempts 163
# episode 917, loss 0.409631, num_attempts 161
# episode 918, loss 0.399449, num_attempts 160
# episode 919, loss 0.399078, num_attempts 203
# episode 920, loss 0.407111, num_attempts 147
# episode 921, loss 0.401884, num_attempts 234
# episode 922, loss 0.400771, num_attempts 165
# episode 923, loss 0.409679, num_attempts 195
# episode 924, loss 0.404964, num_attempts 155
# episode 925, loss 0.390498, num_attempts 253
# episode 926, loss 0.381272, num_attempts 228
# episode 927, loss 0.395934, num_attempts 210
# episode 928, loss 0.397379, num_attempts 155
# episode 929, loss 0.392787, num_attempts 248
# episode 930, loss 0.401394, num_attempts 158
# episode 931, loss 0.389310, num_attempts 156
# episode 932, loss 0.401022, num_attempts 153
# episode 933, loss 0.401094, num_attempts 288
# episode 934, loss 0.405640, num_attempts 239
# episode 935, loss 0.394111, num_attempts 269
# episode 936, loss 0.387216, num_attempts 244
# episode 937, loss 0.390465, num_attempts 202
# episode 938, loss 0.388199, num_attempts 161
# episode 939, loss 0.393524, num_attempts 222
# episode 940, loss 0.403407, num_attempts 164
# episode 941, loss 0.402367, num_attempts 155
# episode 942, loss 0.395323, num_attempts 210
# episode 943, loss 0.398324, num_attempts 160
# episode 944, loss 0.402933, num_attempts 257
# episode 945, loss 0.397256, num_attempts 156
# episode 946, loss 0.408269, num_attempts 197
# episode 947, loss 0.413475, num_attempts 153
# episode 948, loss 0.395207, num_attempts 154
# episode 949, loss 0.396609, num_attempts 160
# episode 950, loss 0.396305, num_attempts 156
# episode 951, loss 0.401288, num_attempts 151
# episode 952, loss 0.402958, num_attempts 191
# episode 953, loss 0.405710, num_attempts 242
# episode 954, loss 0.400214, num_attempts 152
# episode 955, loss 0.393248, num_attempts 204
# episode 956, loss 0.398244, num_attempts 159
# episode 957, loss 0.395144, num_attempts 149
# episode 958, loss 0.400669, num_attempts 160
# episode 959, loss 0.402813, num_attempts 159
# episode 960, loss 0.393530, num_attempts 203
# episode 961, loss 0.402388, num_attempts 159
# episode 962, loss 0.403681, num_attempts 240
# episode 963, loss 0.402015, num_attempts 151
# episode 964, loss 0.395991, num_attempts 154
# episode 965, loss 0.398763, num_attempts 151
# episode 966, loss 0.393972, num_attempts 266
# episode 967, loss 0.400481, num_attempts 159
# episode 968, loss 0.399430, num_attempts 251
# episode 969, loss 0.391571, num_attempts 153
# episode 970, loss 0.407961, num_attempts 217
# episode 971, loss 0.405219, num_attempts 156
# episode 972, loss 0.389062, num_attempts 300
# episode 973, loss 0.396002, num_attempts 157
# episode 974, loss 0.397653, num_attempts 157
# episode 975, loss 0.406509, num_attempts 161
# episode 976, loss 0.397554, num_attempts 171
# episode 977, loss 0.397427, num_attempts 165
# episode 978, loss 0.404569, num_attempts 263
# episode 979, loss 0.404195, num_attempts 216
# episode 980, loss 0.395254, num_attempts 153
# episode 981, loss 0.406720, num_attempts 160
# episode 982, loss 0.397455, num_attempts 186
# episode 983, loss 0.397740, num_attempts 153
# episode 984, loss 0.396566, num_attempts 156
# episode 985, loss 0.403661, num_attempts 152
# episode 986, loss 0.408258, num_attempts 202
# episode 987, loss 0.400118, num_attempts 153
# episode 988, loss 0.405563, num_attempts 240
# episode 989, loss 0.411476, num_attempts 152
# episode 990, loss 0.406268, num_attempts 167
# episode 991, loss 0.408616, num_attempts 151
# episode 992, loss 0.411276, num_attempts 155
# episode 993, loss 0.400876, num_attempts 169
# episode 994, loss 0.413576, num_attempts 157
# episode 995, loss 0.413937, num_attempts 158
# episode 996, loss 0.398201, num_attempts 161
# episode 997, loss 0.406420, num_attempts 153
# episode 998, loss 0.402808, num_attempts 157
# episode 999, loss 0.400159, num_attempts 152
# training cost:  1380.6479613780975

# %% [markdown]
# ## Save the Result

# %%
torch.save(q_learning_policy_net.state_dict(),"saves/MountainCar-v0-dqn.pth")

# %% [markdown]
# ## Plot Train Result

# %%
import matplotlib.pyplot as plt
from typing import Dict
def plot_num_attempts_per_episode(num_attempts_per_episode:Dict):
    fig,ax=plt.subplots()
    ax.plot(num_attempts_per_episode.keys(),num_attempts_per_episode.values())
    
def plot_reward_per_episode(reward_per_episode:Dict):
    fig,ax=plt.subplots()
    ax.plot(reward_per_episode.keys(),reward_per_episode.values())
    
plot_num_attempts_per_episode(q_learning_num_attempts_per_episode)
plot_reward_per_episode(q_learning_reward_per_episode)

# %% [markdown]
# ## Test the Policy

# %%
def test_policy(env: gym.Env, policy_net: Q_Approximator, num_tests: int, device: str):
    num_attempts = []
    for test_i in range(num_tests):
        state = env.reset()[0]
        num_trying_step = 0
        is_terminated = False
        while not is_terminated:
            normalized_state = normalizer(env, state)
            q_actions = torch.zeros((env.action_space.n, 1))
            with torch.no_grad():
                q_actions = policy_net(torch.tensor(
                    normalized_state, dtype=torch.float32, device=device))
            action = torch.argmax(q_actions).detach().cpu().item()
            state, reward, is_terminated, is_truncated, info = env.step(action)
            num_trying_step += 1
        num_attempts.append(num_trying_step)
        print("test %d, take %d steps" % (test_i, num_trying_step))
    print("Average trying step :%f" % (1.0*np.sum(num_attempts)/num_tests))

test_policy(env, q_learning_policy_net, int(1e3),
            device="cuda" if torch.cuda.is_available() else "cpu")
# Out:
# test 0, take 145 steps
# test 1, take 150 steps
# test 2, take 161 steps
# test 3, take 160 steps
# test 4, take 145 steps
# test 5, take 145 steps
# test 6, take 144 steps
# test 7, take 148 steps
# test 8, take 157 steps
# test 9, take 148 steps
# test 10, take 147 steps
# test 11, take 144 steps
# test 12, take 148 steps
# test 13, take 109 steps
# test 14, take 149 steps
# test 15, take 158 steps
# test 16, take 145 steps
# test 17, take 144 steps
# test 18, take 155 steps
# test 19, take 154 steps
# test 20, take 149 steps
# test 21, take 160 steps
# test 22, take 159 steps
# test 23, take 109 steps
# test 24, take 150 steps
# test 25, take 150 steps
# test 26, take 144 steps
# test 27, take 146 steps
# test 28, take 154 steps
# test 29, take 152 steps
# test 30, take 143 steps
# test 31, take 149 steps
# test 32, take 153 steps
# test 33, take 144 steps
# test 34, take 147 steps
# test 35, take 149 steps
# test 36, take 145 steps
# test 37, take 154 steps
# test 38, take 147 steps
# test 39, take 110 steps
# test 40, take 158 steps
# test 41, take 144 steps
# test 42, take 147 steps
# test 43, take 147 steps
# test 44, take 144 steps
# test 45, take 145 steps
# test 46, take 157 steps
# test 47, take 147 steps
# test 48, take 152 steps
# test 49, take 147 steps
# test 50, take 151 steps
# test 51, take 146 steps
# test 52, take 156 steps
# test 53, take 110 steps
# test 54, take 143 steps
# test 55, take 144 steps
# test 56, take 154 steps
# test 57, take 145 steps
# test 58, take 144 steps
# test 59, take 162 steps
# test 60, take 144 steps
# test 61, take 146 steps
# test 62, take 152 steps
# test 63, take 148 steps
# test 64, take 146 steps
# test 65, take 160 steps
# test 66, take 148 steps
# test 67, take 152 steps
# test 68, take 110 steps
# test 69, take 146 steps
# test 70, take 154 steps
# test 71, take 163 steps
# test 72, take 147 steps
# test 73, take 145 steps
# test 74, take 146 steps
# test 75, take 153 steps
# test 76, take 153 steps
# test 77, take 160 steps
# test 78, take 151 steps
# test 79, take 142 steps
# test 80, take 148 steps
# test 81, take 143 steps
# test 82, take 144 steps
# test 83, take 110 steps
# test 84, take 147 steps
# test 85, take 163 steps
# test 86, take 160 steps
# test 87, take 145 steps
# test 88, take 151 steps
# test 89, take 147 steps
# test 90, take 147 steps
# test 91, take 153 steps
# test 92, take 162 steps
# test 93, take 155 steps
# test 94, take 156 steps
# test 95, take 145 steps
# test 96, take 161 steps
# test 97, take 152 steps
# test 98, take 144 steps
# test 99, take 147 steps
# test 100, take 146 steps
# test 101, take 148 steps
# test 102, take 145 steps
# test 103, take 145 steps
# test 104, take 146 steps
# test 105, take 144 steps
# test 106, take 161 steps
# test 107, take 146 steps
# test 108, take 155 steps
# test 109, take 144 steps
# test 110, take 167 steps
# test 111, take 160 steps
# test 112, take 109 steps
# test 113, take 154 steps
# test 114, take 161 steps
# test 115, take 146 steps
# test 116, take 146 steps
# test 117, take 154 steps
# test 118, take 154 steps
# test 119, take 144 steps
# test 120, take 144 steps
# test 121, take 147 steps
# test 122, take 149 steps
# test 123, take 149 steps
# test 124, take 110 steps
# test 125, take 147 steps
# test 126, take 169 steps
# test 127, take 152 steps
# test 128, take 156 steps
# test 129, take 148 steps
# test 130, take 145 steps
# test 131, take 144 steps
# test 132, take 146 steps
# test 133, take 148 steps
# test 134, take 158 steps
# test 135, take 147 steps
# test 136, take 152 steps
# test 137, take 160 steps
# test 138, take 144 steps
# test 139, take 144 steps
# test 140, take 109 steps
# test 141, take 151 steps
# test 142, take 151 steps
# test 143, take 151 steps
# test 144, take 153 steps
# test 145, take 146 steps
# test 146, take 150 steps
# test 147, take 143 steps
# test 148, take 148 steps
# test 149, take 167 steps
# test 150, take 162 steps
# test 151, take 142 steps
# test 152, take 151 steps
# test 153, take 159 steps
# test 154, take 142 steps
# test 155, take 145 steps
# test 156, take 159 steps
# test 157, take 155 steps
# test 158, take 146 steps
# test 159, take 146 steps
# test 160, take 143 steps
# test 161, take 146 steps
# test 162, take 159 steps
# test 163, take 153 steps
# test 164, take 143 steps
# test 165, take 110 steps
# test 166, take 145 steps
# test 167, take 145 steps
# test 168, take 110 steps
# test 169, take 110 steps
# test 170, take 110 steps
# test 171, take 147 steps
# test 172, take 153 steps
# test 173, take 155 steps
# test 174, take 147 steps
# test 175, take 152 steps
# test 176, take 144 steps
# test 177, take 144 steps
# test 178, take 147 steps
# test 179, take 147 steps
# test 180, take 166 steps
# test 181, take 157 steps
# test 182, take 158 steps
# test 183, take 151 steps
# test 184, take 152 steps
# test 185, take 154 steps
# test 186, take 153 steps
# test 187, take 147 steps
# test 188, take 146 steps
# test 189, take 154 steps
# test 190, take 166 steps
# test 191, take 110 steps
# test 192, take 153 steps
# test 193, take 148 steps
# test 194, take 144 steps
# test 195, take 147 steps
# test 196, take 154 steps
# test 197, take 152 steps
# test 198, take 147 steps
# test 199, take 168 steps
# test 200, take 158 steps
# test 201, take 153 steps
# test 202, take 158 steps
# test 203, take 145 steps
# test 204, take 145 steps
# test 205, take 152 steps
# test 206, take 145 steps
# test 207, take 153 steps
# test 208, take 143 steps
# test 209, take 148 steps
# test 210, take 146 steps
# test 211, take 161 steps
# test 212, take 145 steps
# test 213, take 147 steps
# test 214, take 151 steps
# test 215, take 144 steps
# test 216, take 147 steps
# test 217, take 158 steps
# test 218, take 144 steps
# test 219, take 147 steps
# test 220, take 159 steps
# test 221, take 110 steps
# test 222, take 147 steps
# test 223, take 147 steps
# test 224, take 152 steps
# test 225, take 149 steps
# test 226, take 145 steps
# test 227, take 148 steps
# test 228, take 162 steps
# test 229, take 147 steps
# test 230, take 159 steps
# test 231, take 143 steps
# test 232, take 162 steps
# test 233, take 147 steps
# test 234, take 159 steps
# test 235, take 160 steps
# test 236, take 110 steps
# test 237, take 148 steps
# test 238, take 153 steps
# test 239, take 144 steps
# test 240, take 147 steps
# test 241, take 147 steps
# test 242, take 144 steps
# test 243, take 148 steps
# test 244, take 161 steps
# test 245, take 144 steps
# test 246, take 110 steps
# test 247, take 142 steps
# test 248, take 147 steps
# test 249, take 147 steps
# test 250, take 144 steps
# test 251, take 109 steps
# test 252, take 148 steps
# test 253, take 168 steps
# test 254, take 148 steps
# test 255, take 110 steps
# test 256, take 110 steps
# test 257, take 149 steps
# test 258, take 147 steps
# test 259, take 110 steps
# test 260, take 156 steps
# test 261, take 157 steps
# test 262, take 144 steps
# test 263, take 147 steps
# test 264, take 143 steps
# test 265, take 110 steps
# test 266, take 147 steps
# test 267, take 158 steps
# test 268, take 146 steps
# test 269, take 152 steps
# test 270, take 110 steps
# test 271, take 147 steps
# test 272, take 152 steps
# test 273, take 149 steps
# test 274, take 158 steps
# test 275, take 152 steps
# test 276, take 159 steps
# test 277, take 148 steps
# test 278, take 110 steps
# test 279, take 154 steps
# test 280, take 152 steps
# test 281, take 158 steps
# test 282, take 147 steps
# test 283, take 147 steps
# test 284, take 110 steps
# test 285, take 166 steps
# test 286, take 153 steps
# test 287, take 147 steps
# test 288, take 146 steps
# test 289, take 144 steps
# test 290, take 149 steps
# test 291, take 149 steps
# test 292, take 145 steps
# test 293, take 151 steps
# test 294, take 146 steps
# test 295, take 147 steps
# test 296, take 152 steps
# test 297, take 160 steps
# test 298, take 142 steps
# test 299, take 169 steps
# test 300, take 161 steps
# test 301, take 151 steps
# test 302, take 144 steps
# test 303, take 144 steps
# test 304, take 146 steps
# test 305, take 151 steps
# test 306, take 144 steps
# test 307, take 169 steps
# test 308, take 110 steps
# test 309, take 160 steps
# test 310, take 157 steps
# test 311, take 152 steps
# test 312, take 147 steps
# test 313, take 157 steps
# test 314, take 110 steps
# test 315, take 169 steps
# test 316, take 148 steps
# test 317, take 154 steps
# test 318, take 148 steps
# test 319, take 147 steps
# test 320, take 144 steps
# test 321, take 156 steps
# test 322, take 110 steps
# test 323, take 110 steps
# test 324, take 161 steps
# test 325, take 149 steps
# test 326, take 155 steps
# test 327, take 144 steps
# test 328, take 147 steps
# test 329, take 147 steps
# test 330, take 145 steps
# test 331, take 150 steps
# test 332, take 147 steps
# test 333, take 146 steps
# test 334, take 151 steps
# test 335, take 144 steps
# test 336, take 160 steps
# test 337, take 145 steps
# test 338, take 156 steps
# test 339, take 151 steps
# test 340, take 161 steps
# test 341, take 144 steps
# test 342, take 144 steps
# test 343, take 151 steps
# test 344, take 147 steps
# test 345, take 167 steps
# test 346, take 162 steps
# test 347, take 147 steps
# test 348, take 142 steps
# test 349, take 146 steps
# test 350, take 167 steps
# test 351, take 147 steps
# test 352, take 151 steps
# test 353, take 156 steps
# test 354, take 152 steps
# test 355, take 147 steps
# test 356, take 153 steps
# test 357, take 145 steps
# test 358, take 169 steps
# test 359, take 147 steps
# test 360, take 153 steps
# test 361, take 148 steps
# test 362, take 147 steps
# test 363, take 110 steps
# test 364, take 147 steps
# test 365, take 159 steps
# test 366, take 144 steps
# test 367, take 150 steps
# test 368, take 143 steps
# test 369, take 152 steps
# test 370, take 153 steps
# test 371, take 155 steps
# test 372, take 142 steps
# test 373, take 148 steps
# test 374, take 147 steps
# test 375, take 144 steps
# test 376, take 147 steps
# test 377, take 148 steps
# test 378, take 151 steps
# test 379, take 144 steps
# test 380, take 148 steps
# test 381, take 146 steps
# test 382, take 145 steps
# test 383, take 145 steps
# test 384, take 162 steps
# test 385, take 153 steps
# test 386, take 144 steps
# test 387, take 152 steps
# test 388, take 144 steps
# test 389, take 145 steps
# test 390, take 152 steps
# test 391, take 144 steps
# test 392, take 154 steps
# test 393, take 147 steps
# test 394, take 158 steps
# test 395, take 109 steps
# test 396, take 110 steps
# test 397, take 159 steps
# test 398, take 157 steps
# test 399, take 142 steps
# test 400, take 148 steps
# test 401, take 161 steps
# test 402, take 145 steps
# test 403, take 144 steps
# test 404, take 144 steps
# test 405, take 144 steps
# test 406, take 148 steps
# test 407, take 110 steps
# test 408, take 156 steps
# test 409, take 147 steps
# test 410, take 148 steps
# test 411, take 146 steps
# test 412, take 144 steps
# test 413, take 144 steps
# test 414, take 145 steps
# test 415, take 145 steps
# test 416, take 150 steps
# test 417, take 159 steps
# test 418, take 147 steps
# test 419, take 145 steps
# test 420, take 154 steps
# test 421, take 150 steps
# test 422, take 151 steps
# test 423, take 148 steps
# test 424, take 159 steps
# test 425, take 150 steps
# test 426, take 143 steps
# test 427, take 145 steps
# test 428, take 146 steps
# test 429, take 144 steps
# test 430, take 153 steps
# test 431, take 145 steps
# test 432, take 146 steps
# test 433, take 152 steps
# test 434, take 147 steps
# test 435, take 144 steps
# test 436, take 110 steps
# test 437, take 110 steps
# test 438, take 110 steps
# test 439, take 153 steps
# test 440, take 144 steps
# test 441, take 144 steps
# test 442, take 169 steps
# test 443, take 151 steps
# test 444, take 150 steps
# test 445, take 144 steps
# test 446, take 169 steps
# test 447, take 153 steps
# test 448, take 149 steps
# test 449, take 145 steps
# test 450, take 149 steps
# test 451, take 163 steps
# test 452, take 153 steps
# test 453, take 158 steps
# test 454, take 110 steps
# test 455, take 163 steps
# test 456, take 147 steps
# test 457, take 154 steps
# test 458, take 153 steps
# test 459, take 144 steps
# test 460, take 148 steps
# test 461, take 146 steps
# test 462, take 110 steps
# test 463, take 147 steps
# test 464, take 109 steps
# test 465, take 149 steps
# test 466, take 151 steps
# test 467, take 147 steps
# test 468, take 146 steps
# test 469, take 151 steps
# test 470, take 145 steps
# test 471, take 154 steps
# test 472, take 154 steps
# test 473, take 155 steps
# test 474, take 151 steps
# test 475, take 147 steps
# test 476, take 168 steps
# test 477, take 150 steps
# test 478, take 160 steps
# test 479, take 150 steps
# test 480, take 142 steps
# test 481, take 145 steps
# test 482, take 152 steps
# test 483, take 145 steps
# test 484, take 146 steps
# test 485, take 144 steps
# test 486, take 145 steps
# test 487, take 144 steps
# test 488, take 144 steps
# test 489, take 144 steps
# test 490, take 147 steps
# test 491, take 146 steps
# test 492, take 110 steps
# test 493, take 147 steps
# test 494, take 153 steps
# test 495, take 168 steps
# test 496, take 146 steps
# test 497, take 110 steps
# test 498, take 146 steps
# test 499, take 148 steps
# test 500, take 148 steps
# test 501, take 153 steps
# test 502, take 152 steps
# test 503, take 148 steps
# test 504, take 151 steps
# test 505, take 148 steps
# test 506, take 147 steps
# test 507, take 147 steps
# test 508, take 152 steps
# test 509, take 151 steps
# test 510, take 168 steps
# test 511, take 144 steps
# test 512, take 148 steps
# test 513, take 151 steps
# test 514, take 158 steps
# test 515, take 153 steps
# test 516, take 151 steps
# test 517, take 146 steps
# test 518, take 148 steps
# test 519, take 149 steps
# test 520, take 145 steps
# test 521, take 146 steps
# test 522, take 149 steps
# test 523, take 144 steps
# test 524, take 110 steps
# test 525, take 147 steps
# test 526, take 147 steps
# test 527, take 144 steps
# test 528, take 144 steps
# test 529, take 168 steps
# test 530, take 110 steps
# test 531, take 153 steps
# test 532, take 144 steps
# test 533, take 145 steps
# test 534, take 157 steps
# test 535, take 151 steps
# test 536, take 110 steps
# test 537, take 151 steps
# test 538, take 158 steps
# test 539, take 144 steps
# test 540, take 145 steps
# test 541, take 154 steps
# test 542, take 144 steps
# test 543, take 147 steps
# test 544, take 160 steps
# test 545, take 153 steps
# test 546, take 154 steps
# test 547, take 110 steps
# test 548, take 152 steps
# test 549, take 153 steps
# test 550, take 161 steps
# test 551, take 145 steps
# test 552, take 145 steps
# test 553, take 153 steps
# test 554, take 149 steps
# test 555, take 144 steps
# test 556, take 154 steps
# test 557, take 110 steps
# test 558, take 144 steps
# test 559, take 144 steps
# test 560, take 144 steps
# test 561, take 162 steps
# test 562, take 152 steps
# test 563, take 146 steps
# test 564, take 158 steps
# test 565, take 148 steps
# test 566, take 153 steps
# test 567, take 150 steps
# test 568, take 144 steps
# test 569, take 160 steps
# test 570, take 147 steps
# test 571, take 148 steps
# test 572, take 149 steps
# test 573, take 150 steps
# test 574, take 110 steps
# test 575, take 149 steps
# test 576, take 157 steps
# test 577, take 146 steps
# test 578, take 152 steps
# test 579, take 147 steps
# test 580, take 154 steps
# test 581, take 143 steps
# test 582, take 146 steps
# test 583, take 144 steps
# test 584, take 110 steps
# test 585, take 153 steps
# test 586, take 149 steps
# test 587, take 144 steps
# test 588, take 152 steps
# test 589, take 151 steps
# test 590, take 149 steps
# test 591, take 159 steps
# test 592, take 147 steps
# test 593, take 149 steps
# test 594, take 147 steps
# test 595, take 144 steps
# test 596, take 153 steps
# test 597, take 152 steps
# test 598, take 147 steps
# test 599, take 149 steps
# test 600, take 154 steps
# test 601, take 149 steps
# test 602, take 147 steps
# test 603, take 147 steps
# test 604, take 154 steps
# test 605, take 143 steps
# test 606, take 144 steps
# test 607, take 153 steps
# test 608, take 148 steps
# test 609, take 147 steps
# test 610, take 161 steps
# test 611, take 110 steps
# test 612, take 161 steps
# test 613, take 110 steps
# test 614, take 144 steps
# test 615, take 150 steps
# test 616, take 146 steps
# test 617, take 152 steps
# test 618, take 146 steps
# test 619, take 163 steps
# test 620, take 145 steps
# test 621, take 145 steps
# test 622, take 147 steps
# test 623, take 152 steps
# test 624, take 158 steps
# test 625, take 110 steps
# test 626, take 158 steps
# test 627, take 144 steps
# test 628, take 161 steps
# test 629, take 154 steps
# test 630, take 147 steps
# test 631, take 151 steps
# test 632, take 153 steps
# test 633, take 149 steps
# test 634, take 147 steps
# test 635, take 160 steps
# test 636, take 159 steps
# test 637, take 148 steps
# test 638, take 147 steps
# test 639, take 150 steps
# test 640, take 147 steps
# test 641, take 147 steps
# test 642, take 110 steps
# test 643, take 149 steps
# test 644, take 162 steps
# test 645, take 154 steps
# test 646, take 153 steps
# test 647, take 148 steps
# test 648, take 148 steps
# test 649, take 153 steps
# test 650, take 148 steps
# test 651, take 148 steps
# test 652, take 144 steps
# test 653, take 150 steps
# test 654, take 161 steps
# test 655, take 159 steps
# test 656, take 154 steps
# test 657, take 149 steps
# test 658, take 148 steps
# test 659, take 145 steps
# test 660, take 168 steps
# test 661, take 145 steps
# test 662, take 110 steps
# test 663, take 144 steps
# test 664, take 151 steps
# test 665, take 159 steps
# test 666, take 145 steps
# test 667, take 147 steps
# test 668, take 149 steps
# test 669, take 147 steps
# test 670, take 144 steps
# test 671, take 146 steps
# test 672, take 146 steps
# test 673, take 146 steps
# test 674, take 162 steps
# test 675, take 144 steps
# test 676, take 153 steps
# test 677, take 154 steps
# test 678, take 144 steps
# test 679, take 149 steps
# test 680, take 155 steps
# test 681, take 158 steps
# test 682, take 145 steps
# test 683, take 156 steps
# test 684, take 144 steps
# test 685, take 142 steps
# test 686, take 147 steps
# test 687, take 150 steps
# test 688, take 147 steps
# test 689, take 110 steps
# test 690, take 156 steps
# test 691, take 145 steps
# test 692, take 144 steps
# test 693, take 157 steps
# test 694, take 143 steps
# test 695, take 160 steps
# test 696, take 153 steps
# test 697, take 159 steps
# test 698, take 148 steps
# test 699, take 152 steps
# test 700, take 145 steps
# test 701, take 147 steps
# test 702, take 167 steps
# test 703, take 110 steps
# test 704, take 147 steps
# test 705, take 169 steps
# test 706, take 158 steps
# test 707, take 147 steps
# test 708, take 162 steps
# test 709, take 147 steps
# test 710, take 157 steps
# test 711, take 145 steps
# test 712, take 149 steps
# test 713, take 154 steps
# test 714, take 149 steps
# test 715, take 147 steps
# test 716, take 152 steps
# test 717, take 110 steps
# test 718, take 144 steps
# test 719, take 150 steps
# test 720, take 145 steps
# test 721, take 160 steps
# test 722, take 146 steps
# test 723, take 162 steps
# test 724, take 144 steps
# test 725, take 149 steps
# test 726, take 152 steps
# test 727, take 144 steps
# test 728, take 144 steps
# test 729, take 109 steps
# test 730, take 145 steps
# test 731, take 144 steps
# test 732, take 145 steps
# test 733, take 149 steps
# test 734, take 149 steps
# test 735, take 159 steps
# test 736, take 166 steps
# test 737, take 151 steps
# test 738, take 110 steps
# test 739, take 154 steps
# test 740, take 146 steps
# test 741, take 151 steps
# test 742, take 158 steps
# test 743, take 161 steps
# test 744, take 146 steps
# test 745, take 158 steps
# test 746, take 147 steps
# test 747, take 145 steps
# test 748, take 146 steps
# test 749, take 147 steps
# test 750, take 149 steps
# test 751, take 146 steps
# test 752, take 158 steps
# test 753, take 152 steps
# test 754, take 160 steps
# test 755, take 145 steps
# test 756, take 147 steps
# test 757, take 144 steps
# test 758, take 147 steps
# test 759, take 150 steps
# test 760, take 148 steps
# test 761, take 154 steps
# test 762, take 153 steps
# test 763, take 146 steps
# test 764, take 110 steps
# test 765, take 110 steps
# test 766, take 151 steps
# test 767, take 147 steps
# test 768, take 151 steps
# test 769, take 144 steps
# test 770, take 152 steps
# test 771, take 110 steps
# test 772, take 150 steps
# test 773, take 157 steps
# test 774, take 147 steps
# test 775, take 110 steps
# test 776, take 157 steps
# test 777, take 156 steps
# test 778, take 144 steps
# test 779, take 154 steps
# test 780, take 152 steps
# test 781, take 147 steps
# test 782, take 144 steps
# test 783, take 149 steps
# test 784, take 151 steps
# test 785, take 144 steps
# test 786, take 147 steps
# test 787, take 110 steps
# test 788, take 146 steps
# test 789, take 151 steps
# test 790, take 153 steps
# test 791, take 153 steps
# test 792, take 145 steps
# test 793, take 145 steps
# test 794, take 147 steps
# test 795, take 149 steps
# test 796, take 162 steps
# test 797, take 162 steps
# test 798, take 143 steps
# test 799, take 151 steps
# test 800, take 144 steps
# test 801, take 154 steps
# test 802, take 151 steps
# test 803, take 152 steps
# test 804, take 148 steps
# test 805, take 161 steps
# test 806, take 146 steps
# test 807, take 144 steps
# test 808, take 153 steps
# test 809, take 156 steps
# test 810, take 144 steps
# test 811, take 149 steps
# test 812, take 146 steps
# test 813, take 147 steps
# test 814, take 158 steps
# test 815, take 144 steps
# test 816, take 147 steps
# test 817, take 149 steps
# test 818, take 146 steps
# test 819, take 154 steps
# test 820, take 147 steps
# test 821, take 144 steps
# test 822, take 149 steps
# test 823, take 147 steps
# test 824, take 145 steps
# test 825, take 153 steps
# test 826, take 168 steps
# test 827, take 160 steps
# test 828, take 150 steps
# test 829, take 153 steps
# test 830, take 158 steps
# test 831, take 144 steps
# test 832, take 155 steps
# test 833, take 143 steps
# test 834, take 143 steps
# test 835, take 168 steps
# test 836, take 146 steps
# test 837, take 144 steps
# test 838, take 160 steps
# test 839, take 153 steps
# test 840, take 150 steps
# test 841, take 151 steps
# test 842, take 154 steps
# test 843, take 153 steps
# test 844, take 147 steps
# test 845, take 163 steps
# test 846, take 157 steps
# test 847, take 158 steps
# test 848, take 153 steps
# test 849, take 148 steps
# test 850, take 156 steps
# test 851, take 147 steps
# test 852, take 109 steps
# test 853, take 144 steps
# test 854, take 144 steps
# test 855, take 161 steps
# test 856, take 159 steps
# test 857, take 159 steps
# test 858, take 161 steps
# test 859, take 148 steps
# test 860, take 148 steps
# test 861, take 149 steps
# test 862, take 146 steps
# test 863, take 167 steps
# test 864, take 157 steps
# test 865, take 145 steps
# test 866, take 147 steps
# test 867, take 167 steps
# test 868, take 154 steps
# test 869, take 160 steps
# test 870, take 110 steps
# test 871, take 110 steps
# test 872, take 157 steps
# test 873, take 155 steps
# test 874, take 142 steps
# test 875, take 153 steps
# test 876, take 161 steps
# test 877, take 148 steps
# test 878, take 161 steps
# test 879, take 144 steps
# test 880, take 142 steps
# test 881, take 144 steps
# test 882, take 159 steps
# test 883, take 147 steps
# test 884, take 152 steps
# test 885, take 146 steps
# test 886, take 146 steps
# test 887, take 152 steps
# test 888, take 147 steps
# test 889, take 148 steps
# test 890, take 152 steps
# test 891, take 110 steps
# test 892, take 148 steps
# test 893, take 149 steps
# test 894, take 142 steps
# test 895, take 157 steps
# test 896, take 154 steps
# test 897, take 160 steps
# test 898, take 152 steps
# test 899, take 150 steps
# test 900, take 145 steps
# test 901, take 145 steps
# test 902, take 158 steps
# test 903, take 147 steps
# test 904, take 153 steps
# test 905, take 153 steps
# test 906, take 147 steps
# test 907, take 154 steps
# test 908, take 110 steps
# test 909, take 145 steps
# test 910, take 161 steps
# test 911, take 110 steps
# test 912, take 110 steps
# test 913, take 148 steps
# test 914, take 167 steps
# test 915, take 148 steps
# test 916, take 147 steps
# test 917, take 147 steps
# test 918, take 152 steps
# test 919, take 154 steps
# test 920, take 147 steps
# test 921, take 159 steps
# test 922, take 146 steps
# test 923, take 144 steps
# test 924, take 153 steps
# test 925, take 161 steps
# test 926, take 154 steps
# test 927, take 157 steps
# test 928, take 110 steps
# test 929, take 153 steps
# test 930, take 162 steps
# test 931, take 146 steps
# test 932, take 157 steps
# test 933, take 157 steps
# test 934, take 157 steps
# test 935, take 145 steps
# test 936, take 149 steps
# test 937, take 147 steps
# test 938, take 149 steps
# test 939, take 149 steps
# test 940, take 145 steps
# test 941, take 153 steps
# test 942, take 152 steps
# test 943, take 147 steps
# test 944, take 153 steps
# test 945, take 152 steps
# test 946, take 152 steps
# test 947, take 145 steps
# test 948, take 151 steps
# test 949, take 147 steps
# test 950, take 147 steps
# test 951, take 143 steps
# test 952, take 110 steps
# test 953, take 147 steps
# test 954, take 144 steps
# test 955, take 144 steps
# test 956, take 155 steps
# test 957, take 161 steps
# test 958, take 144 steps
# test 959, take 145 steps
# test 960, take 152 steps
# test 961, take 146 steps
# test 962, take 142 steps
# test 963, take 157 steps
# test 964, take 145 steps
# test 965, take 145 steps
# test 966, take 148 steps
# test 967, take 154 steps
# test 968, take 144 steps
# test 969, take 155 steps
# test 970, take 159 steps
# test 971, take 148 steps
# test 972, take 145 steps
# test 973, take 160 steps
# test 974, take 161 steps
# test 975, take 149 steps
# test 976, take 145 steps
# test 977, take 159 steps
# test 978, take 144 steps
# test 979, take 156 steps
# test 980, take 146 steps
# test 981, take 144 steps
# test 982, take 147 steps
# test 983, take 160 steps
# test 984, take 146 steps
# test 985, take 151 steps
# test 986, take 154 steps
# test 987, take 147 steps
# test 988, take 110 steps
# test 989, take 154 steps
# test 990, take 145 steps
# test 991, take 109 steps
# test 992, take 155 steps
# test 993, take 154 steps
# test 994, take 145 steps
# test 995, take 148 steps
# test 996, take 144 steps
# test 997, take 158 steps
# test 998, take 145 steps
# test 999, take 144 steps
# Average trying step :147.449000
